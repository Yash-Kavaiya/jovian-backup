# %% [markdown]
# # India-census-2011
#
# A census is a method of gathering, assembling, analysing, interpreting, publishing, and disseminating statistical data on a population.
#
# In this project, we are going to analyse the India census 2011 data using Python.We'll analyse this dataset using  Now, We'll analyse this dataset using Python analysis techniques and libraries ( Pandas, Matplotlib, Seaborn, etc. )
#
# https://www.kaggle.com/danofer/india-census?select=india-districts-census-2011.csv

# %% [markdown]
# ## Downloading the Dataset

# %%
# !pip install jovian --upgrade --quiet

# %%
import jovian

# %%
# Execute this to save new versions of the notebook
jovian.commit(project="india-census-2011")
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "i16ph021/india-census-2011" on https://jovian.ai
# [jovian] Uploading notebook..
# [jovian] Uploading additional files...
# [jovian] Committed successfully! https://jovian.ai/i16ph021/india-census-2011
# 'https://jovian.ai/i16ph021/india-census-2011'

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
census_data = pd.read_csv("India_Census_2011.csv")

# %%
census_data.head(3)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
# 2     93770    75079         53265           21814  ...         658   1092
#
#    Buddhists  Jains  Secondary_Education  Higher_Education  \
# 0         66     39                74948             39709
# 1         47      6                66459             41367
# 2      88635    103                16265              8923
#
#    Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# ...

# %%
census_data.shape
# Out:
# (640, 25)

# %%
census_data.columns
# Out:
# Index(['District_code', 'State_name', 'District_name', 'Population', 'Male',
#        'Female', 'Literate', 'Workers', 'Male_Workers', 'Female_Workers',
#        'Cultivator_Workers', 'Agricultural_Workers', 'Household_Workers',
#        'Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains',
#        'Secondary_Education', 'Higher_Education', 'Graduate_Education',
#        'Age_Group_0_29', 'Age_Group_30_49', 'Age_Group_50'],
#       dtype='object')

# %%
census_data.style.hide_index()
# Out:
# <style  type="text/css" >
# ...

# %%
census_data[census_data["District_name"].isin(['Vadodara','Surat','Ahmadabad','Rajkot'])]
# Out:
#      District_code State_name District_name  Population     Male   Female  \
# 473            474    GUJARAT     Ahmadabad     7214225  3788051  3426174
# 475            476    GUJARAT        Rajkot     3804558  1974445  1830113
# 485            486    GUJARAT      Vadodara     4165626  2153736  2011890
# 491            492    GUJARAT         Surat     6081322  3402224  2679098
#
#      Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 473   5435760  2594952       2127547          467405  ...       50754  14542
# 475   2725056  1479050       1159480          319570  ...        5478   1918
# 485   2893080  1693473       1233312          460161  ...       23813   9340
# 491   4571410  2553542       2142819          410723  ...       21052   5703
#
#      Buddhists   Jains  Secondary_Education  Higher_Education  \
# 473       4518  209287              1135058            549188
# 475       1170   33591               540278            204306
# ...

# %%
population = census_data.groupby("State_name").Population.sum().sort_values(ascending=False)

# %%
population
# Out:
# State_name
# UTTAR PRADESH                  199812341
# MAHARASHTRA                    112374333
# BIHAR                          104099452
# WEST BENGAL                     91276115
# ANDHRA PRADESH                  84580777
# MADHYA PRADESH                  72626809
# TAMIL NADU                      72147030
# RAJASTHAN                       68548437
# KARNATAKA                       61095297
# GUJARAT                         60439692
# ORISSA                          41974218
# KERALA                          33406061
# JHARKHAND                       32988134
# ASSAM                           31205576
# PUNJAB                          27743338
# CHHATTISGARH                    25545198
# HARYANA                         25351462
# NCT OF DELHI                    16787941
# JAMMU AND KASHMIR               12541302
# UTTARAKHAND                     10086292
# HIMACHAL PRADESH                 6864602
# TRIPURA                          3673917
# ...

# %%
plt.title('India census 2011')
plt.xlabel('States')
plt.ylabel('Populations')
plt.bar(census_data.State_name,census_data.Population)
# Out:
# <BarContainer object of 640 artists>

# %%
census_data[census_data.State_name =='GUJARAT']['Male'].sum()
# Out:
# 31491260

# %%
plt.plot(census_data.Male,census_data.Female);

# %%
census_data.plot.hist(x='State_name',y='Workers')
plt.show()

# %%
census_data[['Male_Workers','Female_Workers']].plot(figsize=(18,10))
# Out:
# <AxesSubplot:>
