# %% [markdown]
# # week-8-decision-tree
#
# Use the "Run" button to execute the code.

# %% [markdown]
# # Decision Tree
#
# - Non-parametric supervised learning methods
# - can learn classification and regression models.
# - Predicts label based on rules inferred from the features in the training set.

# %% [markdown]
# # Tree Algorithms
#
# ID3
#
# C4.5
#
# C5.0
#
# CART

# %% [markdown]
# ## sklearn implementation of trees
#
# scikit-learn uses an optimized version of the CART
# algorithm; however it does not support categorical variables for now
#
#     - Classification:-  `sklearn.tree.DecisionTreeClassifier`
#     - Regression    :- `sklearn.tree.DecisionTreeRegressor`
#
# Both these estimators have the same set of parameters except for
#  criterion
# used for tree splitting.
# - splitter
# - max_depth
# - min_samples_split
# - min_samples_leaf

# %% [markdown]
#  ##  sklearn tree parameters
# - splitter:- Strategy for splitting at each node. best  random
#
#
# - max_depth :Maximum depth of the tree.
# int When None, the tree expanded until all leaves are
#
#
# pure or they contain less than
# samples.
#
# min_samples_split
#
#
# min_samples_split
# int   float
#
# The minimum number of samples required  2
#
# to split an internal node.
#
#
# min_samples_leaf
# int   float
#
# The minimum number of samples required
#
# to be at a leaf node.
