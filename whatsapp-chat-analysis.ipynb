# %% [markdown]
# # whatsapp-chat-analysis
#
# Use the "Run" button to execute the code.

# %%
# !pip install jovian --upgrade --quiet

# %%
import jovian

# %%
# Execute this to save new versions of the notebook
jovian.commit(project="whatsapp-chat-analysis")
# Out:
# [jovian] Updating notebook "yash-kavaiya/whatsapp-chat-analysis" on https://jovian.ai
# [jovian] Committed successfully! https://jovian.ai/yash-kavaiya/whatsapp-chat-analysis
# 'https://jovian.ai/yash-kavaiya/whatsapp-chat-analysis'

# %%
import re
import pandas as pd

# %%
f=open('WhatsApp Chat with CAP Amrutlal.txt','r',encoding='utf-8')

# %%
data =f.read()

# %%
print(data)
# Out:
# 08/10/20, 8:34 pm - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.
# 08/10/20, 8:34 pm - Svnit Help: Hi
# 10/10/20, 7:25 pm - Svnit Help: Follow this link to join my WhatsApp group: https://chat.whatsapp.com/FSXPAsD0NiuAGU4UpvSxoJ
# 11/10/20, 9:27 pm - Svnit Help: 1. All Placement Materials Drive Links:
#
# TCS:
#  https://drive.google.com/open?id=1XN8w1Q9akk1IagpaSPDKVowlVCQJ1tV8
#
# CTS:
#  https://drive.google.com/open?id=1a-HWjvdfAb4t3xo0O_R8_kwlqGs6Ipt-
#
# TEK SYSTEMS:
#  https://drive.google.com/open?id=1wsJFR1RNpzcDWcecYkx7Ke5EtvUa3b7i
#
#
# TECH MAHINDRA :
#  https://drive.google.com/open?id=1ltJ4CSu-6rSCOgjLKtFC6LIwfVej5NXl
#
# WIPRO:
#  https://drive.google.com/open?id=15WDPKzntkQ0ux1-qXZhQ6MQ-IjSgYZWE
#
# INFOSYS:
#  https://drive.google.com/open?id=1A0so4BGzkynu4k9T0hl-c6yokMBlMQiF
#
#
# MINDTREE:
#  https://drive.google.com/open?id=1dkBNs61BGmaQ8bvMDMlNO2ENDtCcNSdp
#
# VALUE LABS:
#  https://drive.google.com/open?id=1MC6LwK5zoTIDkmjZHgm2TxnHPGxGnrHJ
#
# MPHASIS:
#  https://drive.google.com/open?id=1s4ExADXgIicpTaNjLj5Et6yv4UaPqXaT
#
#
# ZENQ:
#  https://drive.google.com/open?id=1FjZxLhhMSNhnkru1pZEGjD1-w8XJPTZQ
#
# EPAM:
#  https://drive.google.com/open?id=14kYwuvk3DiCp_c67Qhdm5j8MQ9ctPmRm
#
# GATE: https://drive.google.com/open?id=1996QqgIeETZQ2o7Lpomh8-fSl49tlckz
#
#
# AMCAT:
#
#  https://drive.google.com/open?id=1vPCyQnc844BK9jsTKQ7WIzcGpx3r3J-d
#
# ELITMUS: https://drive.google.com/open?id=154gp-J7a43zDe2lwvwZPQ0uvEnU7SYF1
#
# TALENT BATTLE:
#  https://drive.google.com/open?id=1wIUuyPIS41jKHTrA_1RyMX1hBNWJ0TFS
#
#
# Sample C Programs:
#  https://drive.google.com/drive/u/3/folders/1pO69Sp5N3sSKCD2GeMKUvmiOQPxQDAhU?usp=gmail
#
# RS AGARWAL: https://drive.google.com/open?id=1nq4YFOp4zFrLu0zj8uIV8u3DZfVMRQyp
#
# TR & HR Preparation:**
#  https://drive.google.com/open?id=1jkLdSlyv-zAx3a8G-EZ38eXQV_AGjci4
#
#
# 2. All  cse Books over 500 books are there👇
#
# https://drive.google.com/drive/folders/0B9XbEQh3jB9pWVBFX0hqTzA0dUU
# 11/10/20, 9:31 pm - CAP Amrutlal: This message was deleted
# 11/10/20, 9:31 pm - CAP Amrutlal: 1. All Placement Materials Drive Links:
#
# TCS:
#  https://drive.google.com/open?id=1XN8w1Q9akk1IagpaSPDKVowlVCQJ1tV8
#
# CTS:
#  https://drive.google.com/open?id=1a-HWjvdfAb4t3xo0O_R8_kwlqGs6Ipt-
#
# TEK SYSTEMS:
#  https://drive.google.com/open?id=1wsJFR1RNpzcDWcecYkx7Ke5EtvUa3b7i
#
#
# TECH MAHINDRA :
#  https://drive.google.com/open?id=1ltJ4CSu-6rSCOgjLKtFC6LIwfVej5NXl
#
# WIPRO:
#  https://drive.google.com/open?id=15WDPKzntkQ0ux1-qXZhQ6MQ-IjSgYZWE
#
# INFOSYS:
#  https://drive.google.com/open?id=1A0so4BGzkynu4k9T0hl-c6yokMBlMQiF
#
#
# MINDTREE:
#  https://drive.google.com/open?id=1dkBNs61BGmaQ8bvMDMlNO2ENDtCcNSdp
#
# VALUE LABS:
#  https://drive.google.com/open?id=1MC6LwK5zoTIDkmjZHgm2TxnHPGxGnrHJ
#
# MPHASIS:
#  https://drive.google.com/open?id=1s4ExADXgIicpTaNjLj5Et6yv4UaPqXaT
#
#
# ZENQ:
#  https://drive.google.com/open?id=1FjZxLhhMSNhnkru1pZEGjD1-w8XJPTZQ
#
# EPAM:
#  https://drive.google.com/open?id=14kYwuvk3DiCp_c67Qhdm5j8MQ9ctPmRm
#
# GATE: https://drive.google.com/open?id=1996QqgIeETZQ2o7Lpomh8-fSl49tlckz
#
#
# AMCAT:
#
#  https://drive.google.com/open?id=1vPCyQnc844BK9jsTKQ7WIzcGpx3r3J-d
#
# ELITMUS: https://drive.google.com/open?id=154gp-J7a43zDe2lwvwZPQ0uvEnU7SYF1
#
# TALENT BATTLE:
#  https://drive.google.com/open?id=1wIUuyPIS41jKHTrA_1RyMX1hBNWJ0TFS
#
#
# Sample C Programs:
#  https://drive.google.com/drive/u/3/folders/1pO69Sp5N3sSKCD2GeMKUvmiOQPxQDAhU?usp=gmail
#
# RS AGARWAL: https://drive.google.com/open?id=1nq4YFOp4zFrLu0zj8uIV8u3DZfVMRQyp
#
# TR & HR Preparation:**
#  https://drive.google.com/open?id=1jkLdSlyv-zAx3a8G-EZ38eXQV_AGjci4
#
#
# 2. All  cse Books over 500 books are there👇
#
# https://drive.google.com/drive/folders/0B9XbEQh3jB9pWVBFX0hqTzA0dUU
# 12/10/20, 4:33 pm - Svnit Help: All Physics news, study material, conference news, internship, conference and jobs are one place
#
#
# Website :-
# www.myephysics.tk
#
# Facebook Group:-
# https://www.facebook.com/groups/631058463998415/
#
# WhatsApp Group:
# https://chat.whatsapp.com/Bhgkjq1GfWX7JkcyO1FTqp
#
# Instagram Page:-
# https://www.instagram.com/Myephysics/
#
# Telegram Group:-
# https://t.me/myephysics
#
# Facebook Page:-
# https://www.facebook.com/MyePhysics-100813561286456/
#
# YouTube  channel
# https://youtu.be/-7irOymPTxk
# 13/10/20, 4:27 pm - Svnit Help: Join live seminar
#
# We have now come up with an enlightening webinar on JoSAA counseling which would be given by Mr. Yash Kavaiya, Training and Placement Coordinator at NIT Surat.
#
# We welcome you to join the event and RSVP in the below link (join fast, only 60 participants!!!)
# https://www.runtheworld.today/app/invitation/9847
#
# If at all you aren't able to join in the event, we will be live on our Facebook page Social Edignite!!!
# https://www.facebook.com/socialindiagroup.in/
# 21/10/20, 8:20 am - Svnit Help: *💯AMZONE GREAT FESTIVAL DAYS*
#
# *⏱️Today is last date*
#
# 📚📙📘📗📕📔📓📖 *Reference-Books-for-CSIR-NET-JRF-GATE-TIFR-JEST-Examination*
#
# https://www.myephysics.tk/2019/09/reference-books-for-csir-net-jrf-gate.html?m=1
# 21/10/20, 8:24 am - Svnit Help: *💯AMAZON GREAT INDIAN SALES DAYS*
#
# *⏱️Today is last date*
#
#
# *Buy books and get 10-30 % discount*
#
# 📚📙📘📗📕📔📓📖 *Reference-Books-for-CSIR-NET-JRF-GATE-TIFR-JEST-Examination*
#
# https://www.myephysics.tk/2019/09/reference-books-for-csir-net-jrf-gate.html?m=1
# 24/10/20, 10:19 pm - CAP Amrutlal: https://forms.gle/ThFnBVWDj1nxAA469
# 24/10/20, 10:21 pm - CAP Amrutlal: Mission
#
# ગુજરાત કોલેજ ગ્રુપનું મિશન ગુજરાત ના વિધાર્થીઓ માં સ્કીલ કેળવવા માટેનો છે
#
# Key Point
# ગુજરાત કોલેજ ગ્રુપ વિધાર્થીઓ ને માહિતી અને માધ્યમ આપે છે
# કોલેજકાળ દરમિયાન જોતમારી પાસે નવી આવડત હશે તો તમે જીવનમાં આગળ વધી શકશો
# આ ગ્રુપ કોલેજના ઇવેન્ટ, કોલેજની બૂક ,અને અન્ય નોટ્સ આપવામાં આવશે.
# દર મહીને એક વર્કશોપ થશે જેમાં વિધાર્થીઓ ને Advance Excel, Powerpoint ,LATEX, Placement Preparation , Aptitude ,Group Discussion ,Quiz and SOFTWARE, શીખવવામાં આવશે.
#
#
# How to join
# કોઈ પણ વિદ્યાર્થી જે શીખવાની આશા રાખે તે જોડાય શકે છે.
#
#
# How to be Part of Gujarat College Group
#
# જો તમે તમારી કોલેજના Campus Ambassador બનવા માંગતા હોય તો
# નીચેનું ફોર્મ ભરી દેવું
# interview
# આ ફોર્મ ભરાયા બાદ તમને interview વિશે Email થી જણાવવામાં આવશે.
# 24/10/20, 10:21 pm - CAP Amrutlal: Gujarat College Group
# 24/10/20, 10:21 pm - CAP Amrutlal: <Media omitted>
# 24/10/20, 10:21 pm - CAP Amrutlal: <Media omitted>
# 24/10/20, 10:24 pm - Svnit Help: *🏫Gujarat College Group*
#
# *🔸Mission*
#
# ગુજરાત કોલેજ ગ્રુપનું મિશન ગુજરાત ના વિધાર્થીઓ માં સ્કીલ કેળવવા માટેનો છે
#
# *🔸Key Point*
# ગુજરાત કોલેજ ગ્રુપ વિધાર્થીઓ ને માહિતી અને માધ્યમ આપે છે
# કોલેજકાળ દરમિયાન જોતમારી પાસે નવી આવડત હશે તો તમે જીવનમાં આગળ વધી શકશો
# આ ગ્રુપ કોલેજના ઇવેન્ટ, કોલેજની બૂક ,અને અન્ય નોટ્સ આપવામાં આવશે.
# દર મહીને એક વર્કશોપ થશે જેમાં વિધાર્થીઓ ને Advance Excel, Powerpoint ,LATEX, Placement Preparation , Aptitude ,Group Discussion ,Quiz and SOFTWARE, શીખવવામાં આવશે.
#
# *🔸How to join*
#
# કોઈ પણ વિદ્યાર્થી જે શીખવાની આશા રાખે તે જોડાય શકે છે.
#
# *🔸How to be Part of Gujarat College Group*
#
# જો તમે તમારી કોલેજના Campus Ambassador બનવા માંગતા હોય તો
# નીચેનું ફોર્મ ભરી દેવું
#
# *🔸Interview*
# આ ફોર્મ ભરાયા બાદ તમને interview વિશે Email થી જણાવવામાં આવશે.
#
# https://forms.gle/ThFnBVWDj1nxAA469
# 25/10/20, 9:55 pm - Svnit Help: I recently tried CashKaro.com & highly recommend it! You get extra Cashback on top of all retailer discounts.
# Try it out: https://play.google.com/store/apps/details?id=com.cashkaro&referrer=r%3D2685571%26refname%3DKavaiya%20Yashkumar%26utm_source%3Dapp_referral
# 26/10/20, 4:11 pm - Svnit Help: નમસ્કાર મિત્રો
#
# *ફોટો પાડો અને જવાબ મેળવો*
#
# ધોરણ 6 થી ધોરણ 12 ના વિદયાર્થીઓને ખૂબ ઉપયોગી એપ
#
# *Snap solve Mobile App*
#
# https://ytb123.onelink.me/C8ft/asktutorreferral
#
#  આ એપ્લિકશન થી તમે તમારા પ્રશ્નોના જવાબ સેકન્ડ માં મેળવી શકો છો
#
# તમારે પ્રશ્ન નો ફોટો પાડવાનો રહેશે. ત્યારબાદ થોડી સેકન્ડ માં જવાબ મળી જશે.
#
# આ વિડિયો સોલ્યુશન પણ મળશે
# તેના માટે તમારે નીચે આપેલા Referal Code નો ઉપયોગ કરી વિડિયો સોલ્યુશન મેળવી શકશો.
#
# કોડ :- MT98WX
#
# https://ytb123.onelink.me/C8ft/asktutorreferral
# 29/10/20, 8:53 am - CAP Amrutlal: One-week Short Term TrainingProgramme (STTP)
# Computational Tools for Physics (CTS 2020)23rd -27th November 2020ABOUT THE TRAINING PROGRAMME This training program is designed to cover a broad spectrum of scientific computational tools developed based on various advanced statistical methods, and are being used by scientists and engineers worldwide. The participants will be introduced to the basics of these tools for demonstrating and analyzing problems in various fields of applied physics. The sessions will also be inclined towards introducing these tools as a means of imparting education. Lectures followed by demonstrations and/or hands-on sessions will be delivered.
#
# MAJOR HIGHLIGHTS• MATLAB/Simulink
# • LabVIEW
# • Mathematica
#
# WHO CAN ATTEND IT•Faculty members from AICTE recognized institutes
# •Research Scholars pursuing a Ph.D.
# •PG/UG students from science and engineering background
# •Industry personnel Limited seats will be filled based on a first-come, first-serve basis.
#
# REGISTRATION AND GENERAL INFORMATIONRegistration will be done via GoogleForm using the following link:https://forms.gle/KHSoiVCsWBMZVmbk9Alternatively, the participants can sendthe scanned copies of the FilledRegistration Form and Payment Detailson the following email idsp@phy.svnit.ac.insttp.ctp.2020@gmail.com • The certificate of participation will beissued only to those candidates securingmore than 80% attendance. • E-certificates will be sent to theparticipants by email.• Students (UG/PG/Ph.D) : Rs. 300 /-• Faculty: Rs. 600/- • Industry person:: 2500/-The non-refundable registration feeshould be sent through Netbanking/Online Payment: • Bank Account Name: Director, SVNITCCE• SBI Account No.: 37030749143• IFSC Code: SBIN0003320 • Branch: SVRCET Branch, Ichchhanath,Surat, Gujarat, 395007. While paying through the net-banking, inremarks the purpose is to be written as“Registration Fee for CTP2020”.(Kindly save the receipt or takescreenshot of the payment)
# Last date of registration:
# 14th November 2020.
# Intimation of selection through E-mail: 16th November 2020.
# 29/10/20, 8:57 am - CAP Amrutlal: <Media omitted>
# 29/10/20, 8:57 am - CAP Amrutlal: <Media omitted>
# 29/10/20, 8:58 am - CAP Amrutlal: http://bit.ly/Sttp_Ctp
# 29/10/20, 9:00 am - CAP Amrutlal: https://chat.whatsapp.com/Bhgkjq1GfWX7JkcyO1FTqp
# 29/10/20, 9:04 am - CAP Amrutlal: *One-week Short Term TrainingProgramme (STTP)*
#
# *Computational Tools for Physics (CTS 2020)l*
#
# 23rd -27th November 2020
#
# *ABOUT THE TRAINING PROGRAMME*
#
# This training program is designed to cover a broad spectrum of scientific computational tools developed based on various advanced statistical methods, and are being used by scientists and engineers worldwide. The participants will be introduced to the basics of these tools for demonstrating and analysing problems in various fields of applied physics. The sessions will also be inclined towards introducing these tools as a means of imparting education. Lectures followed by demonstrations and/or hands-on sessions will be delivered.
#
# *MAJOR HIGHLIGHTS*
#
# • MATLAB/Simulink
# • LabVIEW
# • Mathematica
#
# *WHO CAN ATTEND*
#  IT•Faculty members from AICTE recognized institutes
# •Research Scholars pursuing a Ph.D.
# •PG/UG students from science and engineering background
# •Industry personnel Limited seats will be filled based on a first-come, first-serve basis.
#
# *REGISTRATION AND GENERAL INFORMATION*
#
# Registration will be done via Google Form using the following
#  link:https://forms.gle/KHSoiVCsWBMZVmbk9
#
# Alternatively, the participants can send the scanned copies of the Filled Registration Form and Payment Details on  the following email id
#
# sp@phy.svnit.ac.in
# sttp.ctp.2020@gmail.com
#
#  • The certificate of participation will beissued only to those candidates securingmore than 80% attendance.
# • E-certificates will be sent to theparticipants by email.• Students (UG/PG/Ph.D) : Rs. 300 /-
# • Faculty: Rs. 600/-
# • Industry person:: 2500/-The non-refundable registration fee should be sent through Netbanking/Online Payment:
# • Bank Account Name: Director, SVNITCCE
# • SBI Account No.: 37030749143
# • IFSC Code: SBIN0003320
# • Branch: SVRCET Branch, Ichchhhanath,Surat, Gujarat, 395007. While paying through the net-banking, inremarks the purpose is to be written as“Registration Fee for CTP2020”.(Kindly save the receipt or take screenshot of the payment)
# Last date of registration:
# 14th November 2020.
# Intimation of selection through E-mail: 16th November 2020.
# 29/10/20, 9:06 am - Svnit Help: *One-week Short Term TrainingProgramme (STTP)*
#
# *Computational Tools for Physics (CTS 2020)l*
#
# 23rd -27th November 2020
#
# *ABOUT THE TRAINING PROGRAMME*
#
# This training program is designed to cover a broad spectrum of scientific computational tools developed based on various advanced statistical methods, and are being used by scientists and engineers worldwide. The participants will be introduced to the basics of these tools for demonstrating and analysing problems in various fields of applied physics. The sessions will also be inclined towards introducing these tools as a means of imparting education. Lectures followed by demonstrations and/or hands-on sessions will be delivered.
#
# *MAJOR HIGHLIGHTS*
#
# • MATLAB/Simulink
# • LabVIEW
# • Mathematica
#
# *WHO CAN ATTEND*
#  IT•Faculty members from AICTE recognized institutes
# •Research Scholars pursuing a Ph.D.
# •PG/UG students from science and engineering background
# •Industry personnel Limited seats will be filled based on a first-come, first-serve basis.
#
# *REGISTRATION AND GENERAL INFORMATION*
#
# Registration will be done via Google Form using the following
#  link:https://forms.gle/KHSoiVCsWBMZVmbk9
#
# Alternatively, the participants can send the scanned copies of the Filled Registration Form and Payment Details on  the following email id
#
# sp@phy.svnit.ac.in
# sttp.ctp.2020@gmail.com
#
# For more updates like this join our Whatsapp Group
# https://chat.whatsapp.com/Bhgkjq1GfWX7JkcyO1FTqp
#
#
#
#  • The certificate of participation will beissued only to those candidates securingmore than 80% attendance.
# • E-certificates will be sent to theparticipants by email.• Students (UG/PG/Ph.D) : Rs. 300 /-
# • Faculty: Rs. 600/-
# • Industry person:: 2500/-The non-refundable registration fee should be sent through Netbanking/Online Payment:
# • Bank Account Name: Director, SVNITCCE
# • SBI Account No.: 37030749143
# • IFSC Code: SBIN0003320
# • Branch: SVRCET Branch, Ichchhhanath,Surat, Gujarat, 395007. While paying through the net-banking, inremarks the purpose is to be written as“Registration Fee for CTP2020”.(Kindly save the receipt or take screenshot of the payment)
# Last date of registration:
# 14th November 2020.
# Intimation of selection through E-mail: 16th November 2020.
# 29/10/20, 7:36 pm - Svnit Help: https://www.facebook.com/groups/csirnetphysics/permalink/4599681823439779/
# 30/10/20, 11:54 am - Svnit Help: ITKK9j9I5pLdHbFTzhHTgg
# 30/10/20, 11:57 am - Svnit Help: 16 Graphic Designer Courses
#
# Become the High paying Graphic Designer Full Courses Free Download
# Basics of Graphic Design
#
# Graphic Design Basics Core Principles for Visual Design
#
# Color Theory Basics for Graphic Designers - Creating Color Palettes
#
# Getting Started with Adobe Illustrator Learn Through Projects!
#
# Photoshop for Entrepreneurs - Design 11 Practical Projects
#
# Logo Design Mastery- The Full Course
#
# Graphic Design for Digital - A Social Media Campaign
#
# Infographic Design- Create Compelling Graphics from Facts and Data
#
# Create A Food Package Design - A Graphic Design Project for Beginners
#
# Layout Design Theory - Create Strong Designs
#
# Master Typography Basics Anatomy, Phrases, Paragraphs and Logos
#
# Natural Light Portrait Retouching in Photoshop - Start to Finish
#
# The Personal Branding Process for Creative Freelancers
#
# Adobe Illustrator Crash Course
#
# Adobe Photoshop CC for Beginners
#
# Illustrator-CC-2020-MasterClass
#
# Download :
# https://mega.nz/folder/eoxnWRAS
#
# Decryption Key : ITKK9j9I5pLdHbFTzhHTgg
# 30/10/20, 12:02 pm - Svnit Help: Worth $80000 now its for FREE
#
# WHATS INCLUDED HERE:
#
# Adobe Photoshop CC 2020
#
# https://drive.google.com/uc?id=1b1VAYz8mq8gn6uhOUfnSCb7ydsdoIVj5&export=download
#
# Adobe Animate CC 2020
#
# https://drive.google.com/uc?id=1ARH0MgFijoB6RC2f29vJzZFnoFuVhTxB&export=download
#
# Adobe Illustrator CC 2020
#
# https://drive.google.com/uc?id=1wFOR8f4nHGUG0nihv9Id4rlwzKYBTX3z&export=download
#
# Adobe Premiere Pro CC 2020
#
# https://drive.google.com/uc?id=1qyaRufD4gXMl6zMwtD0Tofc6xEuIbNHj&export=download
#
# Premiere Rush 2020
#
# https://drive.google.com/uc?id=1eVet0xZjD85ruG-0oAQm6e_IygwBGCCh&export=download
#
# Adobe Media Encoder: 2020
#
# https://drive.google.com/uc?id=10SEL8TaxzfTQkQK6a9gslASF20PVnLmz&export=download
#
# Adobe After Effects CC 2020
#
# https://drive.google.com/uc?id=1-yVPlnA4L2Cz70CL32V9V7ST20zRxWch&export=download
#
# Adobe InDesign CC 2020
#
# https://drive.google.com/uc?id=1XKvDUG8HexPp_p2c7gQAovx6kIc9rf3b&export=download
#
# Adobe InCopy CC 2020
#
# https://drive.google.com/uc?id=1WVFbkmQq3ZFrNHaqE20uRollFROJZvtz&export=download
#
# Adobe Dimension CC 2020
#
# https://drive.google.com/uc?id=1r2YJB7z2teF820i3x_gkokhnzrVvYEDi&export=download
#
# Adobe Audition CC 2020
#
# https://drive.google.com/uc?id=1bw6F6gYKjXdnqpwj-jV5D2IsXG3fyJmq&export=download
#
# Adobe Dreamweaver CC 2020
#
# https://drive.google.com/uc?id=1XVQ6lRmQYdBItaVE1SGYMGmexBIqynx7&export=download
#
# Adobe Character Animator CC 2020
#
# https://drive.google.com/uc?id=1kZLLRQyXsBZZZN66gKjc7aFfDlDC9FzZ&export=download
# 30/10/20, 12:03 pm - Svnit Help: 18GB Covid-19 Graphics, Photo, Video & More
#
# Stock Video
# Photos
# Graphics
# Video Templates
# Graphic Templates
# Presentation Templates
# Web Templates
#
# https://mega.nz/folder/SdZEiChR#ikbV1gIoXgO6NlJBfWxarw
# 30/10/20, 12:04 pm - Svnit Help: 30,000+ Courses Free Download Largest Collection On Planet
# 1. https://mega.nz/folder/xoRAQKKK#Q-fJZbrj7pz7rieZt7hUSA
# 2. https://mega.nz/#F!9RYzGSwT!MSgQvkQFel_3UXaiXMXtOg
# 3. https://mega.nz/#F!dVRB2KyD!7nlxgbMyMk9W7ZwLnTpJSw
# 4.
# https://mega.nz/#F!dVRB2KyD!7nlxgbMyMk9W7ZwLnTpJSw
# 5.
# https://mega.nz/#F!aFdGDKzS!uOJxSGciWEbSsZQgzPlAag
# 6.
# https://mega.nz/#F!pCxVXJjA!uO8MGAUs--VfhixffVzYZA
# 7.
# https://mega.nz/#F!f5B2TBrJ!7mvXwTsvQXD4Y0Yu5L7kCw
# 8.
# https://mega.nz/#F!nJtEGDJA!wAmYa0rT_h0AKo-uVkuhqw
# 9.
# https://mega.nz/#F!zjAzlLjL!HaM2tjZDSd5qNNPe5lYoTA
# 10.
# https://mega.nz/folder/vg4CyK4B#kbHCovzj3dYYwnewOzF_NQ
# 11. 300BT
# https://drive.google.com/drive/folders/1oCMgJeBc55NuEasPcgwjx2FuPdQd8neu?sort=13&direction=a
# 12. (10000+ Courses, Retriving Folder Data takes some time)
# https://mega.nz/folder/TjAGxSLD#pi9cuU55Kqze_7v9tzsMHQ
# 13.(This drive contains more than 30,000+ Courses. But, need to ask for permission)
#
# https://drive.google.com/drive/u/0/folders/1BbIUn3XSGtKUDGQKRWgxDt81JKcVl2lG
#
# All Programming Languages
# AutoCAD
# Web Development
# Ethical Hacking
# 3D & 2D Animation
# Network and Security
# Hardware
# Deep Learning.
# Python for Everybody.
# Data Science.
# Business Foundations.
# Architecting with Google Cloud Platform.
# Data Engineering on Google Cloud Platform.
# Excel to MySQL.
# Photography
# Video Editing
# All Adobe
# iOS develpoment
# Photoshop
# SEO
# Advertising
# YouTube
# Cloud Computing
# Artificial Intelligence
# Arts & Crafts
# Body Language
# Windows Softwares
# CCNA
# CERT
# Marketing
# Music
# Short Film
# Data Visualization
# Poster Designing
# DevOps
# Many more…
# You Can find any Course on our Planet
# 30/10/20, 12:05 pm - Svnit Help: GFX Pack Free Download
#
# 3D Layer Styles
# Layer Styles Bapsy
# Layer Styles
# Abstract Pack
# BackPack Wolfs
# DuckCC
# Jades Graphics
# Kamo Personal
# Phantom
# Nordic Pack
#
# LINK: https://mega.nz/folder/hAsTCKQL#2k4deOAnitACnFuXfOkgoQ
# 30/10/20, 12:06 pm - Svnit Help: GFX Pack Free Download
#
# 3D Layer Styles
# Layer Styles Bapsy
# Layer Styles
# Abstract Pack
# BackPack Wolfs
# DuckCC
# Jades Graphics
# Kamo Personal
# Phantom
# Nordic Pack
#
# LINK: https://mega.nz/folder/hAsTCKQL#2k4deOAnitACnFuXfOkgoQ
# 31/10/20, 7:26 am - Svnit Help: Terms of use
# Gigzoe ("we" or "Gigzoe") is a product of Blizzcraft Infotech Pvt. Ltd.
#
# By accessing or using the Gigzoe website ("https://www.gigzoe.com"), the Gigzoe service, or any applications (including mobile applications) made available by Gigzoe (together, the "Service") you agree to be bound by these terms of use ("Terms of Service"). The Service is owned and controlled by Blizzcraft Infotech Pvt. Ltd.("Gigzoe”). These Terms of Service affect your legal rights and obligations. If you do not agree to be bound by all of these Terms of Use, do not access or use the Service.
#
# By using the Services, you agree and state that:
#
# You form a binding contract with Gigzoe
# You are not a person who is barred from receiving the Services under the laws of India or any other applicable jurisdiction
# You will comply with these Terms and all applicable local, state, national, and international laws, rules, and regulations.
# You may not use the Services and may not accept the Terms if you are not of legal age to form a binding contract with Gigzoe.
# 1. Definitions
# Section 1 contains definitions of certain important terms used through these Terms of Service. We advise our users to know what these terms mean:
#
# 1.1  The term "Service" refers to the Services by Gigzoe, including without limitation to Gigzoe website ("https://www.gigzoe.com"), the Gigzoe service, or any applications (including mobile applications) made available by Gigzoe, use of Gigzoe’s Web and Mobile Applications in their entirety and of online community, blog and forum and help centre.
#
# 1.2  The term “Website” refers to Gigzoe’s Website ("https://www.gigzoe.com"), including all pages, sub pages and sub domains, including all information, content, products and services made available through the website.
#
# 1.3  “Gigzoe”, “We”, “Us” or “Our” refers to our parent entity Blizzcraft Infotech Private limited
#
# 1.4  The term “User(s)” refers to any party whether a person, company or firm who visits and/or registers itself on Gigzoe Website and/or Service.
#
# 1.5  The term “Seller” refers to any Person, firm, Company or agency providing and/or selling any business services who registers on Gigzoe Website and/or Service to sell services to Buyers. Sellers are not agents or employees of Gigzoe and Gigzoe does not refer to them as any work or Client.
#
# 1.6  The term “Buyer” refers to any Person, Company or Firm or any other business which registers itself on Gigzoe Website and/or Service and buys or books a service.
#
# 1.7  The term “Business Services” refers to services sold by Sellers on Gigzoe.
#
# 1.8  The term “Content” refers to any Content displayed on Gigzoe’s Website and Mobile Application including without limitation to any information, text, data, graphics, videos, art, sound, design and any other material.
#
# 1.9  The term “User Generated Content” refers to any content created, posted or published by Users on Gigzoe’s Website and Mobile Application and/or Service.
#
# 1.10  The term “Order” refers to the order placed by a Buyer with a Seller for a particular Service/Gig.
#
# 1.11  The term “Service or Gig” refers to the service offered by a Seller on Gigzoe.
#
# 1.12  The term “Order Booking Date” refers to the date on which an order is placed by the buyer with a seller by paying a booking amount.
#
# 1.13  The term “Order in progress” refers to an order created/booked between Buyer and Seller on Gigzoe which is not marked as completed.
#
# 1.14  The term “Completed Order” refers to an order created/booked between Buyer and Seller on Gigzoe which is marked as completed.
#
# 2. Gigzoe Purpose, Basic Terms, and Relationship with Users
# 2.1  Gigzoe is a tech driven interactive platform for Buyers to find, hire and book services with Sellers. Buyers can discover Services/Gigs, discover Sellers based on various filters and buy any service they want. Buyers can also post their projects to request proposals from Sellers. Gigzoe does not force Buyers to book any service from any Seller.
#
# 2.2  Sellers include freelancers, firms, agencies and companies in the categories of Design, Web & Software Development, Content & Marketing, Tax & Accounting, Legal & Compliances. Gigzoe is not a law firm or Chartered Accountancy firm or Company Secretary Firm and does not provide any legal services, legal advice, audit services,”lawyer or Chartered Accountant or Company secretary referral services" and do not provide or participate in any legal representation.
#
# 2.3  Sellers on Gigzoe sell their services by creating Gigs/Services and/or by sending proposals to projects posted by Potential Buyers.
#
# 2.4  We put our efficiency to verify Seller's registering on Gigzoe through a tough screening process which includes profile creation, KYC Verification, Interview and screening process and quality checks. However, we do not warranty, guarantee or represent any inability, incompetency, quality or qualifications of/for any Seller.
#
# 2.5  Sellers have full freedom and are solely responsible for determining the Services/Gigs they want to sell on Gigzoe, set prices for their services, set delivery time for their services. Sellers are solely responsible for any content they upload and/or share while creating Services/Gigs.
#
# 2.6  Gigzoe does not force any Seller to register on Gigzoe and sell his/her Services/Gigs. It is totally free for any Seller to register on Gigzoe out of their own wish. If any laws, regulations, rules and guidelines stop or prohibit any Seller from registering and selling Services/Gigs on Gigzoe, then the Seller has voluntarily violated such laws, regulations, rules and guidelines by registering on Gigzoe. Seller takes sole responsibility for violating any such laws & regulations.
#
# 2.7  Gigzoe reserves the following rights:
#
# Verify and approve Sellers to sell Services/Gigs on Gigzoe
# Verify and approve Services/Gigs created by Sellers
# Deactivate Seller Accounts
# Suspend Seller Accounts
# Deactivate Buyer Accounts
# Suspend Buyer Accounts
#
#  https://www.wizcounsel.com/?referral_code=KAVAIYA10747
# 31/10/20, 7:31 am - Svnit Help: *Gigzoe Purpose, Basic Terms, and Relationship with Users*
#
# https://www.wizcounsel.com/?referral_code=KAVAIYA10747
#
# 2.1  Gigzoe is a tech driven interactive platform for Buyers to find, hire and book services with Sellers. Buyers can discover Services/Gigs, discover Sellers based on various filters and buy any service they want. Buyers can also post their projects to request proposals from Sellers. Gigzoe does not force Buyers to book any service from any Seller.
#
# 2.2  Sellers include freelancers, firms, agencies and companies in the categories of Design, Web & Software Development, Content & Marketing, Tax & Accounting, Legal & Compliances. Gigzoe is not a law firm or Chartered Accountancy firm or Company Secretary Firm and does not provide any legal services, legal advice, audit services,”lawyer or Chartered Accountant or Company secretary referral services" and do not provide or participate in any legal representation.
#
# 2.3  Sellers on Gigzoe sell their services by creating Gigs/Services and/or by sending proposals to projects posted by Potential Buyers.
#
# 2.4  We put our efficiency to verify Seller's registering on Gigzoe through a tough screening process which includes profile creation, KYC Verification, Interview and screening process and quality checks. However, we do not warranty, guarantee or represent any inability, incompetency, quality or qualifications of/for any Seller.
#
# 2.5  Sellers have full freedom and are solely responsible for determining the Services/Gigs they want to sell on Gigzoe, set prices for their services, set delivery time for their services. Sellers are solely responsible for any content they upload and/or share while creating Services/Gigs.
#
# 2.6  Gigzoe does not force any Seller to register on Gigzoe and sell his/her Services/Gigs. It is totally free for any Seller to register on Gigzoe out of their own wish. If any laws, regulations, rules and guidelines stop or prohibit any Seller from registering and selling Services/Gigs on Gigzoe, then the Seller has voluntarily violated such laws, regulations, rules and guidelines by registering on Gigzoe. Seller takes sole responsibility for violating any such laws & regulations.
#
# 2.7  Gigzoe reserves the following rights:
#
# Verify and approve Sellers to sell Services/Gigs on Gigzoe
# Verify and approve Services/Gigs created by Sellers
# Deactivate Seller Accounts
# Suspend Seller Accounts
# Deactivate Buyer Accounts
# Suspend Buyer Accounts
#
# https://www.wizcounsel.com/?referral_code=KAVAIYA10747
# 31/10/20, 7:33 am - Svnit Help: *New freelancing platform*
#
# *Gigzoe Purpose, Basic Terms, and Relationship with Users*
#
# https://www.wizcounsel.com/?referral_code=KAVAIYA10747
#
# 2.1  Gigzoe is a tech driven interactive platform for Buyers to find, hire and book services with Sellers. Buyers can discover Services/Gigs, discover Sellers based on various filters and buy any service they want. Buyers can also post their projects to request proposals from Sellers. Gigzoe does not force Buyers to book any service from any Seller.
#
# 2.2  Sellers include freelancers, firms, agencies and companies in the categories of Design, Web & Software Development, Content & Marketing, Tax & Accounting, Legal & Compliances. Gigzoe is not a law firm or Chartered Accountancy firm or Company Secretary Firm and does not provide any legal services, legal advice, audit services,”lawyer or Chartered Accountant or Company secretary referral services" and do not provide or participate in any legal representation.
#
# 2.3  Sellers on Gigzoe sell their services by creating Gigs/Services and/or by sending proposals to projects posted by Potential Buyers.
#
# 2.4  We put our efficiency to verify Seller's registering on Gigzoe through a tough screening process which includes profile creation, KYC Verification, Interview and screening process and quality checks. However, we do not warranty, guarantee or represent any inability, incompetency, quality or qualifications of/for any Seller.
#
# 2.5  Sellers have full freedom and are solely responsible for determining the Services/Gigs they want to sell on Gigzoe, set prices for their services, set delivery time for their services. Sellers are solely responsible for any content they upload and/or share while creating Services/Gigs.
#
# 2.6  Gigzoe does not force any Seller to register on Gigzoe and sell his/her Services/Gigs. It is totally free for any Seller to register on Gigzoe out of their own wish. If any laws, regulations, rules and guidelines stop or prohibit any Seller from registering and selling Services/Gigs on Gigzoe, then the Seller has voluntarily violated such laws, regulations, rules and guidelines by registering on Gigzoe. Seller takes sole responsibility for violating any such laws & regulations.
#
# 2.7  Gigzoe reserves the following rights:
#
# Verify and approve Sellers to sell Services/Gigs on Gigzoe
# Verify and approve Services/Gigs created by Sellers
# Deactivate Seller Accounts
# Suspend Seller Accounts
# Deactivate Buyer Accounts
# Suspend Buyer Accounts
#
# https://www.wizcounsel.com/?referral_code=KAVAIYA10747
# 31/10/20, 9:14 pm - CAP Amrutlal: https://zfrmz.in/FyxAec8nLQPbd7OejULx
# 06/11/20, 8:04 am - Svnit Help: <Media omitted>
# 06/11/20, 8:04 am - Svnit Help: Voila Folks!
# What's the most exciting thing all of us get from our elder ones in Diwali?
# Crackers? Wishes? Anything else?
# Nope guys..... its blessings in the form of money !!!
#
# Scosh brings amazing opportunity for you all to use your tiny little scientific
# brains and win exciting prizes for this Diwali celebration. Check prizes at the end of this message (🥳😌😎)
#
# SQUIZOSH - The Quiz Mania
# is a great platform where you can showcase your skills and put your minds in work.
# The rules and Instructions are given in the attached file:- https://drive.google.com/file/d/1s2AeNpYXjoGcOVi1nSjNg70JgrfM2c-M/view?usp=sharing
#
# So, what are you guys waiting for.... get to the bottom of this message and find out
# the exact details of the event to be conducted on 7th and 8th of November.
#
# P.S. This time we are going to have a surprise feature for all the participants which allows them to stay in the contest till the end.
#
# Stay tuned ! Stay Safe ! Stay healthy !
# And most importantly; participate.....coz we know you actually have nothing solid work to do :)
#
# Oh ya...prizes are:
# 1st - 2000
# 2nd - 1000
# 3rd - 500
# And surprise goodies....
#
# Now find the important links and things here....😎👇
# Registration Link :- https://forms.gle/xCKya56D5vyTr2H1A
#
# Date: 7th and 8th November, 2020.
# Platform:- Google meet and myquiz.org
# Timing- 4pm onwards ( for 1st round of Quiz)
# Meet link- meet.google.com/vdz-knst-cef
# 06/11/20, 8:39 pm - Svnit Help: ènli
#
# Baldevpari is an ideal guru for millions of students in Gujarat today, Times of India, Vadodara editor Sachin Sharma has put together a nice article on what students say about Baldevpari. It is a matter of joy and pride that today the number of visitors to this website has crossed 1 crore.
#
# The rare achievement of a rare person has been received at the national level as the best teacher and ICT, award, state level best teacher award and awards, honors through rich institutions, the list of which is very long. More than 250 organizations have honored him.
#
# Baldevpari attributes this achievement to himself .. | Dr. Nalinbhai Pandit, Former Director, GCERT, Dr. T. S. Joshi, Director, ad
# 06/11/20, 8:50 pm - Svnit Help: Namaskaram,
#
# *Isha Leadership Academy (ILA)* is in the process of creating education programs for supporting *Sadhguru's vision of building conscious and inclusive leaders* who can provide leadership in different spheres such as business, political and social.
#
# We are happy to share *remote volunteering opportunities for ILA curriculum development*.
#
# ILA is looking for *academicians and business professionals * who can take up various volunteering roles to support course content development on themes such as leadership, entrepreneurship, marketing, finance, economics, strategy etc.
#
# *Roles available:*
# *Subject Matter Experts:* to research and develop course content. They can have a Masters or a Ph.D. in the subject with relevant academic or industry experience
# *Technical / Platform interface experts* - to integrate course content with the LMS platform,
# *Technology Platform Selection and Deployment experts* - to do product evaluation, fitment, implementation, and vendor management
# *Media editors* - to do media research and edits,
# *Legal experts* – to handle IPRs and copyrights,
# *Project Managers* - to manage various projects
#
# *Time commitment:* Both full-time and part-time options are available.
#
# *To apply:* Please fill the form below:
#
# https://forms.gle/wLidpFXLM8jZ28ff9
#
# For more information and queries please contact:
# Narayan: 9167329389
#
# Pranams
# 07/11/20, 5:05 pm - Svnit Help: આપના જન્મ દિવસે આપ નિરોગી ,દીર્ઘાયુ  રહી  ખૂબ ખૂબ પ્રગતી કરો અને સદાય રાષ્ટ્ર અને સમાજ ને ઉપયોગી થઇ આપની કીર્તિ વધારો તેવી શુભકામના..
#
# सर्वोपद्रवनिर्मुक्त:­­­­­­ सर्वव्याधिविवर्जित : | सर्वदापूर्णहृदय: साक्षात शिवमयोभव : || शतं जीव शरद : |.........
#
#  Wish You Many Many Happy Returns Of The Day ! Happy Birthday to you..God bless you. . Wishing you a good heath and long life...
# 11/11/20, 10:57 am - Svnit Help: I recently tried CashKaro.com & highly recommend it! You get extra Cashback on top of all retailer discounts.
# Try it out: https://play.google.com/store/apps/details?id=com.cashkaro&referrer=r%3D2685571%26refname%3DKavaiya%20Yashkumar%26utm_source%3Dapp_referral
# 11/11/20, 11:05 am - CAP Amrutlal: https://bit.ly/CashkaroCash
# 11/11/20, 11:07 am - CAP Amrutlal: Norton Security Subscription offer - Purchase Norton Security Plus for 1 year worth Rs.1349 at Rs.699 only. This Antivirus Helps defend against ransomware, viruses, spyware, malware and other online threats. Utilizes one of the largest global civilian intelligence networks to spot threats faster and more features.
#
# https://bit.ly/gopaisaNORTON
# 29/11/20, 4:28 pm - Svnit Help: https://chat.whatsapp.com/KoJqB3p8w3r8l9saxbELur
# 30/11/20, 11:48 pm - Svnit Help: *Company Name :-* Chegg India Pvt. Ltd.
#
# *Company Description:* As the leading student-first connected learning platform, Cheggs Student Hub makes higher education more affordable and more accessible, all while improving student outcomes. Chegg is a publicly-held company based in Santa Clara, CA with offices in San Francisco, New York, Portland, India, Israel, Berlin, and Ukraine.
#
# For more details visit - https://experts.cheggindia.com/chegg-india-about-us/
#
# *Designation*: Subject Matter Expert (Academic Expert)
# Timing: Flexible work schedule, (Part time opportunity)
#
# *Job Description:*
# To answer questions asked by students from US
# Ensure that you follow the quality parameters
# Ensure that the guidelines of answering are strictly followed
# To ensure academic integrity
#
# *Benefits:*
# No Recruitment charges
# Earn while you learn
# International exposure
# Academic development
#
# *Compensation:* Average estimated income INR 30,000 to INR 1,00,000 +. Paid per question answered.
# Start recruitment process by clicking on http://bit.ly/37QHLVm
#
# Thanks & Regards,
# Expert Hiring Team
# Chegg India Pvt. Ltd. I www.cheggindia.com
# Expert Testimonials I Chegg Inc
# 30/11/20, 11:55 pm - CAP Amrutlal: https://bit.ly/CheggQandA
# 30/11/20, 11:55 pm - CAP Amrutlal: *Company Name :-* Chegg India Pvt. Ltd.
#
# *Company Description:* As the leading student-first connected learning platform, Cheggs Student Hub makes higher education more affordable and more accessible, all while improving student outcomes. Chegg is a publicly-held company based in Santa Clara, CA with offices in San Francisco, New York, Portland, India, Israel, Berlin, and Ukraine.
#
# For more details visit - here
#
# https://bit.ly/CheggQandA
#
# *Designation*: Subject Matter Expert (Academic Expert)
# Timing: Flexible work schedule, (Part time opportunity)
#
# *Job Description:*
# To answer questions asked by students from US
# Ensure that you follow the quality parameters
# Ensure that the guidelines of answering are strictly followed
# To ensure academic integrity
#
# *Benefits:*
# No Recruitment charges
# Earn while you learn
# International exposure
# Academic development
#
# *Compensation:* Average estimated income INR 30,000 to INR 1,00,000 +. Paid per question answered.
# Start recruitment process by clicking on
#
# https://bit.ly/CheggQandA
# 05/12/20, 7:27 pm - Svnit Help: *LIC Golden Jubilee Scholarship Scheme - સુવર્ણ જ્યુબિલી શિષ્યવૃત્તિ યોજના 2020*
#
# 2020 ના ફોર્મ ભરવાની શરૂવાત થઈ ગઈ છે
#
# તમે 10000-20000 હજાર રૂપિયા ની સ્કોલરશીપ મેળવી શકો છો.
#
# https://youtu.be/t7_ijzRUySU
#
# જરૂરીયાત હોય તેને પહોચાડવા વિનંતિ
# 07/12/20, 12:21 pm - Svnit Help: All Physics news, study material, conference news, internship, conference and jobs are one place
#
#
# Website :-
# www.myephysics.tk
#
# Facebook Group:-
# https://www.facebook.com/groups/631058463998415/
#
# WhatsApp Group:
# https://chat.whatsapp.com/Bhgkjq1GfWX7JkcyO1FTqp
#
# Instagram Page:-
# https://www.instagram.com/Myephysics/
#
# Telegram Group:-
# https://t.me/myephysics
#
# Facebook Page:-
# https://www.facebook.com/MyePhysics-100813561286456/
#
# YouTube  channel
# https://youtu.be/-7irOymPTxk
# 12/12/20, 8:42 pm - Svnit Help: Inspired Scholarship 2020 ધોરણ ૧૨ માં લાવો સારા માર્ક્સ અને મેળવો ૮૦૦૦૦ રૂપિયા https://youtu.be/W4nq1CSJX8Q
# 12/12/20, 8:43 pm - Svnit Help: *Inspired Scholarship 2020*                                                                                                                                                                              ધોરણ ૧૨ માં લાવો સારા માર્ક્સ અને મેળવો ૮૦૦૦૦ રૂપિયા                                                                                                                                          https://youtu.be/W4nq1CSJX8Q
# 15/12/20, 9:52 pm - Svnit Help: Hi there!🙋‍♂️ Congrats for making it to SVNIT, This is Shivam from Applied Mathematics (2nd Yr). Since everything has been online since March 2019 and no one knows how long its gonna be and the interaction with you people has been very least. I know you guys are missing on one of the most imp. part of your life but it is, what it is!  So cheer up!😼
#
# I believe you have many queries with all the stuff going on, be it about sports, fests, studies or other activities.
#
# Join this W-Group for the same.✌
# We"ll try to answer all of'em.
#
# https://chat.whatsapp.com/FEDZVXROM7l6lJMC8yUJPj
# 22/12/20, 11:39 am - Svnit Help: Job in AIRPORTS AUTHORITY OF INDIA || AAI Recruitment 2020 | https://www.myephysics.tk/2020/12/job-in-airports-authority-of-india-aai.html
# 22/12/20, 4:07 pm - CAP Amrutlal: શું ન હોય તો જીવન અધૂરું છે? http://bit.ly/3nLradG
# 24/12/20, 9:00 am - CAP Amrutlal: *Job in AIRPORTS AUTHORITY OF INDIA || AAI Recruitment 2020*
#
# *Pay scale*
#
# Junior Executive (E-1) :- Rs.40000-3%-140000
#
# The CTC per annum for the post of Manager CTC would be around Rs. 18 lacs (approximately) and for the post of Junior Executive it would be around Rs. 12 lacs (approximately).
#
# *Application fees*
# Application fees of Rs. 1000/- (Rupees One Thousand Only) is to be paid by the candidates. SC/ST/Female candidates have to pay only Rs. 170/- (Rupees One hundred and seventy only).
#
# *Important dates*
#
# Opening date for On-line *Applications:15.12.2020*
# *Last date for Online Application :- 14.01.2021*
#  https://www.myephysics.tk/2020/12/job-in-airports-authority-of-india-aai.html
# 24/12/20, 9:00 am - CAP Amrutlal: *Job in AIRPORTS AUTHORITY OF INDIA || AAI Recruitment 2020*
#
# *Pay scale*
#
# Junior Executive (E-1) :- Rs.40000-3%-140000
#
# The CTC per annum for the post of Manager CTC would be around Rs. 18 lacs (approximately) and for the post of Junior Executive it would be around Rs. 12 lacs (approximately).
#
# *Application fees*
# Application fees of Rs. 1000/- (Rupees One Thousand Only) is to be paid by the candidates. SC/ST/Female candidates have to pay only Rs. 170/- (Rupees One hundred and seventy only).
#
# *Important dates*
#
# Opening date for On-line *Application-15.12.2020*
# *Last date for Online Application :-14.01.2021*
#  https://www.myephysics.tk/2020/12/job-in-airports-authority-of-india-aai.html
# 26/12/20, 10:14 pm - Svnit Help: https://chat.whatsapp.com/DvLu5SsvH3u3lRgfyw6Bdr
#
#
# Only Serious Candidates Who are preparing for UPSC or Civil Services join for daily updates.
# 30/12/20, 11:11 pm - Svnit Help: I recently tried CashKaro.com & highly recommend it! You get extra Cashback on top of all retailer discounts.
# Try it out: https://play.google.com/store/apps/details?id=com.cashkaro&referrer=r%3D2685571%26refname%3DKavaiya%20Yashkumar%26utm_source%3Dapp_referral
# 04/01/21, 9:46 am - CAP Amrutlal: Course name:- Overview of Geo-processingusing Python Organized byIndian Institute of Remote Sensing
# Curriculum Overview of GIS and different geospatial data types Overview of Python programming using Raster data processing, resampling, and analysisVector data processing and analysisGeo-spatial data visualization on webFamiliarization with various open-source geospatial dataprocessing libraries e.g. GDAL, Geopandas, etc
# Course Fee There is no course fee for attending this programme
# Programme Reception Programme can be received through the e-class platform ofIIRS-ISRO using internet connectivity. No specifichardware/software required. However, it isrecommended good internet connectivity at the user end. Torun the programme in the classroom, the following hardwarewill be required: Desktop computer with web camera microphone andoutput speakers or laptop with microphone cameraand an output speaker.• Large display screen/projector/TV
# Award of Certificate
# Working Professionals and Students: Based on 70%attendance and 40% in the online examinationThere are the limited number of seats.Registration will be done on first come first serve basis
#
# Registration Link:- https://elearning.iirs.gov.in/edusatregistration/student
# Instagram Page:-
# https://www.instagram.com/Myephysics/
#
# Telegram Group:-
# https://t.me/myephysics
#
# Courses updates and other details will be available onURL – https://www.iirs.gov.in/EDUSAT-News
# 04/01/21, 9:48 am - CAP Amrutlal: <Media omitted>
# 04/01/21, 9:48 am - CAP Amrutlal: <Media omitted>
# 04/01/21, 9:50 am - CAP Amrutlal: *Course name:- Overview of Geo-processingusing Python Organized byIndian Institute of Remote Sensing*
#
# Curriculum
# Overview of GIS and different geospatial data types
# Overview of Python programming using Raster data processing, resampling, and analysisVector data processing and analysis
# Geo-spatial data visualization on webFamiliarization with various open-source geospatial dataprocessing libraries e.g. GDAL, Geopandas, etc
#
# *Course Fee*
# There is no course fee for attending this programme
#
# *Programme Reception*
# Programme can be received through the e-class platform ofIIRS-ISRO using internet connectivity.
#
# No specific hardware/software required. However, it isrecommended good internet connectivity at the user end.
# To run the programme in the classroom, the following hardwarewill be required:
# Desktop computer with web camera microphone andoutput speakers or laptop with microphone cameraand an output speaker.•
# Large display screen/projector/TV
#
# *Award of Certificate*
# Working Professionals and Students: Based on 70%attendance and 40% in the online examination
#
# There are the limited number of seats.Registration will be done on first come first serve basis
#
# *Registration* Link:- https://elearning.iirs.gov.in/edusatregistration/student
#
# for more updates follow our
# *Instagram Page:-*
# https://www.instagram.com/Myephysics/
#
# *Telegram Group:-*
# https://t.me/myephysics
#
# Courses updates and other details will be available on URL – https://www.iirs.gov.in/EDUSAT-News
# 04/01/21, 9:51 am - CAP Amrutlal: <Media omitted>
# 12/01/21, 3:16 pm - CAP Amrutlal: https://amzn.to/39pon3R
# 12/01/21, 3:16 pm - CAP Amrutlal: <Media omitted>
# 13/01/21, 12:27 pm - Svnit Help: https://chat.whatsapp.com/BYHh0E8hTNx5DAVYxjzHBZ
# 13/01/21, 12:41 pm - CAP Amrutlal: <Media omitted>
# 13/01/21, 12:59 pm - CAP Amrutlal: https://sites.google.com/view/myephysics/aai-atc-2021
# 14/01/21, 1:53 pm - Svnit Help: https://inr.deals/tU3pq
# 24/01/21, 8:58 am - Svnit Help: https://quizizz.com/join?gc=315385
# 29/01/21, 10:30 pm - Svnit Help: Hey! Here's my gift to you. Use my referral code and get 10% off any purchase on Testbook. https://play.google.com/store/apps/details?id=com.testbook.tbapp&referrer=testbook_id%3D0WX9Y1  OR code 0WX9Y1
# 31/01/21, 5:32 pm - Svnit Help: <Media omitted>
# 31/01/21, 5:32 pm - Svnit Help: <Media omitted>
# 31/01/21, 5:32 pm - Svnit Help: Dear All,
#
# Department of Physics, SVNIT Surat is going to organize Virtual One Week STTP on Scientific Tools for Theoretical Science (STTS-2021) during 22-26 February 2021. We delightfully welcome all the researchers and developers to share their experiences and ideas through research talks and presentations from diverse fields in emerging theoretical Science. This event offers a platform in bringing together a forum for students, postdocs, and established scientists to exchange their ideas and contributing an integrative approach to theoretical science and experiment.
# Topics
# Astrophysics & Space Science
# Molecular Dynamics & Monte Carlo Simulation
# Ionosphere Science
# Materials Science
# Computational Nano-electronics
# Designing Device for Energy Application
# Condensed Matter Physics
# Density functional Theory
# Registration Form Link:  https://forms.gle/zhtWioWPs3yWkRLd9
#
# Please circulate our STTP Brochure in your circle.
#
# Please let me know if you require any further information.
#
# Thanking you,
#
# With regards,
# Yogesh
# 03/02/21, 9:11 am - Svnit Help: https://forms.gle/7JWiuhkm8Vp8fd8f9
# 03/02/21, 9:12 am - Svnit Help: We are interested in hiring students as Content Developer Experts for Full Time Internship roles from your NIT, Surat. Students who have studied 10th or 12th in Hindi Medium and are currently in B.tech, BPharm, B.Sc etc can qualify for this role.
#
# Location: We are looking for work from home.
#
# Stipend: 20,000 p.m.
#
# Duration : 2 months
# 03/02/21, 9:13 am - Svnit Help: We are interested in hiring students as Content Developer Experts for Full Time Internship roles from your NIT, Surat. Students who have studied 10th or 12th in Hindi Medium and are currently in B.tech, M.Tech,B.Pharm, B.Sc, M.Sc etc can qualify for this role.
#
# JOB TITLE :-  Content Developer Expert (Full Time Internship)
# ...
# 4. તમારા બિઝનેસ નો કેટેલોગ બનાવો
# 5. તમારા બિઝનેસ ની એડ બનાવો.
#
# MY DIGITAL GURU
# https://mydigisolution.blogspot.com/
#
# આ બધું જ કામ કરવો નજીવા દરે
# પ્રથમ ફ્રી સર્વિસ માટે ડાયલ કરો
#
# Yash Kavaiya
# Tata Consultancy Service
# Morbi , Gujarat
#
# https://mydigisolution.blogspot.com/
# 9265745362
# 01/11/21, 3:17 pm - CAP Amrutlal: નમસ્કાર મોરબી વાસીઓ,
#
# તમારો બિઝનેસ લઈ જાવ ઓનલાઇન.
# 1. વેબસાઈટ બનાવો
# 2.તમારા બિઝનેસ માટે પોસ્ટર બનાવો
# 3.તમારા બિઝનેસ ને ગૂગલ મેપ પર લાવો
# 4. તમારા બિઝનેસ નો કેટેલોગ બનાવો
# 5. તમારા બિઝનેસ ની એડ બનાવો.
# 6. ઓનલઇન બિઝનેસ કાર્ડ બનાવો
#
# MY DIGITAL GURU
# https://mydigisolution.blogspot.com/
#
# આ બધું જ કામ કરવો નજીવા દરે
# પ્રથમ ફ્રી સર્વિસ માટે ડાયલ કરો
#
# Yash Kavaiya
# Tata Consultancy Service
# Morbi , Gujarat
#
# https://mydigisolution.blogspot.com/
#
# 9265745362
# 01/11/21, 3:18 pm - Svnit Help: https://wa.me/917567775671
# 01/11/21, 3:18 pm - Svnit Help: https://wa.me/919978849742
# 08/11/21, 12:53 pm - Svnit Help: <Media omitted>
# 08/11/21, 2:35 pm - Svnit Help: The Ultimate List Of Sites With Free Stock Photos
#
# https://visualhunt.com/
# https://unsplash.com/
# https://www.pexels.com/
# https://pixabay.com/
# http://www.freeimages.com/
# http://images.superfamous.com/
# https://picjumbo.com/
# http://imcreator.com/free
# http://gratisography.com/
# https://morguefile.com/
# http://littlevisuals.co/
# http://nos.twnsnd.co/
# http://getrefe.com/
# http://jaymantri.com/
# http://publicdomainarchive.com/
# http://magdeleine.co/
# http://libreshot.com/
# http://kaboompics.com/
# http://photos.bucketlistly.com/
# http://travelcoffeebook.com/
# https://foodiesfeed.com/
# http://cupcake.nilssonlee.se/
# http://moveast.me/
# http://stokpic.com/
# https://www.splitshire.com/
# http://snapwiresnaps.tumblr.com/
# https://stocksnap.io/
# 09/11/21, 9:13 am - CAP Amrutlal: <Media omitted>
# 09/11/21, 9:13 am - CAP Amrutlal: <Media omitted>
# 09/11/21, 9:14 am - CAP Amrutlal: <Media omitted>
# 09/11/21, 9:27 am - CAP Amrutlal: <Media omitted>
# 09/11/21, 9:27 am - CAP Amrutlal: <Media omitted>
# 09/11/21, 10:02 am - CAP Amrutlal: https://zignaly.com/app/signup/?invite=6189f877bfd12
#
#
# 🔥 Zignaly crypto Loot
#
# Link 👉 https://zignaly.com/app/signup/?invite=6189f877bfd12
#
# 👉 Register using email only no need of mobile number 😁
#
# 👉 Get 10$ (₹700 approx.) on signup
# 👉 Also share your link to get 10$
#
# Note : Signup and refer bonus instant add nahi hoga 24hrs lagenge update hone mai.
# 10/11/21, 7:52 pm - Svnit Help: <Media omitted>
# 11/11/21, 4:01 pm - Svnit Help: https://wa.me/919624730004
# 11/11/21, 6:35 pm - Svnit Help: Hi! I use CoinDCX app to invest in Bitcoin. Use my invite link to download the app & get ₹100 Free Ethereum when you make your first investment - https://join.coindcx.com/invite/zHdR
#
#  5 Million+ Indians use CoinDCX for their cryptocurrency investments. It's safe, secure and BitGo Insured.
# 17/11/21, 8:30 am - Svnit Help: 478301823637
# 17/11/21, 5:39 pm - Svnit Help: https://www.huobi.ge/en-in/topic/double-reward/?invite_code=9wih3223&t=1637150865412
#
# 🔥 Huobi Pro Rs.800 LOOT
#
# Huobi Pro me New Account Banao
#
# Link :- https://www.huobi.ge/en-in/topic/double-reward/?invite_code=9wih3223&t=1637150865412
#
# Mail ID aur Password de kar Account Bana Lo
#
# Phir App Download karke Usme Log in Karlo ( App Link :-- https://play.google.com/store/apps/details?id=pro.huobi )
#
# KYC Complete karlo PAN, ADHAAR & SELFIE de kar ( 2 Minutes me ho jayega )
#
# Koi bhi Exchange jaise CoinDcx, WazirX se XRP Token apne Huobi Account me Deposit Karo... ( Minimum 20XRP aur Maximum 100 XRP kar sakte ho )
#
# Deposit Complete hone ke Baad Aaplog Market Option me Jao & *USDT/HUSD* pair me Trade karo
#
# Marker Order Place karo & Total $2000 ka Trading Volume honq Chahiye ( Matlab agar $20 Deposit kiya to 100 baar & $100 Deposit kiya to 20 baar Trade karo )
#
# Trading Volume jab $2000 ka Complete ho jata hai... to aapko 40 DOGECOIN mil jayega... Usko Redeem Karlo
#
# Phir Dogecoin ko XRP me Change karke Withdrawal Karlo
# 17/11/21, 5:42 pm - CAP Amrutlal: <Media omitted>
# 17/11/21, 5:42 pm - CAP Amrutlal: <Media omitted>
# 17/11/21, 5:42 pm - CAP Amrutlal: <Media omitted>
# 17/11/21, 5:42 pm - CAP Amrutlal: <Media omitted>
# 17/11/21, 9:53 pm - Svnit Help: https://brainly.in/question/13404041
# 18/11/21, 12:14 pm - Svnit Help: https://wa.me/+919013151515
# 19/11/21, 5:22 pm - Svnit Help: <Media omitted>
# 19/11/21, 5:25 pm - CAP Amrutlal: <Media omitted>
# 19/11/21, 5:25 pm - CAP Amrutlal: <Media omitted>
# 19/11/21, 5:27 pm - CAP Amrutlal: <Media omitted>
# 19/11/21, 5:28 pm - CAP Amrutlal: <Media omitted>
# 19/11/21, 5:28 pm - CAP Amrutlal: <Media omitted>
# 19/11/21, 5:30 pm - CAP Amrutlal: <Media omitted>
# 19/11/21, 5:30 pm - CAP Amrutlal: <Media omitted>
# 19/11/21, 5:32 pm - CAP Amrutlal: <Media omitted>
# 19/11/21, 5:32 pm - CAP Amrutlal: <Media omitted>
# 19/11/21, 5:33 pm - CAP Amrutlal: <Media omitted>
# 19/11/21, 5:33 pm - CAP Amrutlal: <Media omitted>
# 19/11/21, 5:42 pm - Svnit Help: <Media omitted>
# 19/11/21, 5:44 pm - Svnit Help: <Media omitted>
# 19/11/21, 5:46 pm - Svnit Help: <Media omitted>
# 19/11/21, 5:47 pm - Svnit Help: <Media omitted>
# 19/11/21, 5:57 pm - Svnit Help: <Media omitted>
# 19/11/21, 10:06 pm - Svnit Help: https://brainly.in/question/37858044
# 22/11/21, 11:47 am - Svnit Help: https://www.careerride.com/view/sample-letter-to-a-hotel-for-booking-cancellation-11450.aspx
# 22/11/21, 11:51 am - Svnit Help: Dear __________________,
# This is with reference to my booking [number xyz] with your [hotel/restaurant] on [some date]. I'm sorry to inform you that I won't be able to make it due to [some reason], hence I would like to cancel my booking. I apologize for any inconvenience resulting from this decision, but I have no other choice considering the circumstances.
# I kindly ask you to acknowledge the receiving of my request and to confirm the cancellation of my booking. I really hope to make it some other time should the opportunity arise.
# Sincerely,
# 22/11/21, 11:52 am - Svnit Help: I appreciate a response from you acknowledging and confirming my request.
# I apologize for the inconvenience and I hope that I can make next time.
# 22/11/21, 12:07 pm - CAP Amrutlal: Dear Manager,
# My name is Yash Kavaiya, and my booking id no is 785695865 with your Moyo rooms on 15th May 2021. I apologize to inform you that I won't make it due to a personal emergency with one of my senior associates. Hence I would like to cancel my hotel booking. I apologize for any inconvenience resulting from my decision. Please accept my apologies for any inconvenience caused by my choices. Considering the circumstances, I don't have any other options. I humbly request that you acknowledge receipt of my request and confirm the cancellation of my hotel reservation. I hope to make it some additional time should the opportunity arise.
#
# I would appreciate it if you could acknowledge and confirm my request.
# 26/11/21, 3:21 pm - Svnit Help: <Media omitted>
# 26/11/21, 4:01 pm - Svnit Help: Resolution: Dear Associate, As per teams conversation, You are not allocated to any project sso getting the attached error, so try to raise the request after you allocation, As per your confirmation resolving the ticket.
# 26/11/21, 4:02 pm - Svnit Help: Ticket Description: Download O-365-Outlook in TCS LAPTOP Ticket Resolution: Dear user, Currently your holding F1 license with this license you cannot install Outlook in your machine please raise GPS request and get the license upgraded to E1+ Intune license Or E3 license to access Also for all Microsoft products your license needs to be upgraded.
# 27/11/21, 7:41 pm - Svnit Help: Https://wa.me/917005501314
# 27/11/21, 7:42 pm - Svnit Help: https://wa.me/+917005501314
# 29/11/21, 9:51 am - CAP Amrutlal: My GPS has been unlocked
# 29/11/21, 9:55 am - CAP Amrutlal: But I have a doubt.
#
# Microsoft E3 upgradation  will charge some amount.
#
# Whether I proceed or not??
# 29/11/21, 9:56 am - CAP Amrutlal: <Media omitted>
# 30/11/21, 8:30 am - Svnit Help: We have teams to attend meeting.
#
# And we use mail in web/mobile.
# 30/11/21, 8:32 am - Svnit Help: Kindly, initiate project training
# 30/11/21, 4:04 pm - CAP Amrutlal: https://chat.whatsapp.com/KnP0t4Cfq9b6Y4U94pGjsP
# 30/11/21, 9:04 pm - Svnit Help: https://youtu.be/QajSCF7MLFk yecheck kro
#
#  7 out of 22 in BARC
#
# Physics by A Singh sir
# 30/11/21, 9:30 pm - CAP Amrutlal: https://www.urbanpro.com/r/4341241
# 01/12/21, 2:45 pm - CAP Amrutlal: https://chat.whatsapp.com/F7fEavTJpCg6OANww0II3W
# 03/12/21, 4:52 pm - CAP Amrutlal: <Media omitted>
# 03/12/21, 4:52 pm - CAP Amrutlal: <Media omitted>
# 05/12/21, 8:27 pm - CAP Amrutlal: Https://wa.me/919875051514
# 06/12/21, 9:15 am - Svnit Help: 1/12/84
# 06/12/21, 9:15 am - Svnit Help: 10 to 11
# 06/12/21, 9:15 am - Svnit Help: Motabhela
# 07/12/21, 8:56 am - Svnit Help: *GET BASICS OF FINANCIAL MARKETS Course By ElearnMarket For Free | Worth ₹4720*
#
# COURSE HIGHLIGHTS
#
# 33 Videos
#
# 2+ Hours of Content
#
# 3 Supplementary Study Materials
#
# Chapter-wise tests
#
# Full-Length Test
#
# INTRODUCTION
#
# It is important that you should have a clear understanding of the type of instrument and the market before making any investment decision. This course will help you to do just that.
#
# Beginners Finance is a perfectly designed course which aims to enable the participants to gain comprehensive knowledge on the basics of the financial market in general and the stock market in particular. This programme will simplify different financial jargons like IPO, Currencies, Mutual Funds, etc. It will help the learners to gain knowledge on the procedure for opening Demat Account, the process of stock trading, risk management system, regulatory framework etc. They will also know about the impact of corporate actions in the stock market.
#
# If you are new to the stock market and want to know the basics, then this programme is perfect for you!
#
# OBJECTIVE
#
# This programme will enable the participants to:
#
# Learn the basics of Financial Market in general and the stock market in particular.
#
# Gain knowledge on Primary Market Instruments like IPO and the workings of the Secondary Market and the role of different market participants.
#
# Understand the concept of Stock Market Index and its calculation
#
# Know the basics of Currency, Fixed Income Securities and Mutual Funds
#
# Master the concept of Time Value of Money
#
# Interpret the impact of different corporate actions on the stock market
#
# Understand the procedure for opening Demat Account
#
# Learn about the trade life cycle, the process of trading, risk management, contract notes, etc.
#
# Gain knowledge on the Regulatory Framework, Regulators and the Investors redress mechanisms in the Indian Capital market.
#
# BENEFITS
#
# Students enrolling for this course will be able to measure their knowledge level by appearing for tests designed after each session to check and ensure the level of their understanding.
#
# An email query support, Question& Answer Community platform can also be availed by the learners for any kind of doubt clearance related to content while pursuing this beginners course.
#
# The course contains IPO case studies which will help the students to understand in a better manner by providing practical know-how to analyze the Capital market.
#
# After successful completion of the course, the students will get a Certificate of Completion
#
# TOPICS COVERED
#
# Basics of Financial Markets:
#
# An introduction to basics of Financial Markets
#
# Various market participants and their roles
#
# Time Value of Money
#
# Primary and Secondary Markets:
#
# Primary Markets and their concepts
#
# SecondaryMarkets and Stock Market Indicators
#
# Currency and Fixed Income:
#
# Currency Market
#
# Fixed Income Instruments
#
# Mutual Funds:
#
# Concept and Role of a Mutual Fund
#
# Fund Structure and Constituents
#
# Mutaul Fund Products
#
# Corporate Actions -Meaning and their Calculations:
#
# An introduction to Corproate Actions
#
# Dividend
#
# Bonus
#
# Rights Issue
#
# Stock Spilt
#
# Buyback
#
# Financial Market Operations:
#
# Client Registration for Trading and Demat Account
#
# Trade Life Cycle
#
# Investor Grievance and Arbitration
#
# Financial Market Regulations:
#
# Regulators
#
# Regulatory Framework
#
# Basic Financial Market course worth Rs 4720 Totally FREE
#
# Coupon Code: *AFF100*
# Get Certificate after completion
# Courses Link mentioned below
# In English -
# https://www.elearnmarkets.com/courses/display/basics-of-financial-markets?
#
# In Hindi - click here
#
# https://www.elearnmarkets.com/courses/display/beginners-finance-in-hindi?
# 14/12/21, 2:06 pm - Svnit Help: SC-900: Microsoft Security, Compliance, and Identity Fundamentals
#
#
# Get free microsoft voucher for exam after session
#
# enroll now
#
# https://pages.cloudthat.com/microsoft-get-secured-get-certified/sc-900/
#
#
# master link : https://www.microsoft.com/en-in/campaign/MS-IndiaSkillingInitiative/SecuritySkilling.aspx#Cybersecurity
# 14/12/21, 2:06 pm - Svnit Help: Name: Tutspoint all the PDF
#
# Size: 1.43GB
# Files: 605
#
# https://helpothers4.freehotspot.workers.dev/0:/Tutspoint/
# 14/12/21, 2:06 pm - Svnit Help: https://drive.google.com/folderview?id=1aKfhDCuRT0OaCOWsQRgy6Dvm0y7yHNDz
# 15/12/21, 12:48 pm - CAP Amrutlal: https://www.notesbureau.com/2021/08/python-pandas-fresco-play-hands-on.html
# 15/12/21, 12:48 pm - CAP Amrutlal: https://www.tejatechview.com/2021/03/fresco-play-python-pandas-hands-on.html
# 15/12/21, 2:19 pm - CAP Amrutlal: https://colab.research.google.com/github/DharmendraDevaraj/FrescoPlay-Matplotlib-Handson/blob/master/FrescoPlay%20%20Data%20Visualisation%20with%20Matplotlib%20HANDSON.ipynb#scrollTo=0sa1oxDfO1P5
# 18/12/21, 10:24 pm - CAP Amrutlal: https://chat.whatsapp.com/HeOSCYT6WKMFa9RxhG1Awr
# 25/12/21, 11:08 pm - Svnit Help: All Physics news, study material, conference news, internship, conference and jobs are one place
#
#
# Website :-
# www.myephysics.tk
#
# Facebook Group:-
# https://www.facebook.com/groups/631058463998415/
#
# WhatsApp Group:
# https://chat.whatsapp.com/Bhgkjq1GfWX7JkcyO1FTqp
#
# Instagram Page:-
# https://www.instagram.com/Myephysics/
#
# Telegram Group:-
# https://t.me/myephysics
#
# Facebook Page:-
# https://www.facebook.com/MyePhysics-100813561286456/
#
# YouTube  channel
# https://youtu.be/-7irOymPTxk
# 27/12/21, 11:51 am - Svnit Help: NDA Exam 2022
#
# https://www.upsconline.nic.in
# Last Date:- 11-02-2021
# 27/12/21, 12:06 pm - Svnit Help: NDA Exam 2022
#
# ધોરણ 12 પછી NDA માં જવા માંગતા વિદ્યાર્થી ઓ માટે
#
# NDA 2022 ના ફોર્મ ભરવાની શરૂ થઈ ગયા છે
#
# આવનારી NDA ની પરિક્ષામાં Girls પણ ફોર્મ ભરી શકે છે.
#
# NDA વિશે સામાન્ય માહિતી માટે નીચેની લિંક પર ક્લીક કરો
# https://gsebsciencestream.blogspot.com/2021/06/nda-exam-information-in-gujarati-nda.html?m=1
#
#
#
# NDA na પાછલા વર્ષ ના પેપર ડાઉનલોડ કરવા માટે નીચેની લિંક ઓપન કરો
# https://gsebsciencestream.blogspot.com/2021/06/nda-exam-information-in-gujarati-nda.html?m=1
#
#
# NDA પરિક્ષા નો સિલેબસ અને તૈયારી કેવી રીતે કરવી તેના માટેનો વિડીયો
#
# આ NDA પરિક્ષા ની વય મર્યાદા 19.5 વર્ષ છે.
#
# ફોર્મ ભરવા અહી કલિક કરો
# https://www.upsconline.nic.in/mainmenu2.php
# 27/12/21, 12:17 pm - Svnit Help: *👨🏻‍✈️NDA Exam 2022🧑🏻‍✈️*
#
# ધોરણ 12 પછી NDA માં જવા માંગતા વિદ્યાર્થીઓ માટે
#
# NDA 2022 ના ફોર્મ ભરવાની શરૂ થઈ ગયા છે
#
# આવનારી NDA ની પરિક્ષામાં Girls🧑🏻‍✈️ પણ ફોર્મ ભરી શકે છે.
#
# *NDA વિશે સામાન્ય માહિતી માટે નીચેની લિંક પર ક્લીક કરો*
# 👇🏻👇🏻👇🏻👇🏻
# *બ્લોગ*
# https://bit.ly/nda2022
#
# *Video*
# https://youtu.be/kDO6goSyrb0
#
# *NDA ના પાછલા વર્ષ ના પેપર ડાઉનલોડ કરવા માટે નીચેની લિંક ઓપન કરો*
#
# https://bit.ly/nda2022
#
# *_NDA પરિક્ષા નો સિલેબસ અને તૈયારી કેવી રીતે કરવી તેના માટેનો વિડીયો_*
# 👇🏻👇🏻👇🏻👇🏻
# https://youtu.be/I0CKvCNhR5s?t=132
#
# આ NDA પરિક્ષા ની વય મર્યાદા *19.5 વર્ષ* છે.
#
# ફોર્મ ભરવા અહી કલિક કરો
#
# https://www.upsconline.nic.in/mainmenu2.php
# 05/01/22, 11:22 pm - Svnit Help: https://wa.me/9013151515
# 05/01/22, 11:24 pm - CAP Amrutlal: https://wa.me/919013151515
# 08/01/22, 11:10 pm - Svnit Help: https://drive.google.com/file/d/1f9UKh7qoYNrg1opztr-n9Pme9Ic5AIri/view
# 29/01/22, 11:21 am - CAP Amrutlal: <Media omitted>
# 29/01/22, 11:21 am - CAP Amrutlal: <Media omitted>
# 29/01/22, 11:21 am - CAP Amrutlal: <Media omitted>
# 29/01/22, 11:21 am - CAP Amrutlal: <Media omitted>
# 30/01/22, 11:24 pm - CAP Amrutlal: Vi Care.vcf (file attached)
# 10/02/22, 3:16 pm - CAP Amrutlal: This message was deleted
# 20/02/22, 1:37 pm - Svnit Help: https://wa.me/27810993444
# 02/03/22, 3:15 pm - CAP Amrutlal: <Media omitted>

# %%
type(data)
# Out:
# str

# %%
pattern = '\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s-\s'

# %%
message=re.split(pattern,data)[1:]
len(message)
# Out:
# 0

# %%
dates=re.findall(pattern,data)
dates
# Out:
# []

# %%
df=pd.DataFrame({'user_message':messages,'message_date':dates})
df['message_date']=pd.to_datetime(df['message_date'],format='%d %m %Y, %H:%M - ')
df=rename(columns={'message_date':'date'},inplace=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_35/345661865.py in <module>
#       1 df=pd.DataFrame({'user_message':messages,'message_date':dates})
#       2 df['message_date']=pd.to_datetime(df['message_date'],format='%d %m %Y, %H:%M - ')
# ----> 3 df=rename(columns={'message_date':'date'},inplace=True)
#       4 df.head()
#
# NameError: name 'rename' is not defined

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_35/1472378890.py in <module>
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
users=[]
messages=[]
for message in df['user_message']:
    entry=re.split('([\w\W]+?):\s',message)
    if entry[1:]:
        users.append(entry[1])
        messages.append(entry[2])
    else:
        users.append('group_notification')
        messages.append(entry[0])
        
df['user']=users
df['message']=messages
df.drop(columns=['user_message'],inplace=True)

df.head()
# Out:
# Empty DataFrame
# Columns: [message_date, user, message]
# Index: []

# %%
df['year']=df['date'].dt.year
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /opt/conda/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/conda/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_35/2063528821.py in <module>
# ----> 1 df['year']=df['date'].dt.year
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'date'

# %%
df['month']=df['data'].dt.month_name()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /opt/conda/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/conda/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'data'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_35/4113914792.py in <module>
# ----> 1 df['month']=df['data'].dt.month_name()
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'data'

# %%
df['Day']=df['date'].dt.day
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /opt/conda/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/conda/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_35/3537561206.py in <module>
# ----> 1 df['Day']=df['date'].dt.day
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'date'

# %%
df['hour']=df['date'].dt.hour
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /opt/conda/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/conda/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_35/292484319.py in <module>
# ----> 1 df['hour']=df['date'].dt.hour
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'date'

# %%
df['minute']=df['date'].dt.minute
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /opt/conda/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/conda/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_35/4155288051.py in <module>
# ----> 1 df['minute']=df['date'].dt.minute
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'date'
