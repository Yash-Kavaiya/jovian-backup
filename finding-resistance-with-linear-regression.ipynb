# %% [markdown]
# # finding-resistance-with-linear-regression
#
# Use the "Run" button to execute the code.

# %%
# !pip install jovian --upgrade --quiet

# %%
import jovian

# %%
# Execute this to save new versions of the notebook
jovian.commit(project="finding-resistance-with-linear-regression")

# %% [markdown]
# # Title :-   Finding Resistance with Linear Regression
# Resistors play a crucial role in electronics and circuits for their use in controlling electrical current. They are simply a small device that limits the flow of current throughout a circuit, or in other words, impedes the flow of current through resistance. Hence, the term resistor comes to mind when describing this type of electronic device.
#
# A resistor takes advantage of the fact that it follows what we call Ohm's Law where a resistor placed under a potential V is proportional to current I and overall resistivity value of a resistor. To be more exact, Ohm's law writes
#
# #### Downloading the Data
# The dataset contains 51 rows and 2 columns. Each column of the dataset contains information about current and voltage.

# %% [markdown]
# where voltage is related to both current and resistor values. This means that under a given potential V and current I, we can determine the total resistivity of a resistor at any place in a circuit. The units for resistance is in terms of Ohms(), or otherwise
#
# Now, suppose that we have an unknown resistor. To determine the value of a resistor we must rst provide a voltage across it along with a known value of current. The equipment that we use would include a power supply source that
# does this for us. Once a power output is provided, we can measure the resistor by determining the value of current with a given voltage output. After measuring values for voltage output and current, we should expect a linear model as an
# expectation for understanding the value of a resistor.

# %% [markdown]
# Ohms = \frac{Volts}{Amperes}

# %% [markdown]
# For this lab we will writing a Python script that models the value of a resistor given a set of data values performed on a laboratory environment. The datavalues provided however come with some noise with in the data that can obscure
# the actual value of the resistor. To x this problem we must employ the use of statistics to determine an approximate value for our resistor of interest. In statistics, the use of Linear Regression gives us the line of best fit in
# addition to finding our margin of error given a set of data. This type of analysis allows us to not only predict corresponding values for prediction, but also gives us a close approximation for the value of a resistor, R. Furthermore, the use of linear regression starts by understanding the line of best fit,  $$y = a + bx$$
#
# where just like a linear function, has an intercept a and slope b associated.Specific to our problem now, is that resistance can be modeled with a linear function
#
# $$ V = a + RI$$

# %% [markdown]
# where in a laboratory setting, our independent variable of interest is the current I given as an output from a power source. In turn, the dependent variable in our expression is the output voltage as we vary the current. The slope, R, becomes our variable of interest. By approximating this value through linear regression given a data set should allow us to model any resistor given a set of data values.
# The value of slope in a linear regression model can be expressed through
# means of statistical derivations, but the expression we are interested in is

# %% [markdown]
# and because the expression for Ohm's law V = IR implies no intercept, we can assume that the intercept is a = 0. This should help with solving one variable of interest, which should be the slope. Moreover, the data points are expressed as ($X_i$; $Y_i$) while the average can be expressed as

# %% [markdown]
# ### Instructions

# %% [markdown]
# 1. Given the expression for slope of a linear regression, we can first assume that the resistance is given by the set of data points ($X_i$; $Y_i$) where n represents the length of an array.

# %% [markdown]
# 2. Start a Python script that takes in the import library and load dataset

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.loadtxt("resistance_data.txt")
x  =  data [ :,0]# separate  data  into  x  values
y  =  data [ :,1 ]# separate  data  into  y  values
n  =len( x )# take n to  be  length  of  array  x

# %%
print(x)
# Out:
# [ 0.   0.2  0.4  0.6  0.8  1.   1.2  1.4  1.6  1.8  2.   2.2  2.4  2.6
#   2.8  3.   3.2  3.4  3.6  3.8  4.   4.2  4.4  4.6  4.8  5.   5.2  5.4
#   5.6  5.8  6.   6.2  6.4  6.6  6.8  7.   7.2  7.4  7.6  7.8  8.   8.2
#   8.4  8.6  8.8  9.   9.2  9.4  9.6  9.8 10. ]

# %%
print(y)
# Out:
# [ 26.461  10.002  22.681  45.613  44.013   5.341  38.251  25.73   30.452
#   42.159  42.161  65.814  59.416  53.825  62.658  65.005  86.411  64.923
#   76.696  63.189  41.705  93.804 100.967  80.868 130.046  78.185 104.686
#  105.192 134.992 138.04  122.324 129.672 114.683 102.288 130.781 142.345
#  162.454 166.036 146.19  151.465 144.272 142.7   142.406 201.262 168.355
#  173.429 165.208 199.662 167.792 192.809 186.568]

# %% [markdown]
# 3. The x and y values produced are an array of numbers specific to x and y. We must then attempt to build a function that takes on those data values, computes the averages, and performs multiplication. So then, we follow through. But first, lets define the summation of an array before trying to build the function.

# %% [markdown]
# # Purpose:-  Finding Resistance with Linear Regression

# %%
def sumfunc(array):
    sum=
    |<−−−−−define the summation here using a for loop
    return array sum

# %%
def R(x,y,n ):
    """|<−the numerator of the function R here|<−the denominator of the function R here """
    
    return <numerator of R>/<denominator of R>

# %%
plt.figure(figsize=(12,6))
plt.xlabel("Current (A)")
plt.ylabel("Voltage (V)")
plt.title("Current -Voltage Plot")
plt.scatter(x,y); #plots  scatter  plot  of  data  provided
#plt.plot(I,V(I),color="k") #plots  linear  function V(I) defined above
#plt.text(7,10,r '$V=$I∗%0.3f'% R(x,y,n),fontsize =15)

# %%
from numpy import arange
from pandas import read_csv
from scipy.optimize import curve_fit
from matplotlib import pyplot
 
# define the true objective function
def objective(x, a, b):
	return a * x + b

# load the dataset
data = np.loadtxt("resistance_data.txt")
x  =  data [ :,0]# separate  data  into  x  values
y  =  data [ :,1 ]# separate  data  into  y  values
n  =len( x )
    
# curve fit
resi, _ = curve_fit(objective, x, y)
# summarize the parameter values
a, b = resi
print('y = %.5f * x + %.5f' % (a, b))
# plot input vs output
pyplot.scatter(x, y)
# define a sequence of inputs between the smallest and largest known inputs
x_line = arange(min(x), max(x), 1)
# calculate the output for the range
y_line = objective(x_line, a, b)
# create a line plot for the mapping function
pyplot.plot(x_line, y_line, '--', color='red')
pyplot.show()
# Out:
# y = 17.78821 * x + 12.86262
# <ipython-input-6-f0ab0e1e20d0>:31: RuntimeWarning: divide by zero encountered in true_divide
#   return np.sqrt(np.mean(np.square((y_line/x_line) - (y/x))))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-f0ab0e1e20d0> in <module>
#      30 def rmse(x_line,y_line,x,y):
#      31     return np.sqrt(np.mean(np.square((y_line/x_line) - (y/x))))
# ---> 32 print(rmse(x_line,y_line,x,y))
#
# <ipython-input-6-f0ab0e1e20d0> in rmse(x_line, y_line, x, y)
#      29 pyplot.show()
#      30 def rmse(x_line,y_line,x,y):
# ---> 31     return np.sqrt(np.mean(np.square((y_line/x_line) - (y/x))))
#      32 print(rmse(x_line,y_line,x,y))
#
# ValueError: operands could not be broadcast together with shapes (10,) (51,)

# %% [markdown]
# 4. Now that we have computed the value of our resistance, we have completed our job at minimum, for the day. However, modeling this requires some more thought. Lets then build out linear function V = IR.

# %% [markdown]
# # Data and analysis

# %% [markdown]
# # Discussion

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "yash-kavaiya/finding-resistance-with-linear-regression" on https://jovian.ai
# [jovian] Committed successfully! https://jovian.ai/yash-kavaiya/finding-resistance-with-linear-regression
# 'https://jovian.ai/yash-kavaiya/finding-resistance-with-linear-regression'

# %%
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import matplotlib

data = np.loadtxt("resistance_data.txt")
x  =  data [ :,0]# separate  data  into  x  values
y  =  data [ :,1 ]# separate  data  into  y  values
n  =len( x )

denominator = x.dot(x) - x.mean() * x.sum() 
a = ( x.dot(y) - y.mean()*x.sum() ) / denominator 
b = ( y.mean() * x.dot(x) - x.mean() * x.dot(y) ) / denominator
Yhat = a*x + b

matplotlib.rcParams['font.size'] = 24
sns.set_style("darkgrid")
plt.figure(figsize=(16,8) )
plt.xlabel("Current(A)")
plt.ylabel("Voltage (V)" )
plt.title ("Current−Voltage Plot")

plt.scatter(x, y)
plt.plot(x, Yhat, ls='--', c='r')
plt.show()

d1 = y - Yhat
d2 = y - y.mean()
accuracy= (1-r2)*100
r2 = d1.dot(d1) / d2.dot(d2)
print("Error in our linear regression:- ",r2*100," %")
print("Accurity of linear regression:- ",accuracy ,"%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-48b2b158f65a> in <module>
#      27 d1 = y - Yhat
#      28 d2 = y - y.mean()
# ---> 29 accuracy= (1-r2)*100
#      30 r2 = d1.dot(d1) / d2.dot(d2)
#      31 print("Error in our linear regression:- ",r2*100," %")
#
# NameError: name 'r2' is not defined
