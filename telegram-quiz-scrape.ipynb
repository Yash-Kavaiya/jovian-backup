# %%
import json

# Opening JSON file
f = open('result.json')

# returns JSON object as
# a dictionary
data = json.load(f)

# Iterating through the json
print(data)

# Closing file
f.close()

dict2=data['messages']
print(len(dict2))
q=[]
o1=[]
o2=[]
o3=[]
o4=[]
for i in range(0,200):
    print(dict2[i]['poll']["question"][7:])
    q.append(dict2[i]['poll']["question"][7:])
    
    print((dict2[i]['poll']["answers"][0]["text"]))
    
    o1.append(dict2[i]['poll']["answers"][0]["text"])
    
    if (len(dict2[i]['poll']["answers"]))>1:
        o2.append(dict2[i]['poll']["answers"][1]["text"])
    else:
        o2.append("-")
    
    if len(dict2[i]['poll']["answers"])>2:
        o3.append(dict2[i]['poll']["answers"][2]["text"])
    else:
        o3.append("-")
        
    if len(dict2[i]['poll']["answers"])>3:   
        o4.append(dict2[i]['poll']["answers"][3]["text"])
    else:
        o4.append("-")
    
print(len(q),len(o1),len(o2),len(o3),len(o4))
import pandas as pd

# dictionary of lists 
dict8 = {'Question': q, 'option1': o1,'option2': o2,'option3': o3,'option4': o4 } 
    
df = pd.DataFrame(dict8)
print(df)
df.to_csv('ગુજરાતી વ્યાકરણો.tsv', sep="\t")
# Out:
# {'name': 'Quiz Bot', 'type': 'bot_chat', 'id': 983000232, 'messages': [{'id': 1971, 'type': 'message', 'date': '2022-08-30T15:37:38', 'date_unixtime': '1661854058', 'from': 'Quiz Bot', 'from_id': 'user983000232', 'poll': {'question': '[1/101] ગ્રીસના લોકો સિંધુ નદીને શું કહેતા હતા.?', 'closed': True, 'total_voters': 0, 'answers': [{'text': 'ગંગેય', 'voters': 0, 'chosen': False}, {'text': 'ઇન્ડસ', 'voters': 0, 'chosen': False}, {'text': 'હીંડોસ', 'voters': 0, 'chosen': False}, {'text': 'ઇન્ડીયા', 'voters': 0, 'chosen': False}, {'text': 'E', 'voters': 0, 'chosen': False}]}, 'text': ''}, {'id': 1972, 'type': 'message', 'date': '2022-08-30T15:37:55', 'date_unixtime': '1661854075', 'from': 'Quiz Bot', 'from_id': 'user983000232', 'poll': {'question': '[2/101] આઠમી સદીમાં મધ્યભાગમાં બંગાળમાં ક્યા વંશનું શાસન હતું?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'ચંદેલ વંશનું', 'voters': 0, 'chosen': False}, {'text': 'ચંદેલ વંશનું', 'voters': 1, 'chosen': True}, {'text': 'પાલ વંશનું', 'voters': 0, 'chosen': False}, {'text': 'પ્રતિહરોનું', 'voters': 0, 'chosen': False}, {'text': 'E', 'voters': 0, 'chosen': False}]}, 'text': ''}, {'id': 1973, 'type': 'message', 'date': '2022-08-30T15:38:05', 'date_unixtime': '1661854085', 'from': 'Quiz Bot', 'from_id': 'user983000232', 'poll': {'question': '[3/101] ડચ લોકો ક્યા દેશના વતની હતા.?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'નોર્વે', 'voters': 0, 'chosen': False}, {'text': 'ડેનમાર્ક', 'voters': 1, 'chosen': True}, {'text': 'સ્વીડન', 'voters': 0, 'chosen': False}, {'text': 'હોલેન્ડ', 'voters': 0, 'chosen': False}, {'text': 'E', 'voters': 0, 'chosen': False}]}, 'text': ''}, {'id': 1974, 'type': 'message', 'date': '2022-08-30T15:38:12', 'date_unixtime': '1661854092', 'from': 'Quiz Bot', 'from_id': 'user983000232', 'poll': {'question': '[4/101] રાજા રામમોહનરાયે બ્રહ્મોસમાજ ની સ્થાપના કયારે કરી હતી.?', 'closed': True, 'total_voters': 1, 'answers': [{'text': '1828', 'voters': 1, 'chosen': True}, {'text': '1831', 'voters': 0, 'chosen': False}, {'text': '1821', 'voters': 0, 'chosen': False}, {'text': '1938', 'voters': 0, 'chosen': False}, {'text': 'E', 'voters': 0, 'chosen': False}]}, 'text': ''}, {'id': 1975, 'type': 'message', 'date': '2022-08-30T15:38:18', 'date_unixtime': '1661854098', 'from': 'Quiz Bot', 'from_id': 'user983000232', 'poll': {'question': '[5/101] ભારતમાં પ્રથમ ગવર્નર જનરલ તરીકે કોણ આવ્યો હતો.?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'વોરેન હેસ્ટીંગ', 'voters': 1, 'chosen': True}, {'text': 'વેલેસ્લી', 'voters': 0, 'chosen': False}, {'text': 'ડેલહાઉસી', 'voters': 0, 'chosen': False}, {'text': 'બેંટિક', 'voters': 0, 'chosen': False}, {'text': 'E', 'voters': 0, 'chosen': False}]}, 'text': ''}, {'id': 1976, 'type': 'message', 'date': '2022-08-30T15:38:23', 'date_unixtime': '1661854103', 'from': 'Quiz Bot', 'from_id': 'user983000232', 'poll': {'question': '[6/101] કૌટિલ્ય અર્થશાસ્ત્ર ક્યા વંશની માહિતી પૂરી પાડે છે?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'મોર્યવંશ', 'voters': 1, 'chosen': True}, {'text': 'ગુપ્ત વંશ', 'voters': 0, 'chosen': False}, {'text': 'નંદ વંશ', 'voters': 0, 'chosen': False}, {'text': 'સાતવાહન વંશ', 'voters': 0, 'chosen': False}, {'text': 'E', 'voters': 0, 'chosen': False}]}, 'text': ''}, {'id': 1977, 'type': 'message', 'date': '2022-08-30T15:38:31', 'date_unixtime': '1661854111', 'from': 'Quiz Bot', 'from_id': 'user983000232', 'poll': {'question': '[7/101] ગૌતમ બુદ્ધ નું ગૃહ ત્યાગ ની ઘટના ક્યા નામથી ઓળખાય છે.?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'મહાપરી નિર્વાણ', 'voters': 0, 'chosen': False}, {'text': 'સંબોધી', 'voters': 0, 'chosen': False}, {'text': 'ધર્મચક્ર પ્રવતન', 'voters': 0, 'chosen': False}, {'text': 'મહાભીનિષ્ક્રમણ', 'voters': 1, 'chosen': True}, {'text': 'E', 'voters': 0, 'chosen': False}]}, 'text': ''}, {'id': 1978, 'type': 'message', 'date': '2022-08-30T15:38:39', 'date_unixtime': '1661854119', 'from': 'Quiz Bot', 'from_id': 'user983000232', 'poll': {'question': '[8/1 ...
# 100
#  ગ્રીસના લોકો સિંધુ નદીને શું કહેતા હતા.?
# ગંગેય
#  આઠમી સદીમાં મધ્યભાગમાં બંગાળમાં ક્યા વંશનું શાસન હતું?
# ચંદેલ વંશનું
#  ડચ લોકો ક્યા દેશના વતની હતા.?
# નોર્વે
#  રાજા રામમોહનરાયે બ્રહ્મોસમાજ ની સ્થાપના કયારે કરી હતી.?
# 1828
#  ભારતમાં પ્રથમ ગવર્નર જનરલ તરીકે કોણ આવ્યો હતો.?
# વોરેન હેસ્ટીંગ
#  કૌટિલ્ય અર્થશાસ્ત્ર ક્યા વંશની માહિતી પૂરી પાડે છે?
# મોર્યવંશ
#  ગૌતમ બુદ્ધ નું ગૃહ ત્યાગ ની ઘટના ક્યા નામથી ઓળખાય છે.?
# મહાપરી નિર્વાણ
#  પ્રાચીન નગરી તક્ષશિલા નું ખોદકામ કોણે કર્યું હતું?
# ડો.વોગેસ
#  અલંકાર ઓળખવો : ખારવા મોગરાના ફૂલ
# વર્ણાનુંપ્રસ્
# ] સમાસ ઓળખવો : યથાભક્તિ
# તત્પુરુશ
# ] શિખરિણી છંદમાં ગણ ક્યો છે?
# જ ય જ સ ય લ ગા
# ] નિપાત ઓળખવો : નાસ્તામાં તળેલી વાનગી જ હોય ફળ હોય જ ના શકે ?
# જ
# ] સંધિ જોડો : હેતુ + અભાસ
# હેત્વાભાસ
# ] રેખાંકિત વિશેષણ નો પ્રકાર જણાવો..
# ધોરીયાની કૂણી લીલી ધ્રો ઉપર દેહ ઢાળીને બેઠો.
# કર્તુવાચક
# ] " વાયુની ઘનતા તેના આણું વજનથી અડધી હોય છે " વાયુ સંચાર નો નિયમ જણાવો.
# બોઇલનો નિયમ
# ] ક્યા વિકારના કારણે વૃદ્ધાવસ્થામાં મનુષ્યને કાનમાં બહેરાશ થતી હોય છે ?
# કિસ્ટલાયન
# ] દીવાસળી બનાવવા માટે ક્યો પદાર્થ ઉપયોગ થાય છે.?
# લાલ ફોસ્ફરસ
# ] ..............ને ઈન્ટરનેટ ના પિતા તરીકે ઓળખવામાં આવે છે?
# ચાર્લ્સ બેબેજ
# ] અવાજના એનેલોગ સ્વરૂપને ..........તરીકે ઓળખવામાં આવે છે?
# સાઉન્ડ
# ] પેજની ચારે બાજુથી મૂકવામાં આવતી જગ્યાને .....કહે છે?
# Header
# ] ગુજરાત નો પ્રમાણિક ઇતિહાસ ક્યારથી શરૂ થાય છે?
# ગુપ્ત કાળથી
# ] હડપ્પીય સભ્યતાનું સ્થળ દેશલપર કઈ નદીના કિનારે આવેલું છે?
# સરસ્વતી
# ] સિંધુ લિપિમાં લખાયેલ  10 અક્ષરોવાળું સાઈનબોર્ડ kyathialu આવ્યું છે ?
# લોથલ
# ] નીચેનામાંથી કયા રાજા દ્વારા સુદર્શન તળાવ માંથી ખેતી ની સિંચાઈ માટે નહેરો કઢાવાઈ હતી?
# ચંદ્રગુપ્ત મૌર્ય
# ] રાણકીવાવ ક્યા પ્રકારની વાવ છે?
# જ્યાં
# ] દેરાણી જેઠાણીના ગોખ ક્યા સ્થાપત્ય માં આવેલા છે?
# દેલવાડા ના દેરા
# ] નીચેનામાંથી કયા સ્થળનો યુનેસ્કોની વિશ્વ વિરાસત સ્થળની યાદીમાં સમાવેશ કરાયો છે?
# એલિફંટાની ગુફાઓ
# ] પ્રસિદ્ધ શિવની ત્રિમૂર્તિ નું શિલ્પ નીચેનામાંથી કઈ ગુફામાં આવેલું છે?
# ઇલોરાની ગુફાઓ
# ] ' મંજુશા ' લોક ચિત્રકલા ક્યા રાજ્યમાં જોવા મળે છે.?
# ઉત્તરપ્રદેશ
# ] કર્કવૃત્ત નીચેનામાંથી કયા રાજ્યમાંથી પસાર થતું નથી?
# ઉત્તરપ્રદેશ
# ] શેત્રફળ ની દ્વષ્ટિએ ભારત વિશ્વમાં ક્યા ક્રમે છે?
# 5
# ] મેકમોહન રેખા ક્યા બે દેશો વચ્ચે છે?
# ભારત અને ચીન
# ] બોમ્બે નેચરલ સોસાયટી દ્વારા જાહેર થયેલ કાજ નાનવડા આદ્રભૂમી ક્યા જિલ્લામાં આવેલ છે ?
# જૂનાગઢ
# ] બેડી લાખાની મેડી સ્તૂપ કયા જિલ્લામાં આવેલ છે ?
# જુનાગઢ
# ] સોન કંસારી ના ડેરા નામનું પ્રાચીન સ્થાપત્ય ક્યા જિલ્લામાં છે.?
# સાબરકાંઠા
# ] ખોટી જોડણી શોધો
# હરિણી
# ] કહેવત નો અર્થ જણાવો : કપાળમાં ઉગે વાળ તો ભાલ માં ઉગે ઝાડ
# સાવ ઉજ્જડ જ્યાં  ઝાડ પાન જોવા ન મળે
# ] શબ્દસમૂહ માટે એક શબ્દ આપો : ઉનાળાની સખત ગરમ હવા
# લું
# ] સાચો વિરોધી શબ્દ ઓળખવો
# પૂર્વ : પશ્ચિમ
# ] નીચે આપેલ વિકલ્પોમાંથી ક્યો શબ્દ સમાનાર્થી નથી?
# કારમુ : ભયંકર
# ] રૂઢિપ્રયોગ નો અર્થ શોધો : મો પડી જવું
# શરમિંદુ થવું
# ] ICC / ઇન્ટરનેશનલ ક્રિકેટ કાઉન્સિલ ની સ્થાપના કયા વર્ષે થઈ હતી.?
# 1908
# ] તરણના ક્યા ખેલાડીને સૌપ્રથમ અર્જુન એવોર્ડ મળ્યો હતો?
# વીર ધવલખડે
# ] નહેરુ ટ્રોફી કઈ રમત સાથે સંકળાયેલ છે?
# બેડમિન્ટન
# ] જો 26 જાન્યુઆરી ,2005 ના રોજ સોમવાર હોય, તો 26 જાન્યુઆરી 2006 ના રોજ ક્યો વાર હોય?
# રવિવાર
# ] X,U,S,P,N,K,I........
# M
# ] જો AT=20 તથા BAT=40 હોય તો DOG=.........
# 80
# ] નીચેનામાંથી કયા રાજયમાં વડાપ્રધાન મોદીના નામે માર્ગ બન્યો.?
# સિક્કમ
# ] નીચેનામાંથી કયો દેશ તાજેતરમાં NBD  ( ન્યુ ડેવલપમેન્ટ બેંક ) નો સદસ્ય બન્યો ?
# નાઇજીરીયા
# ] SPMRM ( શ્યામા પ્રસાદ મુખર્જી રૂબરુંન મિશન )ને લાગુ કરવામાં ક્યું રાજ્ય ટોચ પર રહ્યું છે ?
# ગુજરાત
# ] મધ્યયુગ નું છેલ્લું લખાણ .......માં જોવા માંગો છે
# બાલાવબોધ
# ] નીચેનામાંથી કઈ વિગત અસત્ય છે ?
# સોનેટ ના પિતા બ. ક.ઠાકોર ગણાય છે
# ] 👆👆👆👆👆
# A-1,B-2,C-3,D-4
# ] નીચેનામાંથી કોણ બાળ સાહિત્યકાર નથી?
# પુષ્પા અંતાણી
# ] નીચેનામાંથી કઈ જોડ ખોટી છે?
# સ્નેહરશ્મિ - હાઇકુ
# ] ગુજરાતી સાહિત્ય માં લઘુકથા ના જનક તરીકે..... નુ નામ જાણીતું છે
# ઈજ્જત કુમાર ત્રિવેદી
# ] કલિકાલસર્વજ્ઞ તરીકે ક્યા સર્જક ઓળખાઈ છે?
# અખો
# ] અસાઈત ઠાકોરનો સૌથી જૂનામાં જૂનો વેશ ક્યો છે.?
# જસમા ઓડણ
# ] નીચેનામાંથી કયો વિકલ્પ સાચો છે?
# 2 એ સૌથી નાની વિષમ સંખ્યા છે
# ] જો 1400 ના X %=119 hoy તો x=....
# 17
# ] Fill in the gap.
# Flowers : Bud : : Plant : _________
# Seed
# ] Put proper question tag. Little water is in the bowl ______?
# isn’t it
# ] Join sentences with infinitive :
# He wants to earn his livelihood. He works hard for that reason.
# He wants to work hard to earn his livelihood.
# ] Fill in the blank: ‘Crime and Punishment’ is one of ______.
# good novel of the world.
# ] Allow your elders to know your activities at school. (Use ‘Let’)
# Let your elders know your activities at school.
# ] Find the correct spelling
# perseverance
# ] Fill in the blank:
# The king, with his ministers, _______ to be present.
# are
# ] Proper form of verbs: _______ you ever _______ our C.M.?
# Did ...... meet
# ] નીચે પૈકી કોણે તમિલ ભાષામાં ' રામાયણ ' ની રચના કરી હતી ?
# કવિ પોન્ના
# ] ઈલોરાની ગુફાઓના સંદર્ભમાં સાચું વિધાન પસંદ કરો.
# બૌદ્ધ ધર્મને લગતી ગુફાઓ ૧ થી ૧૨ નંબરની છે.
# ] નીચે પૈકી કયો વેદ ગદ્ય અને પદ્ય એમ બંનેમાં લખાયેલ છે ?
# સામવેદ
# ] જિલ્લા આયોજન સમિતિના અધ્યક્ષ કોણ હોય છે ?
# જિલ્લા વિકાસ અધિકારી
# ] ગુજરાતમાં વીસ મુદ્દાનો કાર્યક્રમ ક્યારથી અમલમાં છે ?
# 1/4/1987
# ] જિલ્લા પ્રમુખ કઈ સમિતિના અધ્યક્ષપદ પર રહી શકતા નથી ?
# સામાજિક ન્યાય સમિતિ
# ] તાલુકા પંચાયતમાં કારોબારી સમિતિમાં વધુમાં વધુ સભ્યસંખ્યા કેટલી હોય છે ?
# 7
# ] જિલ્લા પંચાયતની પ્રથમ બેઠકની તારીખ કોણ નક્કી કરે છે ?
# જિલ્લા વિકાસ અધિકારી
# ] તાલુકા પંચાયત અને જિલ્લા પંચાયતની બેઠકો સામાન્ય રીતે કેટલા સમયે મળવી જોઈએ ?
# બે માસ
# ] સરપંચ ઉપસરપંચની ચૂંટણીમાં મત ...........
# આપી શકે
# ] તાલુકા પ્રમુખ અને ઉપપ્રમુખના હોદ્દાની મુદત કેટલી હોય છે ?
# પાંચ વર્ષ
# ] ભારતમાં જાહેર વહીવટી અંગેનું શિક્ષણ સૌપ્રથમ કયા વિશ્વવિદ્યાલયમાં શરૂ કરવામાં આવ્યું હતું ?
# જવાહરલાલ નહેરુ વિશ્વવિદ્યાલય
# ] નોકરશાહી માટે વપરાતો શબ્દ ' બ્યુરોક્રેસી ' શબ્દ કઈ ભાષામાંથી આવેલ છે ?
# કોરિયન
# ] ભારતમાં જિલ્લા કલેકટરની સ્થાપના કોના દ્વારા કરવામાં આવી હતી ?
# રિપન
# ] ' પ્રશાસન એ એક એવું વિશાળ ક્ષેત્ર છે કે પ્રશાસનની ફિલસૂફી એ લગભગ જીવનની ફિલસૂફી બની જાય છે ' - આ વિધાન કોનું છે ?
# વુડ્રો વિલ્સન
# ] સનદી સેવાઓને ' એક કાયમી, વૈજ્ઞાનિક અને કૌશલ્યસભર અધિકારીઓની વ્યાવસાયિક સંસ્થા ' તરીકે કોણે વ્યાખ્યાયિત કરી છે ?
# હરમન ફીમર
# ] નીચે પૈકી કયા વર્ષો દરમિયાન સૌપ્રથમવાર સરકાર અને ‌જાહેર ક્ષેત્રના એકમો વચ્ચે મેમોરેન્ડમ ઓફ અન્ડરસ્ટેન્ડિંગ (MOU) ની પદ્ધતિ દાખલ કરવામાં આવી ?
# 1986-87
# ] ગુજરાત ખાતે આવેલ આઈ.એ.એસ.ટ્રેઈનિંગ સેન્ટરનું નામ જણાવો.
# આદિત્ય બિરલા આઈ.એ.એસ.ટ્રેઈનિંગ સેન્ટર
# ] ગુજરાતમાં કઈ યુનિવર્સિટીમાં સૌપ્રથમ જાહેર વહીવટનું અધ્યાપન શરૂ કરવામાં આવ્યું હતું ?
# ગુજરાત યુનિવર્સિટી
# ] 1948 ના ધર આયોગનું ગઠન શા માટે થયું હતું ?
# રાજ્યોના વર્ગીકરણના અભ્યાસ‌ માટે
# ] નીચેનામાંથી કયો કેસ ન્યાયતંત્રમાં નિયુક્તિ માટેની કોલેજીયમ સિસ્ટમ વિશે છે ?
# કેશવાનંદ ભારતી કેસ
# ] વ્યવસ્થાપનમાં કામદારોની ભાગીદારીને બંધારણમાં શેમાં સમાવવામાં આવ્યું છે ?
# આમુખ
# ] નીચેનામાંથી કયું વિધાન સાચું છે ?
# 44 મા બંધારણીય સુધારા દ્વારા વડાપ્રધાનની ચૂંટણીને ન્યાયિક સમીક્ષાથી બાકાત રાખવામાં આવી
# ] સંયુક્ત બેઠકમાંથી વિધેયક .............. પસાર કરવું પડે.
# હાજર અને મતદાન કરનાર સભ્યોની સામાન્ય બહુમતીથી
# ] નીચેનામાંથી કઈ બાબત સર્વોચ્ચ અદાલત અને વડી અદાલત એમ બંનેના સત્તાક્ષેત્રમાં આવે ?
# રાજ્ય અને રાજ્ય વચ્ચેનો વિવાદ
# ] નીચેનામાંથી કઈ સમિતિ મૂળભૂત ફરજો સાથે સંકળાયેલ છે ?
# જેવીપી સમિતિ
# ] 1 લી મે,ગુજરાત સ્થાપના દિવસની ઉજવણી આ વર્ષે ક્યાં કરવામાં આવી ?
# કચ્છ
# ] તાજેતરમાં વેક્યુમ આધારિત સીવર સિસ્ટમ લગાવવાવાળું દેશનું પ્રથમ શહેર કયું બન્યું ?
# આગ્રા
# ] તાજેતરમાં કઈ જગ્યાએથી ગ્રામીણ વિકાસ અને પંચાયતી રાજ મંત્રી ગિરિરાજ સિંહે "આઝાદીથી અંત્યોદય સુધી" અભિયાનનો આરંભ કર્યો ?
# નવી દિલ્હી
# ] તાજેતરમાં કઈ જગ્યાએ "સેમિકોન કોન્ફરન્સ - 2022" નું ઉદ્દઘાટન કરવામાં આવ્યું ?
# તિરુવંથપુરમ
# ] હાલના નીતિ આયોગ નાં CEO કોણ છે
# રાજીવ કુમાર
# 1] હાલના ટ્વીટર નાં સીઇઓ કોણ છે
# પરાગ અગ્રવાલ
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_38/2747046635.py in <module>
#      22 o4=[]
#      23 for i in range(0,200):
# ---> 24     print(dict2[i]['poll']["question"][7:])
#      25     q.append(dict2[i]['poll']["question"][7:])
#      26
#
# IndexError: list index out of range

# %% [markdown]
# # gset
#
# Use the "Run" button to execute the code.

# %%
# !pip install jovian --upgrade --quiet

# %%
import jovian

# %%
# Execute this to save new versions of the notebook
jovian.commit(project="gset")
# Out:
# [jovian] Updating notebook "yash-kavaiya/gset" on https://jovian.ai
# [jovian] Committed successfully! https://jovian.ai/yash-kavaiya/gset
# 'https://jovian.ai/yash-kavaiya/gset'

# %%
import json

# Opening JSON file
f = open('result.json')

# returns JSON object as
# a dictionary
data = json.load(f)

# Iterating through the json
print(data)

# Closing file
f.close()
# Out:
# {'name': 'Quiz Bot', 'type': 'bot_chat', 'id': 983000232, 'messages': [{'id': 2560, 'type': 'message', 'date': '2022-08-30T17:28:44', 'date_unixtime': '1661860724', 'from': 'Quiz Bot', 'from_id': 'user983000232', 'poll': {'question': '[1/101] કવિ રમેશ પારેખનો જન્મ ક્યાં થયો હતો?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'અમરેલી', 'voters': 0, 'chosen': False}, {'text': 'બોટાદ', 'voters': 0, 'chosen': False}, {'text': 'ભાવનગર', 'voters': 1, 'chosen': True}, {'text': 'સુરત', 'voters': 0, 'chosen': False}]}, 'text': ''}, {'id': 2561, 'type': 'message', 'date': '2022-08-30T17:29:02', 'date_unixtime': '1661860742', 'from': 'Quiz Bot', 'from_id': 'user983000232', 'poll': {'question': '[2/101] અમરતકાકી – કઈ કૃતિનું પાત્ર છે?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'જનમટીપ', 'voters': 0, 'chosen': False}, {'text': 'લોહીની સગાઈ', 'voters': 0, 'chosen': False}, {'text': 'શરણાઈના સૂર', 'voters': 1, 'chosen': True}, {'text': 'જુમો ભિસ્તી', 'voters': 0, 'chosen': False}]}, 'text': ''}, {'id': 2562, 'type': 'message', 'date': '2022-08-30T17:29:05', 'date_unixtime': '1661860745', 'from': 'Quiz Bot', 'from_id': 'user983000232', 'poll': {'question': '[3/101] ગોપાળબાપા’ પ્રકરણ કઈ નવલકથામાંથી લેવામાં આવ્યું છે?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'દીપ નિર્વાણ', 'voters': 0, 'chosen': False}, {'text': 'સોક્રેટીસ', 'voters': 0, 'chosen': False}, {'text': 'ઝેર તો પીધા છે જાણી જાણી', 'voters': 1, 'chosen': True}, {'text': 'કુરુક્ષેત્ર', 'voters': 0, 'chosen': False}]}, 'text': ''}, {'id': 2563, 'type': 'message', 'date': '2022-08-30T17:29:10', 'date_unixtime': '1661860750', 'from': 'Quiz Bot', 'from_id': 'user983000232', 'poll': {'question': '[4/101] નીચેનામાંથી ખોટી સંધિ જણાવો.', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'કવીશ્વર = કવિ + ઈશ્વર', 'voters': 0, 'chosen': False}, {'text': 'પૂર્વોક્ત = પૂર્વ + ઊક્ત', 'voters': 1, 'chosen': True}, {'text': 'ઉપેન્દ્ર = ઉપ + ઈન્દ્ર', 'voters': 0, 'chosen': False}, {'text': 'રવીન્દ્ર = રવિ + ઈન્દ્ર', 'voters': 0, 'chosen': False}]}, 'text': ''}, {'id': 2564, 'type': 'message', 'date': '2022-08-30T17:29:13', 'date_unixtime': '1661860753', 'from': 'Quiz Bot', 'from_id': 'user983000232', 'poll': {'question': '[5/101] એક સમાંતર શ્રેણીનું પ્રથમ પદ 5 અને છેલ્લું પદ 45 છે અને બધા પદોનો સરવાળો 500 હોય તો પદોની સંખ્યા કેટલી હશે?', 'closed': True, 'total_voters': 1, 'answers': [{'text': '19', 'voters': 0, 'chosen': False}, {'text': '22', 'voters': 0, 'chosen': False}, {'text': '21', 'voters': 1, 'chosen': True}, {'text': '20', 'voters': 0, 'chosen': False}]}, 'text': ''}, {'id': 2565, 'type': 'message', 'date': '2022-08-30T17:29:16', 'date_unixtime': '1661860756', 'from': 'Quiz Bot', 'from_id': 'user983000232', 'poll': {'question': '[6/101] વેપારી પોતાના માલ પર 20% અને 10% એમ બે ક્રમિક વળતર આપે છે. પરિણામી વળતર કેટલું થાય?', 'closed': True, 'total_voters': 1, 'answers': [{'text': '30', 'voters': 0, 'chosen': False}, {'text': '22', 'voters': 1, 'chosen': True}, {'text': '28', 'voters': 0, 'chosen': False}, {'text': '20', 'voters': 0, 'chosen': False}]}, 'text': ''}, {'id': 2566, 'type': 'message', 'date': '2022-08-30T17:29:18', 'date_unixtime': '1661860758', 'from': 'Quiz Bot', 'from_id': 'user983000232', 'poll': {'question': '[7/101] રાહીનું સ્થાન વર્ગમાં ઉપરથી 16મું અને નીચેથી 24મું છે, તો વર્ગમાં કુલ કેટલા વિદ્યાર્થીઓ હશે?', 'closed': True, 'total_voters': 1, 'answers': [{'text': '41', 'voters': 0, 'chosen': False}, {'text': '39', 'voters': 0, 'chosen': False}, {'text': '40', 'voters': 1, 'chosen': True}, {'text': '38', 'voters': 0, 'chosen': False}]}, 'text': ''}, {'id': 2567, 'type': 'message', 'date': '2022-08-30T17:29:21', 'date_unixtime': '1661860761', 'from': 'Quiz Bot', 'from_id': 'user983000232', 'poll': {'question': '[8/101] શ્રેણી -6, ૩, 0નો સામાન્ય તફાવત _____ છે.', 'closed': True, 'total_voters': 1, 'answers': [{'text': '3', 'voters': 0, 'chosen': False}, {'text': '-3', 'voters': 0, 'chosen': False}, {'text': '-9', 'voters': 1, 'chose ...

# %%
data['messages']
# Out:
# [{'id': 2560,
#   'type': 'message',
#   'date': '2022-08-30T17:28:44',
#   'date_unixtime': '1661860724',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[1/101] કવિ રમેશ પારેખનો જન્મ ક્યાં થયો હતો?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'અમરેલી', 'voters': 0, 'chosen': False},
#     {'text': 'બોટાદ', 'voters': 0, 'chosen': False},
#     {'text': 'ભાવનગર', 'voters': 1, 'chosen': True},
#     {'text': 'સુરત', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2561,
#   'type': 'message',
#   'date': '2022-08-30T17:29:02',
#   'date_unixtime': '1661860742',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[2/101] અમરતકાકી – કઈ કૃતિનું પાત્ર છે?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'જનમટીપ', 'voters': 0, 'chosen': False},
#     {'text': 'લોહીની સગાઈ', 'voters': 0, 'chosen': False},
#     {'text': 'શરણાઈના સૂર', 'voters': 1, 'chosen': True},
#     {'text': 'જુમો ભિસ્તી', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2562,
#   'type': 'message',
#   'date': '2022-08-30T17:29:05',
#   'date_unixtime': '1661860745',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[3/101] ગોપાળબાપા’ પ્રકરણ કઈ નવલકથામાંથી લેવામાં આવ્યું છે?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'દીપ નિર્વાણ', 'voters': 0, 'chosen': False},
#     {'text': 'સોક્રેટીસ', 'voters': 0, 'chosen': False},
#     {'text': 'ઝેર તો પીધા છે જાણી જાણી', 'voters': 1, 'chosen': True},
#     {'text': 'કુરુક્ષેત્ર', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2563,
#   'type': 'message',
#   'date': '2022-08-30T17:29:10',
#   'date_unixtime': '1661860750',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[4/101] નીચેનામાંથી ખોટી સંધિ જણાવો.',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'કવીશ્વર = કવિ + ઈશ્વર', 'voters': 0, 'chosen': False},
#     {'text': 'પૂર્વોક્ત = પૂર્વ + ઊક્ત', 'voters': 1, 'chosen': True},
#     {'text': 'ઉપેન્દ્ર = ઉપ + ઈન્દ્ર', 'voters': 0, 'chosen': False},
#     {'text': 'રવીન્દ્ર = રવિ + ઈન્દ્ર', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2564,
#   'type': 'message',
#   'date': '2022-08-30T17:29:13',
#   'date_unixtime': '1661860753',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[5/101] એક સમાંતર શ્રેણીનું પ્રથમ પદ 5 અને છેલ્લું પદ 45 છે અને બધા પદોનો સરવાળો 500 હોય તો પદોની સંખ્યા કેટલી હશે?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': '19', 'voters': 0, 'chosen': False},
#     {'text': '22', 'voters': 0, 'chosen': False},
#     {'text': '21', 'voters': 1, 'chosen': True},
#     {'text': '20', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2565,
#   'type': 'message',
#   'date': '2022-08-30T17:29:16',
#   'date_unixtime': '1661860756',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[6/101] વેપારી પોતાના માલ પર 20% અને 10% એમ બે ક્રમિક વળતર આપે છે. પરિણામી વળતર કેટલું થાય?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': '30', 'voters': 0, 'chosen': False},
#     {'text': '22', 'voters': 1, 'chosen': True},
#     {'text': '28', 'voters': 0, 'chosen': False},
#     {'text': '20', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2566,
#   'type': 'message',
#   'date': '2022-08-30T17:29:18',
#   'date_unixtime': '1661860758',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[7/101] રાહીનું સ્થાન વર્ગમાં ઉપરથી 16મું અને નીચેથી 24મું છે, તો વર્ગમાં કુલ કેટલા વિદ્યાર્થીઓ હશે?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': '41', 'voters': 0, 'chosen': False},
#     {'text': '39', 'voters': 0, 'chosen': False},
#     {'text': '40', 'voters': 1, 'chosen': True},
#     {'text': '38', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2567,
#   'type': 'message',
#   'date': '2022-08-30T17:29:21',
#   'date_unixtime': '1661860761',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[8/101] શ્રેણી -6, ૩, 0નો સામાન્ય તફાવત _____ છે.',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': '3', 'voters': 0, 'chosen': False},
#     {'text': '-3', 'voters': 0, 'chosen': False},
#     {'text': '-9', 'voters': 1, 'chosen': True},
#     {'text': '9', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2568,
#   'type': 'message',
#   'date': '2022-08-30T17:29:23',
#   'date_unixtime': '1661860763',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[9/101] 14 કારીગરોનો 10 દિવસનો પગાર 22,400 રૂ. છે તો 16 કારીગરોનો 16 દિવસનો પગાર કેટલો થાય?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': '20480', 'voters': 0, 'chosen': False},
#     {'text': '4096', 'voters': 1, 'chosen': True},
#     {'text': '25600', 'voters': 0, 'chosen': False},
#     {'text': '40960', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2569,
#   'type': 'message',
#   'date': '2022-08-30T17:29:26',
#   'date_unixtime': '1661860766',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[10/101] નીચેનામાંથી કયો શબ્દ તત્પુરુષ સમાસ નથી?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'દેશપ્રેમ', 'voters': 0, 'chosen': False},
#     {'text': 'વનવાસ', 'voters': 0, 'chosen': False},
#     {'text': 'પાપપુણ્ય', 'voters': 1, 'chosen': True},
#     {'text': 'સ્નેહાધિન', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2571,
#   'type': 'message',
#   'date': '2022-08-30T17:29:28',
#   'date_unixtime': '1661860768',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[11/101] સાંઢ નાથ્યો’ પ્રકરણ કઈ નવલકથામાંથી લેવામાં આવ્યું છે',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'ભવસાગર', 'voters': 0, 'chosen': False},
#     {'text': 'જનમટીપ', 'voters': 0, 'chosen': False},
#     {'text': 'મારી હૈયા સગડી', 'voters': 1, 'chosen': True},
#     {'text': 'દીપ નિર્માણ', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2572,
#   'type': 'message',
#   'date': '2022-08-30T17:29:31',
#   'date_unixtime': '1661860771',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[12/101] નીચેનામાંથી કયો શબ્દ કર્મધારય સમાસ છે?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'પૃથ્વી', 'voters': 1, 'chosen': True},
#     {'text': 'મનહર', 'voters': 0, 'chosen': False},
#     {'text': 'પિતાંબર', 'voters': 0, 'chosen': False},
#     {'text': 'ખાધું-પીધું', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2573,
#   'type': 'message',
#   'date': '2022-08-30T17:29:37',
#   'date_unixtime': '1661860777',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[13/101] ભારતના બંધારણના નીચેના પૈકી ક્યા અનુચ્છેદો સંઘ અને રાજ્યો વચ્ચેના વહીવટી સબંધો બાબતના છે?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'અનુ. 245 – 255', 'voters': 0, 'chosen': False},
#     {'text': 'અનુ. 233 – 245', 'voters': 1, 'chosen': True},
#     {'text': 'અનુ. 256 – 263', 'voters': 0, 'chosen': False},
#     {'text': 'અનુ. 269 – 279', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2574,
#   'type': 'message',
#   'date': '2022-08-30T17:29:40',
#   'date_unixtime': '1661860780',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[14/101] ભારતની રાષ્ટ્રપતિની ચૂંટણીમાંદરેક સંસદ સભ્યના મતનું મૂલ્ય કેટલું છે?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': '708', 'voters': 0, 'chosen': False},
#     {'text': '504', 'voters': 0, 'chosen': False},
#     {'text': '706', 'voters': 1, 'chosen': True},
#     {'text': '302', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2575,
#   'type': 'message',
#   'date': '2022-08-30T17:29:43',
#   'date_unixtime': '1661860783',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[15/101] 16 ડિસેમ્બર, 2017ના રોજ વડાપ્રધાન શ્રી નરેન્દ્રભાઈ મોદીએ ક્યા રાજ્યમાં ગરીબોને મફત વીજળી આપવાની જાહેરાત કરી હતી?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'ઓરિસ્સા', 'voters': 0, 'chosen': False},
#     {'text': 'ઉત્તરપ્રદેશ', 'voters': 0, 'chosen': False},
#     {'text': 'મિઝોરમ', 'voters': 1, 'chosen': True},
#     {'text': 'બિહાર', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2576,
#   'type': 'message',
#   'date': '2022-08-30T17:29:45',
#   'date_unixtime': '1661860785',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[16/101] ભારતમાં ઉપરાષ્ટ્રપતિ હોદ્દાની રૂએ…',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'લોકસભાના અધ્યક્ષ બને છે',
#      'voters': 0,
#      'chosen': False},
#     {'text': 'રાજ્યસભાના અધ્યક્ષ બને છે', 'voters': 1, 'chosen': True},
#     {'text': 'બંનેના અધ્યક્ષ બની શકે છે', 'voters': 0, 'chosen': False},
#     {'text': 'ત્રણેયમાંથી એક પણ નહિ', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2577,
#   'type': 'message',
#   'date': '2022-08-30T17:29:48',
#   'date_unixtime': '1661860788',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[17/101] Change into passive voice : “They asked me my name”',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'My name is asked by them',
#      'voters': 0,
#      'chosen': False},
#     {'text': 'I was asked my name by them', 'voters': 0, 'chosen': False},
#     {'text': 'I asked my name by them', 'voters': 1, 'chosen': True},
#     {'text': 'I am asked my name by them', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2578,
#   'type': 'message',
#   'date': '2022-08-30T17:29:51',
#   'date_unixtime': '1661860791',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[18/101] Give synonym of ‘poison’',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'elixir', 'voters': 0, 'chosen': False},
#     {'text': 'fatal', 'voters': 0, 'chosen': False},
#     {'text': 'bitter', 'voters': 1, 'chosen': True},
#     {'text': 'venom', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2579,
#   'type': 'message',
#   'date': '2022-08-30T17:29:53',
#   'date_unixtime': '1661860793',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[19/101] Choose odd one out :',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'Odour', 'voters': 0, 'chosen': False},
#     {'text': 'Fragrance', 'voters': 0, 'chosen': False},
#     {'text': 'Foul', 'voters': 1, 'chosen': True},
#     {'text': 'Incense', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2580,
#   'type': 'message',
#   'date': '2022-08-30T17:29:56',
#   'date_unixtime': '1661860796',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[20/101] ભારતમાં મ્યુનિસિપલ ગવર્નર ક્યા વર્ષથી અસ્તિત્વમાં આવ્યું?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': '1961', 'voters': 0, 'chosen': False},
#     {'text': '1752', 'voters': 0, 'chosen': False},
#     {'text': '1681', 'voters': 1, 'chosen': True},
#     {'text': '1687', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2582,
#   'type': 'message',
#   'date': '2022-08-30T17:29:59',
#   'date_unixtime': '1661860799',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[21/101] પંચાયતી રાજ પ્રણાલીનો અમલ પ્રથમ કયા રાજ્યમાં થયો ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'રાજસ્થાન', 'voters': 0, 'chosen': False},
#     {'text': 'હરિયાણા', 'voters': 0, 'chosen': False},
#     {'text': 'પંજાબ', 'voters': 1, 'chosen': True},
#     {'text': 'ગુજરાત', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2583,
#   'type': 'message',
#   'date': '2022-08-30T17:30:02',
#   'date_unixtime': '1661860802',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[22/101] ભારતમાં 73 મો બંધારણીય સુધારો કયા વર્ષથી અમલમાં મુકવામાં આવ્યો ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': '1994', 'voters': 0, 'chosen': False},
#     {'text': '1989', 'voters': 1, 'chosen': True},
#     {'text': '1998', 'voters': 0, 'chosen': False},
#     {'text': '1992', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2584,
#   'type': 'message',
#   'date': '2022-08-30T17:30:06',
#   'date_unixtime': '1661860806',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[23/101] ક્યા સત્યાગ્રહને ગુજરાતનો પ્રથમ સત્યાગ્રહ માનવામાં આવે છે ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'બારડોલી', 'voters': 0, 'chosen': False},
#     {'text': 'બોરસદ', 'voters': 0, 'chosen': False},
#     {'text': 'ખેડા', 'voters': 1, 'chosen': True},
#     {'text': 'અમદાવાદ', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2585,
#   'type': 'message',
#   'date': '2022-08-30T17:30:09',
#   'date_unixtime': '1661860809',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[24/101] ભારતમાં ટેલિકોમ ક્રાંતિ લાવવામાં ક્યા ગુજરાતીઓએ અગ્રણી ભૂમિકા ભજવી છે ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'જમશેદજી તાતા', 'voters': 0, 'chosen': False},
#     {'text': 'સામ પિત્રોડા', 'voters': 1, 'chosen': True},
#     {'text': 'મુકેશભાઈ અંબાણી', 'voters': 0, 'chosen': False},
#     {'text': 'ધીરુભાઈ અંબાણી', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2586,
#   'type': 'message',
#   'date': '2022-08-30T17:30:14',
#   'date_unixtime': '1661860814',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[25/101] સાક્ષર નગરી તરીકે કયું શહેર જાણીતું છે ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'નડિયાદ', 'voters': 0, 'chosen': False},
#     {'text': 'બોટાદ', 'voters': 1, 'chosen': True},
#     {'text': 'આણંદ', 'voters': 0, 'chosen': False},
#     {'text': 'ભાવનગર', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2587,
#   'type': 'message',
#   'date': '2022-08-30T17:30:17',
#   'date_unixtime': '1661860817',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[26/101] ચુડા તાલુકો ગુજરાત રાજ્યના કયા જિલ્લામાં આવેલો છે ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'બોટાદ', 'voters': 0, 'chosen': False},
#     {'text': 'રાજકોટ', 'voters': 1, 'chosen': True},
#     {'text': 'સુરેન્દ્રનગર', 'voters': 0, 'chosen': False},
#     {'text': 'ભાવનગર', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2588,
#   'type': 'message',
#   'date': '2022-08-30T17:30:20',
#   'date_unixtime': '1661860820',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[27/101] કેલ્સાઈટ ના ઉત્પાદન માં ગુજરાત સમગ્ર ભારતમાં કેટલામાં ક્રમે છે ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'પ્રથમ', 'voters': 0, 'chosen': False},
#     {'text': 'ત્રીજા', 'voters': 0, 'chosen': False},
#     {'text': 'બીજા', 'voters': 1, 'chosen': True},
#     {'text': 'ચોથા', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2589,
#   'type': 'message',
#   'date': '2022-08-30T17:30:22',
#   'date_unixtime': '1661860822',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[28/101] ગુજરાત ના કેટલા જિલ્લાઓ ની સરહદ દરિયા સાથે સંકળાયેલ છે ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': '14', 'voters': 0, 'chosen': False},
#     {'text': '16', 'voters': 0, 'chosen': False},
#     {'text': '13', 'voters': 1, 'chosen': True},
#     {'text': '15', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2590,
#   'type': 'message',
#   'date': '2022-08-30T17:30:25',
#   'date_unixtime': '1661860825',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[29/101] નિમ્નલિખિત પૈકી કઈ અખિલ ભારતીય સેવા નથી ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'ભારતીય પ્રશાસનિક સેવા', 'voters': 0, 'chosen': False},
#     {'text': 'ભારતીય પોલીસ સેવા', 'voters': 0, 'chosen': False},
#     {'text': 'ભારતીય વન  સેવા', 'voters': 1, 'chosen': True},
#     {'text': 'ભારતીય વિદેશ સેવા', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2591,
#   'type': 'message',
#   'date': '2022-08-30T17:30:28',
#   'date_unixtime': '1661860828',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[30/101] જુમો ભિસ્તી વાર્તા માં પાડા નું નામ શું છે ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'ભૂરો', 'voters': 0, 'chosen': False},
#     {'text': 'જુમો', 'voters': 0, 'chosen': False},
#     {'text': 'વેણુ', 'voters': 1, 'chosen': True},
#     {'text': 'રેણુ', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2593,
#   'type': 'message',
#   'date': '2022-08-30T17:30:31',
#   'date_unixtime': '1661860831',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': "[31/101] 'જેનામાં વૃક્ષ પ્રીતિ નથી તેનામાં જાણે કે જીવન પ્રીતિ જ નથી ' પંક્તિ નો અલંકાર ઓળખાવો ?",
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'ઉત્પ્રેક્ષા', 'voters': 0, 'chosen': False},
#     {'text': 'વનવાસ', 'voters': 1, 'chosen': True},
#     {'text': 'ઉપમા', 'voters': 0, 'chosen': False},
#     {'text': 'સ્નેહાધીન', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2594,
#   'type': 'message',
#   'date': '2022-08-30T17:30:38',
#   'date_unixtime': '1661860838',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[32/101] સન્યાસી સંધિનો ક્યો વિગ્રહ સાચો છે ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'સમ્ + નિ + _આસ્તી', 'voters': 0, 'chosen': False},
#     {'text': 'સન + ન્યાસી', 'voters': 0, 'chosen': False},
#     {'text': 'સ + નિ +\u200c યાસી', 'voters': 1, 'chosen': True},
#     {'text': 'સન્ની + યાસી', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2595,
#   'type': 'message',
#   'date': '2022-08-30T17:30:42',
#   'date_unixtime': '1661860842',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[33/101] વાવ તે લણે માટે સર્વનામ ના પ્રકાર દર્શાવો ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'દર્શક', 'voters': 0, 'chosen': False},
#     {'text': 'અન્યન્યવાચક', 'voters': 1, 'chosen': True},
#     {'text': 'સાપેક્ષ', 'voters': 0, 'chosen': False},
#     {'text': 'ત્રીજા પુરુષ', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2596,
#   'type': 'message',
#   'date': '2022-08-30T17:30:44',
#   'date_unixtime': '1661860844',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[34/101] થીગડું વાર્તા ના લેખક કોણ છે?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'ચંદ્રકાંત બક્ષી', 'voters': 0, 'chosen': False},
#     {'text': 'મધુરાય', 'voters': 1, 'chosen': True},
#     {'text': 'સુરેશ જોશી', 'voters': 0, 'chosen': False},
#     {'text': 'રઘુવીર ચૌધરી', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2597,
#   'type': 'message',
#   'date': '2022-08-30T17:30:47',
#   'date_unixtime': '1661860847',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[35/101] નીચેનામાંથી કયો સમાસ એકપદપ્રધાન નથી ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'દ્વન્દ્વ', 'voters': 0, 'chosen': False},
#     {'text': 'મધ્યમપદલોપી', 'voters': 1, 'chosen': True},
#     {'text': 'કર્મધારય', 'voters': 0, 'chosen': False},
#     {'text': 'ઉપપદ', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2598,
#   'type': 'message',
#   'date': '2022-08-30T17:30:50',
#   'date_unixtime': '1661860850',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[36/101] ભારતનો સંત્રી એટલે શું ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'હિંદ મહાસાગર', 'voters': 0, 'chosen': False},
#     {'text': 'હિમાલય પર્વત', 'voters': 1, 'chosen': True},
#     {'text': 'અરવલ્લી પર્વત', 'voters': 0, 'chosen': False},
#     {'text': 'કચ્છનો અખાત', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2599,
#   'type': 'message',
#   'date': '2022-08-30T17:30:52',
#   'date_unixtime': '1661860852',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[37/101] બનારસ હિંદુ વિશ્વવિદ્યાલયના સ્થાપક કોણ હતા ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'મદન મોહન માલવીયા', 'voters': 0, 'chosen': False},
#     {'text': 'બાળ ગંગાધર તિલક', 'voters': 1, 'chosen': True},
#     {'text': 'એની બેસન્ટ', 'voters': 0, 'chosen': False},
#     {'text': 'સરદાર પટેલ', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2600,
#   'type': 'message',
#   'date': '2022-08-30T17:30:55',
#   'date_unixtime': '1661860855',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[38/101] સંયુક્ત રાષ્ટ્ર ઔદ્યોગિક વિકાસ સંગઠનનું મુખ્યાલય કયાં આવેલું છે?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'સ્વિટઝર્લેન્ડ', 'voters': 0, 'chosen': False},
#     {'text': 'ન્યૂયોર્ક', 'voters': 0, 'chosen': False},
#     {'text': 'વિયેના', 'voters': 1, 'chosen': True},
#     {'text': 'વોશિગ્ટન ડી.સી.', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2601,
#   'type': 'message',
#   'date': '2022-08-30T17:30:58',
#   'date_unixtime': '1661860858',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[39/101] P,Q,R અને S ચાર ક્રમિક મહિના છે જો P અને S 30 દિવસો છે તો  S ક્યો મહિનો છે.?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'સપ્ટેમ્બર', 'voters': 0, 'chosen': False},
#     {'text': 'જૂન', 'voters': 1, 'chosen': True},
#     {'text': 'એપ્રિલ', 'voters': 0, 'chosen': False},
#     {'text': 'નવેમ્બર', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2602,
#   'type': 'message',
#   'date': '2022-08-30T17:31:01',
#   'date_unixtime': '1661860861',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[40/101] Will you mind ____ sitting there?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'My', 'voters': 1, 'chosen': True},
#     {'text': 'Me', 'voters': 0, 'chosen': False},
#     {'text': 'I', 'voters': 0, 'chosen': False},
#     {'text': 'Mine', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2604,
#   'type': 'message',
#   'date': '2022-08-30T17:31:03',
#   'date_unixtime': '1661860863',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[41/101] The dinner _____ before I arrived.',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'had been served', 'voters': 0, 'chosen': False},
#     {'text': 'had been served', 'voters': 1, 'chosen': True},
#     {'text': 'will be served', 'voters': 0, 'chosen': False},
#     {'text': 'has been served', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2605,
#   'type': 'message',
#   'date': '2022-08-30T17:31:07',
#   'date_unixtime': '1661860867',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[42/101] Find the uncountable noun',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'Book', 'voters': 0, 'chosen': False},
#     {'text': 'a swarm', 'voters': 0, 'chosen': False},
#     {'text': 'orange', 'voters': 1, 'chosen': True},
#     {'text': 'water', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2606,
#   'type': 'message',
#   'date': '2022-08-30T17:31:11',
#   'date_unixtime': '1661860871',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[43/101] Usual behaviour of a social group',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'fondle', 'voters': 0, 'chosen': False},
#     {'text': 'benevolence', 'voters': 1, 'chosen': True},
#     {'text': 'custom', 'voters': 0, 'chosen': False},
#     {'text': 'custems', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2607,
#   'type': 'message',
#   'date': '2022-08-30T17:31:14',
#   'date_unixtime': '1661860874',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[44/101] My brother lives ____ Jetpur.',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'On', 'voters': 0, 'chosen': False},
#     {'text': 'Into', 'voters': 0, 'chosen': False},
#     {'text': 'In', 'voters': 1, 'chosen': True},
#     {'text': 'At', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2608,
#   'type': 'message',
#   'date': '2022-08-30T17:31:17',
#   'date_unixtime': '1661860877',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[45/101] નીચેનામાંથી કયાં વિધાનો સાચાં છે?  \n1.ગુજરાતમાં પ્રાથમિક શાળામાં ફરજિયાત શિક્ષણ સયાજીરાવ ગાયકવાડ દ્વારા શરૂ કરાયું હતુ. \n2.સ્વામી દયાનંદ સરસ્વતી એ આર્ય સમાજની સ્થાપના કરી હતી.  3.મોહમ્મદ ગઝનવીએ સોમનાથ પર ચડાઈ કરી તે સમયે ભીમદેવ પ્રથમ ત્યાં રાજ કરતા હતા.',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': '1, 2, 3', 'voters': 0, 'chosen': False},
#     {'text': '1 અને 2', 'voters': 1, 'chosen': True},
#     {'text': '2 અને 3', 'voters': 0, 'chosen': False},
#     {'text': '1 અને 3', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2609,
#   'type': 'message',
#   'date': '2022-08-30T17:31:19',
#   'date_unixtime': '1661860879',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[46/101] સવારે સૂર્યોદય બાદ રાજીવ એક થાંભલા સામે ઊભો હતો . થાંભલાનો પડછાયો તેની જમણી બાજુએ પડતો હતો તો તે કઈ દિશા માં મો રાખીને ઊભો હશે?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'ઉત્તર', 'voters': 0, 'chosen': False},
#     {'text': 'દક્ષિણ', 'voters': 0, 'chosen': False},
#     {'text': 'પૂર્વ', 'voters': 1, 'chosen': True},
#     {'text': 'પશ્ચિમ', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2610,
#   'type': 'message',
#   'date': '2022-08-30T17:31:22',
#   'date_unixtime': '1661860882',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[47/101] એક વેપારી 1 કિલોગ્રામ ને બદલે 1250 ગ્રામ દર્શાવતા વજનકાંટાનો ઉપયોગ કરે છે વધુમાં તે મૂળ કિંમત થી 20% જેટલી વધારે અંકિત રાખે છે તો નફાની ટકાવારી કેટલી થશે ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': '35%', 'voters': 0, 'chosen': False},
#     {'text': '45%', 'voters': 1, 'chosen': True},
#     {'text': '50%', 'voters': 0, 'chosen': False},
#     {'text': 'None', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2611,
#   'type': 'message',
#   'date': '2022-08-30T17:31:24',
#   'date_unixtime': '1661860884',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[48/101] એક સમબાજુ ચતુષ્કોણના વિકર્ણોની લંબાઈ 24 સેમી અને 10 સેમી હોય ,  તો તેના ક્ષેત્રફળ અને પરિમિતિનો ગુણોત્તર કેટલો થશે ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': '12:5', 'voters': 0, 'chosen': False},
#     {'text': '12:7', 'voters': 0, 'chosen': False},
#     {'text': '13:5', 'voters': 1, 'chosen': True},
#     {'text': 'None', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2612,
#   'type': 'message',
#   'date': '2022-08-30T17:31:27',
#   'date_unixtime': '1661860887',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[49/101] નીચે આપેલ શ્રેણી માં ખૂટતું પદ શોધો.\n12, 15, ____, 42, 69',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': '18', 'voters': 0, 'chosen': False},
#     {'text': '26', 'voters': 1, 'chosen': True},
#     {'text': '28', 'voters': 0, 'chosen': False},
#     {'text': '27', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2613,
#   'type': 'message',
#   'date': '2022-08-30T17:31:30',
#   'date_unixtime': '1661860890',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[50/101] એક સાંકેતિક ભાષામાં RED નો સંકેત 2076 હોય તો GREEN નો સંકેત કયો હશે ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': '9207716', 'voters': 0, 'chosen': False},
#     {'text': '9197717', 'voters': 0, 'chosen': False},
#     {'text': '1677209', 'voters': 0, 'chosen': False},
#     {'text': '9207616', 'voters': 1, 'chosen': True}]},
#   'text': ''},
#  {'id': 2615,
#   'type': 'message',
#   'date': '2022-08-30T17:31:34',
#   'date_unixtime': '1661860894',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[51/101] મંદકન્તા છંદ નું બંધારણ ઓળખવો ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'ન ર મ ર સ લ ગા', 'voters': 0, 'chosen': False},
#     {'text': 'મ ભ ન ત ત ગા ગા', 'voters': 1, 'chosen': True},
#     {'text': 'મ ભ ન ત લ ગા ગા', 'voters': 0, 'chosen': False},
#     {'text': 'જ સ જ સ ય લ ગા', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2616,
#   'type': 'message',
#   'date': '2022-08-30T17:31:36',
#   'date_unixtime': '1661860896',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[52/101] નેશનલ રજીસ્ટર ઓફ સીટીઝન (NRC) ની સ્થાપના કયા રાજય માટે કરવામા આવી છે ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'અસમ', 'voters': 0, 'chosen': False},
#     {'text': 'બિહાર', 'voters': 1, 'chosen': True},
#     {'text': 'ગુજરાત', 'voters': 0, 'chosen': False},
#     {'text': 'રાજસ્થાન', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2617,
#   'type': 'message',
#   'date': '2022-08-30T17:31:41',
#   'date_unixtime': '1661860901',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[53/101] તાજેતરમા ક્યાં દેશમાં થયેલા સરકાર વિરોધી દેખાવોમાં આશરે 30 લોકો ના મોત થયા છે ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'ઈરાક', 'voters': 0, 'chosen': False},
#     {'text': 'પાકિસ્તાન', 'voters': 0, 'chosen': False},
#     {'text': 'અફઘાનિસ્તાન', 'voters': 1, 'chosen': True},
#     {'text': 'ઈરાન', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2618,
#   'type': 'message',
#   'date': '2022-08-30T17:31:45',
#   'date_unixtime': '1661860905',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[54/101] બિહુ નૃત્ય ક્યા રાજ્યનું છે?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'બંગાળ', 'voters': 0, 'chosen': False},
#     {'text': 'આસામ', 'voters': 0, 'chosen': False},
#     {'text': 'બિહાર', 'voters': 0, 'chosen': False},
#     {'text': 'ઓરિસ્સા', 'voters': 1, 'chosen': True}]},
#   'text': ''},
#  {'id': 2619,
#   'type': 'message',
#   'date': '2022-08-30T17:31:54',
#   'date_unixtime': '1661860914',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[55/101] ભારતે સૌપ્રથમ વખત અણુ ધડાકો ક્યા કર્યો હતો.?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'પોખરણ', 'voters': 0, 'chosen': False},
#     {'text': 'ચાંદીપુર', 'voters': 1, 'chosen': True},
#     {'text': 'શ્રી હરિકોટા', 'voters': 0, 'chosen': False},
#     {'text': 'થુંબા', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2620,
#   'type': 'message',
#   'date': '2022-08-30T17:31:58',
#   'date_unixtime': '1661860918',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[56/101] સ્વતંત્ર ભારતમાં પહેલી વાર  રૂ.5000 ની ચલણી નોટો ક્યારે બહાર પાડવામાં આવી હતી.',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': '1950', 'voters': 0, 'chosen': False},
#     {'text': '1966', 'voters': 1, 'chosen': True},
#     {'text': '1960', 'voters': 0, 'chosen': False},
#     {'text': '1954', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2621,
#   'type': 'message',
#   'date': '2022-08-30T17:32:08',
#   'date_unixtime': '1661860928',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[57/101] મોઢેરાનું સૂર્યમંદિર ક્યા સોલંકી શાસકના સમયમાં બંધાવ્યું હતું?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'સિદ્ધરાજ જયસિંહ', 'voters': 0, 'chosen': False},
#     {'text': 'ભીમદેવ.1', 'voters': 1, 'chosen': True},
#     {'text': 'કુમારપાળ', 'voters': 0, 'chosen': False},
#     {'text': 'કર્ણદેવ', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2622,
#   'type': 'message',
#   'date': '2022-08-30T17:32:40',
#   'date_unixtime': '1661860960',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[58/101] ઉજ્જૈનનું પ્રાચીન નામ શું હતું?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'અવંતિકા', 'voters': 0, 'chosen': False},
#     {'text': 'ઈન્દ્રપ્રસ્થ', 'voters': 1, 'chosen': True},
#     {'text': 'નાલંદા', 'voters': 0, 'chosen': False},
#     {'text': 'તક્ષશિલા', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2623,
#   'type': 'message',
#   'date': '2022-08-30T17:32:47',
#   'date_unixtime': '1661860967',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[59/101] દાંડીકૂચની શરૂઆત થઈ ત્યારે પ્રથમ રાત્રિ નો વિરામ ક્યા લીધો હતો?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'લાલટ', 'voters': 0, 'chosen': False},
#     {'text': 'આલસી', 'voters': 1, 'chosen': True},
#     {'text': 'અલટ', 'voters': 0, 'chosen': False},
#     {'text': 'અસ્લાલી', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2624,
#   'type': 'message',
#   'date': '2022-08-30T17:32:51',
#   'date_unixtime': '1661860971',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[60/101] ભારતમાં ઉંમર આધારિત સ્ત્રી પુરુષ ગુણોત્તર ની  ગણતરી કરવાનું ક્યારથી શરૂ થયું?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': '1951', 'voters': 0, 'chosen': False},
#     {'text': '1961', 'voters': 1, 'chosen': True},
#     {'text': '1941', 'voters': 0, 'chosen': False},
#     {'text': '1971', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2625,
#   'type': 'message',
#   'date': '2022-08-30T17:32:55',
#   'date_unixtime': '1661860975',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[61/101] ઇન્ડિકા પુસ્તક ના રચયિતા કોણ છે ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'મેગેસ્થનીઝ', 'voters': 0, 'chosen': False},
#     {'text': 'કૌટિલ્ય', 'voters': 1, 'chosen': True},
#     {'text': 'ફફાન', 'voters': 0, 'chosen': False},
#     {'text': 'હુએન ત્યાંગ', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2626,
#   'type': 'message',
#   'date': '2022-08-30T17:32:58',
#   'date_unixtime': '1661860978',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[62/101] Wtok hard______you should fail.',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'So that', 'voters': 0, 'chosen': False},
#     {'text': 'And', 'voters': 0, 'chosen': False},
#     {'text': 'But', 'voters': 1, 'chosen': True},
#     {'text': 'Lest', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2627,
#   'type': 'message',
#   'date': '2022-08-30T17:33:04',
#   'date_unixtime': '1661860984',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[63/101] Give  synonyms of : contemplate',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'Meditate', 'voters': 0, 'chosen': False},
#     {'text': 'Condemn', 'voters': 1, 'chosen': True},
#     {'text': 'Menuplate', 'voters': 0, 'chosen': False},
#     {'text': 'None', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2628,
#   'type': 'message',
#   'date': '2022-08-30T17:33:08',
#   'date_unixtime': '1661860988',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[64/101] લઘુ વાંચવું એ કઈ કેળવણી નથી - કૃંદત નો પ્રકાર જણાવો',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'વિધ્યાથૅ કુંદત', 'voters': 0, 'chosen': False},
#     {'text': 'સબંધક કૃંદત', 'voters': 1, 'chosen': True},
#     {'text': 'ભવિષ્ય કૃંદત', 'voters': 0, 'chosen': False},
#     {'text': 'વર્તમાન કૃંદત', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2629,
#   'type': 'message',
#   'date': '2022-08-30T17:33:12',
#   'date_unixtime': '1661860992',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[65/101] વાછરડું જોયા વિના દૂધ દેહવા દેતી ગાય ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'અવલી', 'voters': 0, 'chosen': False},
#     {'text': 'ઝવલી', 'voters': 1, 'chosen': True},
#     {'text': 'રવલી', 'voters': 0, 'chosen': False},
#     {'text': 'કવલી', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2630,
#   'type': 'message',
#   'date': '2022-08-30T17:33:19',
#   'date_unixtime': '1661860999',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[66/101] ગુજરાતી ભાષાને અન્ય ભાષા જેવું ગૌરવ ન મળે ત્યાં સુધી પાઘડી ન પહેરવાની પ્રતિજ્ઞા કોણે લીધી હતી ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'દલપતરામ', 'voters': 0, 'chosen': False},
#     {'text': 'નર્મદ', 'voters': 1, 'chosen': True},
#     {'text': 'પ્રેમાનંદ', 'voters': 0, 'chosen': False},
#     {'text': 'શામળ', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2631,
#   'type': 'message',
#   'date': '2022-08-30T17:33:21',
#   'date_unixtime': '1661861001',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[67/101] કુસ્તીમાં ઓલમ્પિક મેડલ જીતનાર પ્રથમ ભારતિય મહિલા કોણ છે ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'પી વી સિંધુ', 'voters': 1, 'chosen': True},
#     {'text': 'સાક્ષી મલિક', 'voters': 0, 'chosen': False},
#     {'text': 'ગીતા ફોગટ', 'voters': 0, 'chosen': False},
#     {'text': 'દીપિકા કુમારી', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2632,
#   'type': 'message',
#   'date': '2022-08-30T17:33:26',
#   'date_unixtime': '1661861006',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[68/101] અસ્મિતા પર્વત કયા દિવસે ઉજવવામાં આવે છે ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'જન્માષ્ટમી', 'voters': 1, 'chosen': True},
#     {'text': 'મહાશિવરાત્રી', 'voters': 0, 'chosen': False},
#     {'text': 'હનુમાન જયંતી', 'voters': 0, 'chosen': False},
#     {'text': 'રામનોમવી', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2633,
#   'type': 'message',
#   'date': '2022-08-30T17:33:29',
#   'date_unixtime': '1661861009',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[69/101] નીતિ પંચના અધ્યક્ષ કોણ હોય છે ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'રાષ્ટ્રપતિ', 'voters': 1, 'chosen': True},
#     {'text': 'નાણામંત્રી', 'voters': 0, 'chosen': False},
#     {'text': 'વડાપ્રધાન', 'voters': 0, 'chosen': False},
#     {'text': 'ઉપરાષ્ટ્રપતિ', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2634,
#   'type': 'message',
#   'date': '2022-08-30T17:33:32',
#   'date_unixtime': '1661861012',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[70/101] ભારત સરકાર રમત-ગમતના કોચિંગ માટે કયા સર્વોચ્ચ એવોર્ડ એનાયત કરે છે ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'ગુરુ એવોર્ડ', 'voters': 1, 'chosen': True},
#     {'text': 'ખેલરત્ન એવોર્ડ', 'voters': 0, 'chosen': False},
#     {'text': 'અર્જુન એવોર્ડ', 'voters': 0, 'chosen': False},
#     {'text': 'દ્રોણાચાર્ય એવોર્ડ', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2636,
#   'type': 'message',
#   'date': '2022-08-30T17:33:38',
#   'date_unixtime': '1661861018',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[71/101] બનારસ હિંદુ વિશ્વવિદ્યાલયના સ્થાપક કોણ હતા ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'બાલ ગંગાધર તિલક', 'voters': 0, 'chosen': False},
#     {'text': 'મદન મોહન માલવીયા', 'voters': 1, 'chosen': True},
#     {'text': 'એની બેસન્ટ', 'voters': 0, 'chosen': False},
#     {'text': 'સરદાર પટેલ', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2637,
#   'type': 'message',
#   'date': '2022-08-30T17:33:44',
#   'date_unixtime': '1661861024',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[72/101] ભારતના પ્રથમ ગવર્નર જનરલ કોણ હતા ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'વિલિયમ બેન્ટિક', 'voters': 0, 'chosen': False},
#     {'text': 'લૉર્ડ વિલીઝન', 'voters': 1, 'chosen': True},
#     {'text': 'લૉર્ડ મૈકલ', 'voters': 0, 'chosen': False},
#     {'text': 'લૉર્ડ હેસ્ટિગ્જ', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2638,
#   'type': 'message',
#   'date': '2022-08-30T17:33:47',
#   'date_unixtime': '1661861027',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[73/101] CD ROM ડ્રાઈવર ની ગતિ____હોય છે?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': '40 ×', 'voters': 0, 'chosen': False},
#     {'text': '48 ×', 'voters': 1, 'chosen': True},
#     {'text': '52 ×', 'voters': 0, 'chosen': False},
#     {'text': 'બધા જ', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2639,
#   'type': 'message',
#   'date': '2022-08-30T17:33:50',
#   'date_unixtime': '1661861030',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[74/101] Winzip નામના ટૂલની મદદથી_______છે ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'સાઇઝ ઘટાડી શકાય', 'voters': 0, 'chosen': False},
#     {'text': 'ગુપ્તતા જળવાઈ', 'voters': 1, 'chosen': True},
#     {'text': 'એક કરતાં વધુ ફાઈલો ભેગી થાય', 'voters': 0, 'chosen': False},
#     {'text': 'એક પણ નહીં', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2640,
#   'type': 'message',
#   'date': '2022-08-30T17:33:53',
#   'date_unixtime': '1661861033',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[75/101] DVD સામાન્ય વધુમાં વધુ એક્સેસ દર _______ધરાવે છે ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': '5.3', 'voters': 0, 'chosen': False},
#     {'text': '8.3', 'voters': 1, 'chosen': True},
#     {'text': '6.3', 'voters': 0, 'chosen': False},
#     {'text': '9.3', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2641,
#   'type': 'message',
#   'date': '2022-08-30T17:33:56',
#   'date_unixtime': '1661861036',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[76/101] CNG માં મોટા ભાગે નીચેનામાંથી કયો વાયુ હોય ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'નાઇટ્રોજન', 'voters': 0, 'chosen': False},
#     {'text': 'ઓક્સિજન', 'voters': 0, 'chosen': False},
#     {'text': 'મીથેન', 'voters': 1, 'chosen': True},
#     {'text': 'હિલિયમ', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2642,
#   'type': 'message',
#   'date': '2022-08-30T17:33:59',
#   'date_unixtime': '1661861039',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[77/101] When he found the wallet is face glowed but soon it faded us the wallet was________',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'Recovered', 'voters': 0, 'chosen': False},
#     {'text': 'Empty', 'voters': 1, 'chosen': True},
#     {'text': 'Expensive', 'voters': 0, 'chosen': False},
#     {'text': 'Stoien', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2643,
#   'type': 'message',
#   'date': '2022-08-30T17:34:01',
#   'date_unixtime': '1661861041',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[78/101] તાજેતરમાં ક્યા દેશમાં થયેલા સરકાર વિરોધી દેખાવોમાં આશરે 30 લોકો ના મોત થયા છે ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'ઈરાક', 'voters': 0, 'chosen': False},
#     {'text': 'પાકિસ્તાન', 'voters': 1, 'chosen': True},
#     {'text': 'અફઘનિસ્તાન', 'voters': 0, 'chosen': False},
#     {'text': 'ઈરાન', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2644,
#   'type': 'message',
#   'date': '2022-08-30T17:34:07',
#   'date_unixtime': '1661861047',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[79/101] The police made him_________his crime.',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'Confess', 'voters': 0, 'chosen': False},
#     {'text': 'Confessed', 'voters': 0, 'chosen': False},
#     {'text': 'To confess', 'voters': 1, 'chosen': True},
#     {'text': 'confesses', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2645,
#   'type': 'message',
#   'date': '2022-08-30T17:34:10',
#   'date_unixtime': '1661861050',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[80/101] You and I are doing our work, ________ ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'Are we', 'voters': 0, 'chosen': False},
#     {'text': "Aren't you", 'voters': 1, 'chosen': True},
#     {'text': "Aren't me", 'voters': 0, 'chosen': False},
#     {'text': "Aren't i", 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2647,
#   'type': 'message',
#   'date': '2022-08-30T17:34:16',
#   'date_unixtime': '1661861056',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[81/101] Shraddha_______since afternoon.',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'Has been working', 'voters': 0, 'chosen': False},
#     {'text': 'Is working', 'voters': 1, 'chosen': True},
#     {'text': 'Works', 'voters': 0, 'chosen': False},
#     {'text': 'Was working', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2648,
#   'type': 'message',
#   'date': '2022-08-30T17:34:27',
#   'date_unixtime': '1661861067',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[82/101] લગ્ન વખતે કન્યાને પહેરવાનું વસ્ત્ર શબ્દ સમૂહ માટે નો એક શબ્દ કયો ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'પાલવ', 'voters': 0, 'chosen': False},
#     {'text': 'મીઢણ', 'voters': 1, 'chosen': True},
#     {'text': 'પાનેતર', 'voters': 0, 'chosen': False},
#     {'text': 'સાડી', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2649,
#   'type': 'message',
#   'date': '2022-08-30T17:34:35',
#   'date_unixtime': '1661861075',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[83/101] મધ્યકાલીન ગુજરાતી સાહિત્યમાં સૌથી વધુ લોક પ્રિય પદ્યવાર્તાકાર તરીકે કોણ પ્રસિદ્ધ છે ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'પ્રેમાનંદ', 'voters': 0, 'chosen': False},
#     {'text': 'ભોજા ભગત', 'voters': 1, 'chosen': True},
#     {'text': 'ભાલણ', 'voters': 0, 'chosen': False},
#     {'text': 'શામળ', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2650,
#   'type': 'message',
#   'date': '2022-08-30T17:34:42',
#   'date_unixtime': '1661861082',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[84/101] ઉંબરે ઊભી સાંભળું રે બોલ વાલમના ગીત લખનાર ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'મણિલાલ દેસાઈ', 'voters': 0, 'chosen': False},
#     {'text': 'મણિલાલ વેગડ', 'voters': 1, 'chosen': True},
#     {'text': 'મનસુખલાલ', 'voters': 0, 'chosen': False},
#     {'text': 'મહિપત ભાઈ', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2651,
#   'type': 'message',
#   'date': '2022-08-30T17:34:46',
#   'date_unixtime': '1661861086',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[85/101] ભારતની પ્રથમ વોટર ટેપ નો પ્રારંભ ક્યારે થયો ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'મુંબઈ', 'voters': 0, 'chosen': False},
#     {'text': 'દિલ્હી', 'voters': 1, 'chosen': True},
#     {'text': 'અમદાવાદ', 'voters': 0, 'chosen': False},
#     {'text': 'હૈદરાબાદ', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2652,
#   'type': 'message',
#   'date': '2022-08-30T17:34:48',
#   'date_unixtime': '1661861088',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[86/101] Ipl પીએમ કોલકાતા નાઇટ રાઇડર્સના કેપ્ટન તરીકે કોની પસંદગી કરવામાં આવી છે ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'યુસુફ પઠાણ', 'voters': 0, 'chosen': False},
#     {'text': 'ભુનેશ્વર', 'voters': 1, 'chosen': True},
#     {'text': 'મહેન્દ્રસિંહ ધોની', 'voters': 0, 'chosen': False},
#     {'text': 'શ્રેયસ ઐયર', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2653,
#   'type': 'message',
#   'date': '2022-08-30T17:34:52',
#   'date_unixtime': '1661861092',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[87/101] 16 ફેબ્રુઆરી 2020 ના રોજ ગુરુ રવિદાસ ની કેટલામી જન્મ જયંતી ઉજવાય ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': '653', 'voters': 0, 'chosen': False},
#     {'text': '650', 'voters': 0, 'chosen': False},
#     {'text': '645', 'voters': 1, 'chosen': True},
#     {'text': '655', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2654,
#   'type': 'message',
#   'date': '2022-08-30T17:34:57',
#   'date_unixtime': '1661861097',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[88/101] રાષ્ટ્રીય ઉત્પાદકતા દિવસ ક્યારે ઉજવવામાં આવે છે ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': '12 ફેબ્રુઆરી', 'voters': 0, 'chosen': False},
#     {'text': '8 માર્ચ', 'voters': 1, 'chosen': True},
#     {'text': '10 ફેબ્રુઆરી', 'voters': 0, 'chosen': False},
#     {'text': '20 ફેબ્રુઆરી', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2655,
#   'type': 'message',
#   'date': '2022-08-30T17:35:00',
#   'date_unixtime': '1661861100',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[89/101] I really enjoy______ the poor.',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'Help', 'voters': 0, 'chosen': False},
#     {'text': 'Helped', 'voters': 1, 'chosen': True},
#     {'text': 'Helping', 'voters': 0, 'chosen': False},
#     {'text': 'Will help', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2656,
#   'type': 'message',
#   'date': '2022-08-30T17:35:02',
#   'date_unixtime': '1661861102',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': "[90/101] Don't _______ your time, otherwise you can't progress in life.",
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'Waste', 'voters': 0, 'chosen': False},
#     {'text': 'Start', 'voters': 1, 'chosen': True},
#     {'text': 'Lose', 'voters': 0, 'chosen': False},
#     {'text': 'Spoil', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2658,
#   'type': 'message',
#   'date': '2022-08-30T17:35:06',
#   'date_unixtime': '1661861106',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[91/101] સક્રિય રોના પ્રથમ સેલ પર જવા માટે નીચેનામાંથી ____કી વપરાય છે  ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'END', 'voters': 0, 'chosen': False},
#     {'text': 'HOME', 'voters': 1, 'chosen': True},
#     {'text': 'TAB', 'voters': 0, 'chosen': False},
#     {'text': 'ESC', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2659,
#   'type': 'message',
#   'date': '2022-08-30T17:35:10',
#   'date_unixtime': '1661861110',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[92/101] To run after someone is________',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'Marathen', 'voters': 0, 'chosen': False},
#     {'text': 'Race', 'voters': 1, 'chosen': True},
#     {'text': 'Follo', 'voters': 0, 'chosen': False},
#     {'text': 'Chase', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2660,
#   'type': 'message',
#   'date': '2022-08-30T17:35:15',
#   'date_unixtime': '1661861115',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[93/101] Kusum father was_________ London last month.',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'Had', 'voters': 0, 'chosen': False},
#     {'text': 'Gone', 'voters': 0, 'chosen': False},
#     {'text': 'In', 'voters': 1, 'chosen': True},
#     {'text': 'From', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2661,
#   'type': 'message',
#   'date': '2022-08-30T17:35:18',
#   'date_unixtime': '1661861118',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[94/101] Find nearly opposite meaning : monarchy',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'Kingdom', 'voters': 0, 'chosen': False},
#     {'text': 'Democracy', 'voters': 1, 'chosen': True},
#     {'text': 'Freedom', 'voters': 0, 'chosen': False},
#     {'text': 'Strong rule', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2662,
#   'type': 'message',
#   'date': '2022-08-30T17:35:22',
#   'date_unixtime': '1661861122',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[95/101] રેફ્રિજરેટરમાં કુલન્ટ રૂપે______ગેસનો ઉપયોગ થાય છે ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'એમોનીયા', 'voters': 0, 'chosen': False},
#     {'text': 'કાર્બન ડાયોક્સાઇડ', 'voters': 0, 'chosen': False},
#     {'text': 'હિલિયમ', 'voters': 1, 'chosen': True},
#     {'text': 'નાઇટ્રોજન', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2663,
#   'type': 'message',
#   'date': '2022-08-30T17:35:29',
#   'date_unixtime': '1661861129',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[96/101] પાણીની ઘનતા સૌથી વધુ હોય છે ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': '100સે પર', 'voters': 0, 'chosen': False},
#     {'text': '0સે પર', 'voters': 0, 'chosen': False},
#     {'text': '-4સે પર', 'voters': 1, 'chosen': True},
#     {'text': '4સે પર', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2664,
#   'type': 'message',
#   'date': '2022-08-30T17:35:32',
#   'date_unixtime': '1661861132',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[97/101] પસંદ કરેલ 7 આડી રો તથા 9 ઊભી હરોળ ની હદ માટે એડ્રેસ બોક્સમાં _____ લખાશે   ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': '9C7R', 'voters': 0, 'chosen': False},
#     {'text': '9R × 7C', 'voters': 0, 'chosen': False},
#     {'text': '79RC', 'voters': 1, 'chosen': True},
#     {'text': '7R × 9C', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2665,
#   'type': 'message',
#   'date': '2022-08-30T17:35:35',
#   'date_unixtime': '1661861135',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[98/101] ભારતમાં ગ્રુહ વપરાશ માટે AC વોલ્ટેજ નું મૂલ્ય અને આવૃત્તિ શું છે ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': '110 v, 60 Hz', 'voters': 0, 'chosen': False},
#     {'text': '110 v, 50 Hz', 'voters': 0, 'chosen': False},
#     {'text': '220 v, 50 Hz', 'voters': 1, 'chosen': True},
#     {'text': '220 v, 60 Hz', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2666,
#   'type': 'message',
#   'date': '2022-08-30T17:35:38',
#   'date_unixtime': '1661861138',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[99/101] નીચેના માંથી એરીથમેટિક ઓપરેશન. ક્યાં.?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': '+  અને  -', 'voters': 0, 'chosen': False},
#     {'text': '%  અને  <', 'voters': 0, 'chosen': False},
#     {'text': '*  અને  ?', 'voters': 1, 'chosen': True},
#     {'text': 'તમામ', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2667,
#   'type': 'message',
#   'date': '2022-08-30T17:35:41',
#   'date_unixtime': '1661861141',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[100/101] સ્વાવલંબી પોષણ પદ્ધત્તિ માં શાની જરૂર હોય છે ?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'CO² અને પાણી', 'voters': 0, 'chosen': False},
#     {'text': 'કલોરોફિલ', 'voters': 0, 'chosen': False},
#     {'text': 'સૂર્ય પ્રકાશ', 'voters': 1, 'chosen': True},
#     {'text': 'ત્રણેય', 'voters': 0, 'chosen': False}]},
#   'text': ''}]

# %%
len(data['messages'])
# Out:
# 100

# %%
dict2=data['messages']

# %%
len(dict2)
# Out:
# 100

# %%
for i in dict2:
    a=i
    s={}
   # print(a.keys())
    if a.keys=="['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'poll', 'text']":
        print(a.keys())
        
    a=[]

# %%
for i in dict2:
        for x in i.values():
            print(x)
# Out:
# 2560
# message
# 2022-08-30T17:28:44
# 1661860724
# Quiz Bot
# user983000232
# {'question': '[1/101] કવિ રમેશ પારેખનો જન્મ ક્યાં થયો હતો?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'અમરેલી', 'voters': 0, 'chosen': False}, {'text': 'બોટાદ', 'voters': 0, 'chosen': False}, {'text': 'ભાવનગર', 'voters': 1, 'chosen': True}, {'text': 'સુરત', 'voters': 0, 'chosen': False}]}
#
# 2561
# message
# 2022-08-30T17:29:02
# 1661860742
# Quiz Bot
# user983000232
# {'question': '[2/101] અમરતકાકી – કઈ કૃતિનું પાત્ર છે?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'જનમટીપ', 'voters': 0, 'chosen': False}, {'text': 'લોહીની સગાઈ', 'voters': 0, 'chosen': False}, {'text': 'શરણાઈના સૂર', 'voters': 1, 'chosen': True}, {'text': 'જુમો ભિસ્તી', 'voters': 0, 'chosen': False}]}
#
# 2562
# message
# 2022-08-30T17:29:05
# 1661860745
# Quiz Bot
# user983000232
# {'question': '[3/101] ગોપાળબાપા’ પ્રકરણ કઈ નવલકથામાંથી લેવામાં આવ્યું છે?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'દીપ નિર્વાણ', 'voters': 0, 'chosen': False}, {'text': 'સોક્રેટીસ', 'voters': 0, 'chosen': False}, {'text': 'ઝેર તો પીધા છે જાણી જાણી', 'voters': 1, 'chosen': True}, {'text': 'કુરુક્ષેત્ર', 'voters': 0, 'chosen': False}]}
#
# 2563
# message
# 2022-08-30T17:29:10
# 1661860750
# Quiz Bot
# user983000232
# {'question': '[4/101] નીચેનામાંથી ખોટી સંધિ જણાવો.', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'કવીશ્વર = કવિ + ઈશ્વર', 'voters': 0, 'chosen': False}, {'text': 'પૂર્વોક્ત = પૂર્વ + ઊક્ત', 'voters': 1, 'chosen': True}, {'text': 'ઉપેન્દ્ર = ઉપ + ઈન્દ્ર', 'voters': 0, 'chosen': False}, {'text': 'રવીન્દ્ર = રવિ + ઈન્દ્ર', 'voters': 0, 'chosen': False}]}
#
# 2564
# message
# 2022-08-30T17:29:13
# 1661860753
# Quiz Bot
# user983000232
# {'question': '[5/101] એક સમાંતર શ્રેણીનું પ્રથમ પદ 5 અને છેલ્લું પદ 45 છે અને બધા પદોનો સરવાળો 500 હોય તો પદોની સંખ્યા કેટલી હશે?', 'closed': True, 'total_voters': 1, 'answers': [{'text': '19', 'voters': 0, 'chosen': False}, {'text': '22', 'voters': 0, 'chosen': False}, {'text': '21', 'voters': 1, 'chosen': True}, {'text': '20', 'voters': 0, 'chosen': False}]}
#
# 2565
# message
# 2022-08-30T17:29:16
# 1661860756
# Quiz Bot
# user983000232
# {'question': '[6/101] વેપારી પોતાના માલ પર 20% અને 10% એમ બે ક્રમિક વળતર આપે છે. પરિણામી વળતર કેટલું થાય?', 'closed': True, 'total_voters': 1, 'answers': [{'text': '30', 'voters': 0, 'chosen': False}, {'text': '22', 'voters': 1, 'chosen': True}, {'text': '28', 'voters': 0, 'chosen': False}, {'text': '20', 'voters': 0, 'chosen': False}]}
#
# 2566
# message
# 2022-08-30T17:29:18
# 1661860758
# Quiz Bot
# user983000232
# {'question': '[7/101] રાહીનું સ્થાન વર્ગમાં ઉપરથી 16મું અને નીચેથી 24મું છે, તો વર્ગમાં કુલ કેટલા વિદ્યાર્થીઓ હશે?', 'closed': True, 'total_voters': 1, 'answers': [{'text': '41', 'voters': 0, 'chosen': False}, {'text': '39', 'voters': 0, 'chosen': False}, {'text': '40', 'voters': 1, 'chosen': True}, {'text': '38', 'voters': 0, 'chosen': False}]}
#
# 2567
# message
# 2022-08-30T17:29:21
# 1661860761
# Quiz Bot
# user983000232
# {'question': '[8/101] શ્રેણી -6, ૩, 0નો સામાન્ય તફાવત _____ છે.', 'closed': True, 'total_voters': 1, 'answers': [{'text': '3', 'voters': 0, 'chosen': False}, {'text': '-3', 'voters': 0, 'chosen': False}, {'text': '-9', 'voters': 1, 'chosen': True}, {'text': '9', 'voters': 0, 'chosen': False}]}
#
# 2568
# message
# 2022-08-30T17:29:23
# 1661860763
# Quiz Bot
# user983000232
# {'question': '[9/101] 14 કારીગરોનો 10 દિવસનો પગાર 22,400 રૂ. છે તો 16 કારીગરોનો 16 દિવસનો પગાર કેટલો થાય?', 'closed': True, 'total_voters': 1, 'answers': [{'text': '20480', 'voters': 0, 'chosen': False}, {'text': '4096', 'voters': 1, 'chosen': True}, {'text': '25600', 'voters': 0, 'chosen': False}, {'text': '40960', 'voters': 0, 'chosen': False}]}
#
# 2569
# message
# 2022-08-30T17:29:26
# 1661860766
# Quiz Bot
# user983000232
# {'question': '[10/101] નીચેનામાંથી કયો શબ્દ તત્પુરુષ સમાસ નથી?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'દેશપ્રેમ', 'voters': 0, 'chosen': False}, {'text': 'વનવાસ', 'voters': 0, 'chosen': False}, {'text': 'પાપપુણ્ય', 'voters': 1, 'chosen': True}, {'text': 'સ્નેહાધિન', 'voters': 0, 'chosen': False}]}
#
# 2571
# message
# 2022-08-30T17:29:28
# 1661860768
# Quiz Bot
# user983000232
# {'question': '[11/101] સાંઢ નાથ્યો’ પ્રકરણ કઈ નવલકથામાંથી લેવામાં આવ્યું છે', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'ભવસાગર', 'voters': 0, 'chosen': False}, {'text': 'જનમટીપ', 'voters': 0, 'chosen': False}, {'text': 'મારી હૈયા સગડી', 'voters': 1, 'chosen': True}, {'text': 'દીપ નિર્માણ', 'voters': 0, 'chosen': False}]}
#
# 2572
# message
# 2022-08-30T17:29:31
# 1661860771
# Quiz Bot
# user983000232
# {'question': '[12/101] નીચેનામાંથી કયો શબ્દ કર્મધારય સમાસ છે?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'પૃથ્વી', 'voters': 1, 'chosen': True}, {'text': 'મનહર', 'voters': 0, 'chosen': False}, {'text': 'પિતાંબર', 'voters': 0, 'chosen': False}, {'text': 'ખાધું-પીધું', 'voters': 0, 'chosen': False}]}
#
# 2573
# message
# 2022-08-30T17:29:37
# 1661860777
# Quiz Bot
# user983000232
# {'question': '[13/101] ભારતના બંધારણના નીચેના પૈકી ક્યા અનુચ્છેદો સંઘ અને રાજ્યો વચ્ચેના વહીવટી સબંધો બાબતના છે?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'અનુ. 245 – 255', 'voters': 0, 'chosen': False}, {'text': 'અનુ. 233 – 245', 'voters': 1, 'chosen': True}, {'text': 'અનુ. 256 – 263', 'voters': 0, 'chosen': False}, {'text': 'અનુ. 269 – 279', 'voters': 0, 'chosen': False}]}
#
# 2574
# message
# 2022-08-30T17:29:40
# 1661860780
# Quiz Bot
# user983000232
# {'question': '[14/101] ભારતની રાષ્ટ્રપતિની ચૂંટણીમાંદરેક સંસદ સભ્યના મતનું મૂલ્ય કેટલું છે?', 'closed': True, 'total_voters': 1, 'answers': [{'text': '708', 'voters': 0, 'chosen': False}, {'text': '504', 'voters': 0, 'chosen': False}, {'text': '706', 'voters': 1, 'chosen': True}, {'text': '302', 'voters': 0, 'chosen': False}]}
#
# 2575
# message
# 2022-08-30T17:29:43
# 1661860783
# Quiz Bot
# user983000232
# {'question': '[15/101] 16 ડિસેમ્બર, 2017ના રોજ વડાપ્રધાન શ્રી નરેન્દ્રભાઈ મોદીએ ક્યા રાજ્યમાં ગરીબોને મફત વીજળી આપવાની જાહેરાત કરી હતી?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'ઓરિસ્સા', 'voters': 0, 'chosen': False}, {'text': 'ઉત્તરપ્રદેશ', 'voters': 0, 'chosen': False}, {'text': 'મિઝોરમ', 'voters': 1, 'chosen': True}, {'text': 'બિહાર', 'voters': 0, 'chosen': False}]}
#
# 2576
# message
# 2022-08-30T17:29:45
# 1661860785
# Quiz Bot
# user983000232
# {'question': '[16/101] ભારતમાં ઉપરાષ્ટ્રપતિ હોદ્દાની રૂએ…', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'લોકસભાના અધ્યક્ષ બને છે', 'voters': 0, 'chosen': False}, {'text': 'રાજ્યસભાના અધ્યક્ષ બને છે', 'voters': 1, 'chosen': True}, {'text': 'બંનેના અધ્યક્ષ બની શકે છે', 'voters': 0, 'chosen': False}, {'text': 'ત્રણેયમાંથી એક પણ નહિ', 'voters': 0, 'chosen': False}]}
#
# 2577
# message
# 2022-08-30T17:29:48
# 1661860788
# Quiz Bot
# user983000232
# {'question': '[17/101] Change into passive voice : “They asked me my name”', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'My name is asked by them', 'voters': 0, 'chosen': False}, {'text': 'I was asked my name by them', 'voters': 0, 'chosen': False}, {'text': 'I asked my name by them', 'voters': 1, 'chosen': True}, {'text': 'I am asked my name by them', 'voters': 0, 'chosen': False}]}
#
# 2578
# message
# 2022-08-30T17:29:51
# 1661860791
# Quiz Bot
# user983000232
# {'question': '[18/101] Give synonym of ‘poison’', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'elixir', 'voters': 0, 'chosen': False}, {'text': 'fatal', 'voters': 0, 'chosen': False}, {'text': 'bitter', 'voters': 1, 'chosen': True}, {'text': 'venom', 'voters': 0, 'chosen': False}]}
#
# 2579
# message
# 2022-08-30T17:29:53
# 1661860793
# Quiz Bot
# user983000232
# {'question': '[19/101] Choose odd one out :', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'Odour', 'voters': 0, 'chosen': False}, {'text': 'Fragrance', 'voters': 0, 'chosen': False}, {'text': 'Foul', 'voters': 1, 'chosen': True}, {'text': 'Incense', 'voters': 0, 'chosen': False}]}
#
# 2580
# message
# 2022-08-30T17:29:56
# 1661860796
# Quiz Bot
# user983000232
# {'question': '[20/101] ભારતમાં મ્યુનિસિપલ ગવર્નર ક્યા વર્ષથી અસ્તિત્વમાં આવ્યું?', 'closed': True, 'total_voters': 1, 'answers': [{'text': '1961', 'voters': 0, 'chosen': False}, {'text': '1752', 'voters': 0, 'chosen': False}, {'text': '1681', 'voters': 1, 'chosen': True}, {'text': '1687', 'voters': 0, 'chosen': False}]}
#
# 2582
# message
# 2022-08-30T17:29:59
# 1661860799
# Quiz Bot
# user983000232
# {'question': '[21/101] પંચાયતી રાજ પ્રણાલીનો અમલ પ્રથમ કયા રાજ્યમાં થયો ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'રાજસ્થાન', 'voters': 0, 'chosen': False}, {'text': 'હરિયાણા', 'voters': 0, 'chosen': False}, {'text': 'પંજાબ', 'voters': 1, 'chosen': True}, {'text': 'ગુજરાત', 'voters': 0, 'chosen': False}]}
#
# 2583
# message
# 2022-08-30T17:30:02
# 1661860802
# Quiz Bot
# user983000232
# {'question': '[22/101] ભારતમાં 73 મો બંધારણીય સુધારો કયા વર્ષથી અમલમાં મુકવામાં આવ્યો ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': '1994', 'voters': 0, 'chosen': False}, {'text': '1989', 'voters': 1, 'chosen': True}, {'text': '1998', 'voters': 0, 'chosen': False}, {'text': '1992', 'voters': 0, 'chosen': False}]}
#
# 2584
# message
# 2022-08-30T17:30:06
# 1661860806
# Quiz Bot
# user983000232
# {'question': '[23/101] ક્યા સત્યાગ્રહને ગુજરાતનો પ્રથમ સત્યાગ્રહ માનવામાં આવે છે ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'બારડોલી', 'voters': 0, 'chosen': False}, {'text': 'બોરસદ', 'voters': 0, 'chosen': False}, {'text': 'ખેડા', 'voters': 1, 'chosen': True}, {'text': 'અમદાવાદ', 'voters': 0, 'chosen': False}]}
#
# 2585
# message
# 2022-08-30T17:30:09
# 1661860809
# Quiz Bot
# user983000232
# {'question': '[24/101] ભારતમાં ટેલિકોમ ક્રાંતિ લાવવામાં ક્યા ગુજરાતીઓએ અગ્રણી ભૂમિકા ભજવી છે ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'જમશેદજી તાતા', 'voters': 0, 'chosen': False}, {'text': 'સામ પિત્રોડા', 'voters': 1, 'chosen': True}, {'text': 'મુકેશભાઈ અંબાણી', 'voters': 0, 'chosen': False}, {'text': 'ધીરુભાઈ અંબાણી', 'voters': 0, 'chosen': False}]}
#
# 2586
# message
# 2022-08-30T17:30:14
# 1661860814
# Quiz Bot
# user983000232
# {'question': '[25/101] સાક્ષર નગરી તરીકે કયું શહેર જાણીતું છે ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'નડિયાદ', 'voters': 0, 'chosen': False}, {'text': 'બોટાદ', 'voters': 1, 'chosen': True}, {'text': 'આણંદ', 'voters': 0, 'chosen': False}, {'text': 'ભાવનગર', 'voters': 0, 'chosen': False}]}
#
# 2587
# message
# 2022-08-30T17:30:17
# 1661860817
# Quiz Bot
# user983000232
# {'question': '[26/101] ચુડા તાલુકો ગુજરાત રાજ્યના કયા જિલ્લામાં આવેલો છે ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'બોટાદ', 'voters': 0, 'chosen': False}, {'text': 'રાજકોટ', 'voters': 1, 'chosen': True}, {'text': 'સુરેન્દ્રનગર', 'voters': 0, 'chosen': False}, {'text': 'ભાવનગર', 'voters': 0, 'chosen': False}]}
#
# 2588
# message
# 2022-08-30T17:30:20
# 1661860820
# Quiz Bot
# user983000232
# {'question': '[27/101] કેલ્સાઈટ ના ઉત્પાદન માં ગુજરાત સમગ્ર ભારતમાં કેટલામાં ક્રમે છે ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'પ્રથમ', 'voters': 0, 'chosen': False}, {'text': 'ત્રીજા', 'voters': 0, 'chosen': False}, {'text': 'બીજા', 'voters': 1, 'chosen': True}, {'text': 'ચોથા', 'voters': 0, 'chosen': False}]}
#
# 2589
# message
# 2022-08-30T17:30:22
# 1661860822
# Quiz Bot
# user983000232
# {'question': '[28/101] ગુજરાત ના કેટલા જિલ્લાઓ ની સરહદ દરિયા સાથે સંકળાયેલ છે ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': '14', 'voters': 0, 'chosen': False}, {'text': '16', 'voters': 0, 'chosen': False}, {'text': '13', 'voters': 1, 'chosen': True}, {'text': '15', 'voters': 0, 'chosen': False}]}
#
# 2590
# message
# 2022-08-30T17:30:25
# 1661860825
# Quiz Bot
# user983000232
# {'question': '[29/101] નિમ્નલિખિત પૈકી કઈ અખિલ ભારતીય સેવા નથી ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'ભારતીય પ્રશાસનિક સેવા', 'voters': 0, 'chosen': False}, {'text': 'ભારતીય પોલીસ સેવા', 'voters': 0, 'chosen': False}, {'text': 'ભારતીય વન  સેવા', 'voters': 1, 'chosen': True}, {'text': 'ભારતીય વિદેશ સેવા', 'voters': 0, 'chosen': False}]}
#
# 2591
# message
# 2022-08-30T17:30:28
# 1661860828
# Quiz Bot
# user983000232
# {'question': '[30/101] જુમો ભિસ્તી વાર્તા માં પાડા નું નામ શું છે ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'ભૂરો', 'voters': 0, 'chosen': False}, {'text': 'જુમો', 'voters': 0, 'chosen': False}, {'text': 'વેણુ', 'voters': 1, 'chosen': True}, {'text': 'રેણુ', 'voters': 0, 'chosen': False}]}
#
# 2593
# message
# 2022-08-30T17:30:31
# 1661860831
# Quiz Bot
# user983000232
# {'question': "[31/101] 'જેનામાં વૃક્ષ પ્રીતિ નથી તેનામાં જાણે કે જીવન પ્રીતિ જ નથી ' પંક્તિ નો અલંકાર ઓળખાવો ?", 'closed': True, 'total_voters': 1, 'answers': [{'text': 'ઉત્પ્રેક્ષા', 'voters': 0, 'chosen': False}, {'text': 'વનવાસ', 'voters': 1, 'chosen': True}, {'text': 'ઉપમા', 'voters': 0, 'chosen': False}, {'text': 'સ્નેહાધીન', 'voters': 0, 'chosen': False}]}
#
# 2594
# message
# 2022-08-30T17:30:38
# 1661860838
# Quiz Bot
# user983000232
# {'question': '[32/101] સન્યાસી સંધિનો ક્યો વિગ્રહ સાચો છે ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'સમ્ + નિ + _આસ્તી', 'voters': 0, 'chosen': False}, {'text': 'સન + ન્યાસી', 'voters': 0, 'chosen': False}, {'text': 'સ + નિ +\u200c યાસી', 'voters': 1, 'chosen': True}, {'text': 'સન્ની + યાસી', 'voters': 0, 'chosen': False}]}
#
# 2595
# message
# 2022-08-30T17:30:42
# 1661860842
# Quiz Bot
# user983000232
# {'question': '[33/101] વાવ તે લણે માટે સર્વનામ ના પ્રકાર દર્શાવો ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'દર્શક', 'voters': 0, 'chosen': False}, {'text': 'અન્યન્યવાચક', 'voters': 1, 'chosen': True}, {'text': 'સાપેક્ષ', 'voters': 0, 'chosen': False}, {'text': 'ત્રીજા પુરુષ', 'voters': 0, 'chosen': False}]}
#
# 2596
# message
# 2022-08-30T17:30:44
# 1661860844
# Quiz Bot
# user983000232
# {'question': '[34/101] થીગડું વાર્તા ના લેખક કોણ છે?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'ચંદ્રકાંત બક્ષી', 'voters': 0, 'chosen': False}, {'text': 'મધુરાય', 'voters': 1, 'chosen': True}, {'text': 'સુરેશ જોશી', 'voters': 0, 'chosen': False}, {'text': 'રઘુવીર ચૌધરી', 'voters': 0, 'chosen': False}]}
#
# 2597
# message
# 2022-08-30T17:30:47
# 1661860847
# Quiz Bot
# user983000232
# {'question': '[35/101] નીચેનામાંથી કયો સમાસ એકપદપ્રધાન નથી ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'દ્વન્દ્વ', 'voters': 0, 'chosen': False}, {'text': 'મધ્યમપદલોપી', 'voters': 1, 'chosen': True}, {'text': 'કર્મધારય', 'voters': 0, 'chosen': False}, {'text': 'ઉપપદ', 'voters': 0, 'chosen': False}]}
#
# 2598
# message
# 2022-08-30T17:30:50
# 1661860850
# Quiz Bot
# user983000232
# {'question': '[36/101] ભારતનો સંત્રી એટલે શું ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'હિંદ મહાસાગર', 'voters': 0, 'chosen': False}, {'text': 'હિમાલય પર્વત', 'voters': 1, 'chosen': True}, {'text': 'અરવલ્લી પર્વત', 'voters': 0, 'chosen': False}, {'text': 'કચ્છનો અખાત', 'voters': 0, 'chosen': False}]}
#
# 2599
# message
# 2022-08-30T17:30:52
# 1661860852
# Quiz Bot
# user983000232
# {'question': '[37/101] બનારસ હિંદુ વિશ્વવિદ્યાલયના સ્થાપક કોણ હતા ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'મદન મોહન માલવીયા', 'voters': 0, 'chosen': False}, {'text': 'બાળ ગંગાધર તિલક', 'voters': 1, 'chosen': True}, {'text': 'એની બેસન્ટ', 'voters': 0, 'chosen': False}, {'text': 'સરદાર પટેલ', 'voters': 0, 'chosen': False}]}
#
# 2600
# message
# 2022-08-30T17:30:55
# 1661860855
# Quiz Bot
# user983000232
# {'question': '[38/101] સંયુક્ત રાષ્ટ્ર ઔદ્યોગિક વિકાસ સંગઠનનું મુખ્યાલય કયાં આવેલું છે?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'સ્વિટઝર્લેન્ડ', 'voters': 0, 'chosen': False}, {'text': 'ન્યૂયોર્ક', 'voters': 0, 'chosen': False}, {'text': 'વિયેના', 'voters': 1, 'chosen': True}, {'text': 'વોશિગ્ટન ડી.સી.', 'voters': 0, 'chosen': False}]}
#
# 2601
# message
# 2022-08-30T17:30:58
# 1661860858
# Quiz Bot
# user983000232
# {'question': '[39/101] P,Q,R અને S ચાર ક્રમિક મહિના છે જો P અને S 30 દિવસો છે તો  S ક્યો મહિનો છે.?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'સપ્ટેમ્બર', 'voters': 0, 'chosen': False}, {'text': 'જૂન', 'voters': 1, 'chosen': True}, {'text': 'એપ્રિલ', 'voters': 0, 'chosen': False}, {'text': 'નવેમ્બર', 'voters': 0, 'chosen': False}]}
#
# 2602
# message
# 2022-08-30T17:31:01
# 1661860861
# Quiz Bot
# user983000232
# {'question': '[40/101] Will you mind ____ sitting there?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'My', 'voters': 1, 'chosen': True}, {'text': 'Me', 'voters': 0, 'chosen': False}, {'text': 'I', 'voters': 0, 'chosen': False}, {'text': 'Mine', 'voters': 0, 'chosen': False}]}
#
# 2604
# message
# 2022-08-30T17:31:03
# 1661860863
# Quiz Bot
# user983000232
# {'question': '[41/101] The dinner _____ before I arrived.', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'had been served', 'voters': 0, 'chosen': False}, {'text': 'had been served', 'voters': 1, 'chosen': True}, {'text': 'will be served', 'voters': 0, 'chosen': False}, {'text': 'has been served', 'voters': 0, 'chosen': False}]}
#
# 2605
# message
# 2022-08-30T17:31:07
# 1661860867
# Quiz Bot
# user983000232
# {'question': '[42/101] Find the uncountable noun', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'Book', 'voters': 0, 'chosen': False}, {'text': 'a swarm', 'voters': 0, 'chosen': False}, {'text': 'orange', 'voters': 1, 'chosen': True}, {'text': 'water', 'voters': 0, 'chosen': False}]}
#
# 2606
# message
# 2022-08-30T17:31:11
# 1661860871
# Quiz Bot
# user983000232
# {'question': '[43/101] Usual behaviour of a social group', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'fondle', 'voters': 0, 'chosen': False}, {'text': 'benevolence', 'voters': 1, 'chosen': True}, {'text': 'custom', 'voters': 0, 'chosen': False}, {'text': 'custems', 'voters': 0, 'chosen': False}]}
#
# 2607
# message
# 2022-08-30T17:31:14
# 1661860874
# Quiz Bot
# user983000232
# {'question': '[44/101] My brother lives ____ Jetpur.', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'On', 'voters': 0, 'chosen': False}, {'text': 'Into', 'voters': 0, 'chosen': False}, {'text': 'In', 'voters': 1, 'chosen': True}, {'text': 'At', 'voters': 0, 'chosen': False}]}
#
# 2608
# message
# 2022-08-30T17:31:17
# 1661860877
# Quiz Bot
# user983000232
# {'question': '[45/101] નીચેનામાંથી કયાં વિધાનો સાચાં છે?  \n1.ગુજરાતમાં પ્રાથમિક શાળામાં ફરજિયાત શિક્ષણ સયાજીરાવ ગાયકવાડ દ્વારા શરૂ કરાયું હતુ. \n2.સ્વામી દયાનંદ સરસ્વતી એ આર્ય સમાજની સ્થાપના કરી હતી.  3.મોહમ્મદ ગઝનવીએ સોમનાથ પર ચડાઈ કરી તે સમયે ભીમદેવ પ્રથમ ત્યાં રાજ કરતા હતા.', 'closed': True, 'total_voters': 1, 'answers': [{'text': '1, 2, 3', 'voters': 0, 'chosen': False}, {'text': '1 અને 2', 'voters': 1, 'chosen': True}, {'text': '2 અને 3', 'voters': 0, 'chosen': False}, {'text': '1 અને 3', 'voters': 0, 'chosen': False}]}
#
# 2609
# message
# 2022-08-30T17:31:19
# 1661860879
# Quiz Bot
# user983000232
# {'question': '[46/101] સવારે સૂર્યોદય બાદ રાજીવ એક થાંભલા સામે ઊભો હતો . થાંભલાનો પડછાયો તેની જમણી બાજુએ પડતો હતો તો તે કઈ દિશા માં મો રાખીને ઊભો હશે?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'ઉત્તર', 'voters': 0, 'chosen': False}, {'text': 'દક્ષિણ', 'voters': 0, 'chosen': False}, {'text': 'પૂર્વ', 'voters': 1, 'chosen': True}, {'text': 'પશ્ચિમ', 'voters': 0, 'chosen': False}]}
#
# 2610
# message
# 2022-08-30T17:31:22
# 1661860882
# Quiz Bot
# user983000232
# {'question': '[47/101] એક વેપારી 1 કિલોગ્રામ ને બદલે 1250 ગ્રામ દર્શાવતા વજનકાંટાનો ઉપયોગ કરે છે વધુમાં તે મૂળ કિંમત થી 20% જેટલી વધારે અંકિત રાખે છે તો નફાની ટકાવારી કેટલી થશે ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': '35%', 'voters': 0, 'chosen': False}, {'text': '45%', 'voters': 1, 'chosen': True}, {'text': '50%', 'voters': 0, 'chosen': False}, {'text': 'None', 'voters': 0, 'chosen': False}]}
#
# 2611
# message
# 2022-08-30T17:31:24
# 1661860884
# Quiz Bot
# user983000232
# {'question': '[48/101] એક સમબાજુ ચતુષ્કોણના વિકર્ણોની લંબાઈ 24 સેમી અને 10 સેમી હોય ,  તો તેના ક્ષેત્રફળ અને પરિમિતિનો ગુણોત્તર કેટલો થશે ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': '12:5', 'voters': 0, 'chosen': False}, {'text': '12:7', 'voters': 0, 'chosen': False}, {'text': '13:5', 'voters': 1, 'chosen': True}, {'text': 'None', 'voters': 0, 'chosen': False}]}
#
# 2612
# message
# 2022-08-30T17:31:27
# 1661860887
# Quiz Bot
# user983000232
# {'question': '[49/101] નીચે આપેલ શ્રેણી માં ખૂટતું પદ શોધો.\n12, 15, ____, 42, 69', 'closed': True, 'total_voters': 1, 'answers': [{'text': '18', 'voters': 0, 'chosen': False}, {'text': '26', 'voters': 1, 'chosen': True}, {'text': '28', 'voters': 0, 'chosen': False}, {'text': '27', 'voters': 0, 'chosen': False}]}
#
# 2613
# message
# 2022-08-30T17:31:30
# 1661860890
# Quiz Bot
# user983000232
# {'question': '[50/101] એક સાંકેતિક ભાષામાં RED નો સંકેત 2076 હોય તો GREEN નો સંકેત કયો હશે ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': '9207716', 'voters': 0, 'chosen': False}, {'text': '9197717', 'voters': 0, 'chosen': False}, {'text': '1677209', 'voters': 0, 'chosen': False}, {'text': '9207616', 'voters': 1, 'chosen': True}]}
#
# 2615
# message
# 2022-08-30T17:31:34
# 1661860894
# Quiz Bot
# user983000232
# {'question': '[51/101] મંદકન્તા છંદ નું બંધારણ ઓળખવો ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'ન ર મ ર સ લ ગા', 'voters': 0, 'chosen': False}, {'text': 'મ ભ ન ત ત ગા ગા', 'voters': 1, 'chosen': True}, {'text': 'મ ભ ન ત લ ગા ગા', 'voters': 0, 'chosen': False}, {'text': 'જ સ જ સ ય લ ગા', 'voters': 0, 'chosen': False}]}
#
# 2616
# message
# 2022-08-30T17:31:36
# 1661860896
# Quiz Bot
# user983000232
# {'question': '[52/101] નેશનલ રજીસ્ટર ઓફ સીટીઝન (NRC) ની સ્થાપના કયા રાજય માટે કરવામા આવી છે ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'અસમ', 'voters': 0, 'chosen': False}, {'text': 'બિહાર', 'voters': 1, 'chosen': True}, {'text': 'ગુજરાત', 'voters': 0, 'chosen': False}, {'text': 'રાજસ્થાન', 'voters': 0, 'chosen': False}]}
#
# 2617
# message
# 2022-08-30T17:31:41
# 1661860901
# Quiz Bot
# user983000232
# {'question': '[53/101] તાજેતરમા ક્યાં દેશમાં થયેલા સરકાર વિરોધી દેખાવોમાં આશરે 30 લોકો ના મોત થયા છે ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'ઈરાક', 'voters': 0, 'chosen': False}, {'text': 'પાકિસ્તાન', 'voters': 0, 'chosen': False}, {'text': 'અફઘાનિસ્તાન', 'voters': 1, 'chosen': True}, {'text': 'ઈરાન', 'voters': 0, 'chosen': False}]}
#
# 2618
# message
# 2022-08-30T17:31:45
# 1661860905
# Quiz Bot
# user983000232
# {'question': '[54/101] બિહુ નૃત્ય ક્યા રાજ્યનું છે?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'બંગાળ', 'voters': 0, 'chosen': False}, {'text': 'આસામ', 'voters': 0, 'chosen': False}, {'text': 'બિહાર', 'voters': 0, 'chosen': False}, {'text': 'ઓરિસ્સા', 'voters': 1, 'chosen': True}]}
#
# 2619
# message
# 2022-08-30T17:31:54
# 1661860914
# Quiz Bot
# user983000232
# {'question': '[55/101] ભારતે સૌપ્રથમ વખત અણુ ધડાકો ક્યા કર્યો હતો.?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'પોખરણ', 'voters': 0, 'chosen': False}, {'text': 'ચાંદીપુર', 'voters': 1, 'chosen': True}, {'text': 'શ્રી હરિકોટા', 'voters': 0, 'chosen': False}, {'text': 'થુંબા', 'voters': 0, 'chosen': False}]}
#
# 2620
# message
# 2022-08-30T17:31:58
# 1661860918
# Quiz Bot
# user983000232
# {'question': '[56/101] સ્વતંત્ર ભારતમાં પહેલી વાર  રૂ.5000 ની ચલણી નોટો ક્યારે બહાર પાડવામાં આવી હતી.', 'closed': True, 'total_voters': 1, 'answers': [{'text': '1950', 'voters': 0, 'chosen': False}, {'text': '1966', 'voters': 1, 'chosen': True}, {'text': '1960', 'voters': 0, 'chosen': False}, {'text': '1954', 'voters': 0, 'chosen': False}]}
#
# 2621
# message
# 2022-08-30T17:32:08
# 1661860928
# Quiz Bot
# user983000232
# {'question': '[57/101] મોઢેરાનું સૂર્યમંદિર ક્યા સોલંકી શાસકના સમયમાં બંધાવ્યું હતું?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'સિદ્ધરાજ જયસિંહ', 'voters': 0, 'chosen': False}, {'text': 'ભીમદેવ.1', 'voters': 1, 'chosen': True}, {'text': 'કુમારપાળ', 'voters': 0, 'chosen': False}, {'text': 'કર્ણદેવ', 'voters': 0, 'chosen': False}]}
#
# 2622
# message
# 2022-08-30T17:32:40
# 1661860960
# Quiz Bot
# user983000232
# {'question': '[58/101] ઉજ્જૈનનું પ્રાચીન નામ શું હતું?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'અવંતિકા', 'voters': 0, 'chosen': False}, {'text': 'ઈન્દ્રપ્રસ્થ', 'voters': 1, 'chosen': True}, {'text': 'નાલંદા', 'voters': 0, 'chosen': False}, {'text': 'તક્ષશિલા', 'voters': 0, 'chosen': False}]}
#
# 2623
# message
# 2022-08-30T17:32:47
# 1661860967
# Quiz Bot
# user983000232
# {'question': '[59/101] દાંડીકૂચની શરૂઆત થઈ ત્યારે પ્રથમ રાત્રિ નો વિરામ ક્યા લીધો હતો?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'લાલટ', 'voters': 0, 'chosen': False}, {'text': 'આલસી', 'voters': 1, 'chosen': True}, {'text': 'અલટ', 'voters': 0, 'chosen': False}, {'text': 'અસ્લાલી', 'voters': 0, 'chosen': False}]}
#
# 2624
# message
# 2022-08-30T17:32:51
# 1661860971
# Quiz Bot
# user983000232
# {'question': '[60/101] ભારતમાં ઉંમર આધારિત સ્ત્રી પુરુષ ગુણોત્તર ની  ગણતરી કરવાનું ક્યારથી શરૂ થયું?', 'closed': True, 'total_voters': 1, 'answers': [{'text': '1951', 'voters': 0, 'chosen': False}, {'text': '1961', 'voters': 1, 'chosen': True}, {'text': '1941', 'voters': 0, 'chosen': False}, {'text': '1971', 'voters': 0, 'chosen': False}]}
#
# 2625
# message
# 2022-08-30T17:32:55
# 1661860975
# Quiz Bot
# user983000232
# {'question': '[61/101] ઇન્ડિકા પુસ્તક ના રચયિતા કોણ છે ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'મેગેસ્થનીઝ', 'voters': 0, 'chosen': False}, {'text': 'કૌટિલ્ય', 'voters': 1, 'chosen': True}, {'text': 'ફફાન', 'voters': 0, 'chosen': False}, {'text': 'હુએન ત્યાંગ', 'voters': 0, 'chosen': False}]}
#
# 2626
# message
# 2022-08-30T17:32:58
# 1661860978
# Quiz Bot
# user983000232
# {'question': '[62/101] Wtok hard______you should fail.', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'So that', 'voters': 0, 'chosen': False}, {'text': 'And', 'voters': 0, 'chosen': False}, {'text': 'But', 'voters': 1, 'chosen': True}, {'text': 'Lest', 'voters': 0, 'chosen': False}]}
#
# 2627
# message
# 2022-08-30T17:33:04
# 1661860984
# Quiz Bot
# user983000232
# {'question': '[63/101] Give  synonyms of : contemplate', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'Meditate', 'voters': 0, 'chosen': False}, {'text': 'Condemn', 'voters': 1, 'chosen': True}, {'text': 'Menuplate', 'voters': 0, 'chosen': False}, {'text': 'None', 'voters': 0, 'chosen': False}]}
#
# 2628
# message
# 2022-08-30T17:33:08
# 1661860988
# Quiz Bot
# user983000232
# {'question': '[64/101] લઘુ વાંચવું એ કઈ કેળવણી નથી - કૃંદત નો પ્રકાર જણાવો', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'વિધ્યાથૅ કુંદત', 'voters': 0, 'chosen': False}, {'text': 'સબંધક કૃંદત', 'voters': 1, 'chosen': True}, {'text': 'ભવિષ્ય કૃંદત', 'voters': 0, 'chosen': False}, {'text': 'વર્તમાન કૃંદત', 'voters': 0, 'chosen': False}]}
#
# 2629
# message
# 2022-08-30T17:33:12
# 1661860992
# Quiz Bot
# user983000232
# {'question': '[65/101] વાછરડું જોયા વિના દૂધ દેહવા દેતી ગાય ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'અવલી', 'voters': 0, 'chosen': False}, {'text': 'ઝવલી', 'voters': 1, 'chosen': True}, {'text': 'રવલી', 'voters': 0, 'chosen': False}, {'text': 'કવલી', 'voters': 0, 'chosen': False}]}
#
# 2630
# message
# 2022-08-30T17:33:19
# 1661860999
# Quiz Bot
# user983000232
# {'question': '[66/101] ગુજરાતી ભાષાને અન્ય ભાષા જેવું ગૌરવ ન મળે ત્યાં સુધી પાઘડી ન પહેરવાની પ્રતિજ્ઞા કોણે લીધી હતી ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'દલપતરામ', 'voters': 0, 'chosen': False}, {'text': 'નર્મદ', 'voters': 1, 'chosen': True}, {'text': 'પ્રેમાનંદ', 'voters': 0, 'chosen': False}, {'text': 'શામળ', 'voters': 0, 'chosen': False}]}
#
# 2631
# message
# 2022-08-30T17:33:21
# 1661861001
# Quiz Bot
# user983000232
# {'question': '[67/101] કુસ્તીમાં ઓલમ્પિક મેડલ જીતનાર પ્રથમ ભારતિય મહિલા કોણ છે ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'પી વી સિંધુ', 'voters': 1, 'chosen': True}, {'text': 'સાક્ષી મલિક', 'voters': 0, 'chosen': False}, {'text': 'ગીતા ફોગટ', 'voters': 0, 'chosen': False}, {'text': 'દીપિકા કુમારી', 'voters': 0, 'chosen': False}]}
#
# 2632
# message
# 2022-08-30T17:33:26
# 1661861006
# Quiz Bot
# user983000232
# {'question': '[68/101] અસ્મિતા પર્વત કયા દિવસે ઉજવવામાં આવે છે ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'જન્માષ્ટમી', 'voters': 1, 'chosen': True}, {'text': 'મહાશિવરાત્રી', 'voters': 0, 'chosen': False}, {'text': 'હનુમાન જયંતી', 'voters': 0, 'chosen': False}, {'text': 'રામનોમવી', 'voters': 0, 'chosen': False}]}
#
# 2633
# message
# 2022-08-30T17:33:29
# 1661861009
# Quiz Bot
# user983000232
# {'question': '[69/101] નીતિ પંચના અધ્યક્ષ કોણ હોય છે ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'રાષ્ટ્રપતિ', 'voters': 1, 'chosen': True}, {'text': 'નાણામંત્રી', 'voters': 0, 'chosen': False}, {'text': 'વડાપ્રધાન', 'voters': 0, 'chosen': False}, {'text': 'ઉપરાષ્ટ્રપતિ', 'voters': 0, 'chosen': False}]}
#
# 2634
# message
# 2022-08-30T17:33:32
# 1661861012
# Quiz Bot
# user983000232
# {'question': '[70/101] ભારત સરકાર રમત-ગમતના કોચિંગ માટે કયા સર્વોચ્ચ એવોર્ડ એનાયત કરે છે ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'ગુરુ એવોર્ડ', 'voters': 1, 'chosen': True}, {'text': 'ખેલરત્ન એવોર્ડ', 'voters': 0, 'chosen': False}, {'text': 'અર્જુન એવોર્ડ', 'voters': 0, 'chosen': False}, {'text': 'દ્રોણાચાર્ય એવોર્ડ', 'voters': 0, 'chosen': False}]}
#
# 2636
# message
# 2022-08-30T17:33:38
# 1661861018
# Quiz Bot
# user983000232
# {'question': '[71/101] બનારસ હિંદુ વિશ્વવિદ્યાલયના સ્થાપક કોણ હતા ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'બાલ ગંગાધર તિલક', 'voters': 0, 'chosen': False}, {'text': 'મદન મોહન માલવીયા', 'voters': 1, 'chosen': True}, {'text': 'એની બેસન્ટ', 'voters': 0, 'chosen': False}, {'text': 'સરદાર પટેલ', 'voters': 0, 'chosen': False}]}
#
# 2637
# message
# 2022-08-30T17:33:44
# 1661861024
# Quiz Bot
# user983000232
# {'question': '[72/101] ભારતના પ્રથમ ગવર્નર જનરલ કોણ હતા ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'વિલિયમ બેન્ટિક', 'voters': 0, 'chosen': False}, {'text': 'લૉર્ડ વિલીઝન', 'voters': 1, 'chosen': True}, {'text': 'લૉર્ડ મૈકલ', 'voters': 0, 'chosen': False}, {'text': 'લૉર્ડ હેસ્ટિગ્જ', 'voters': 0, 'chosen': False}]}
#
# 2638
# message
# 2022-08-30T17:33:47
# 1661861027
# Quiz Bot
# user983000232
# {'question': '[73/101] CD ROM ડ્રાઈવર ની ગતિ____હોય છે?', 'closed': True, 'total_voters': 1, 'answers': [{'text': '40 ×', 'voters': 0, 'chosen': False}, {'text': '48 ×', 'voters': 1, 'chosen': True}, {'text': '52 ×', 'voters': 0, 'chosen': False}, {'text': 'બધા જ', 'voters': 0, 'chosen': False}]}
#
# 2639
# message
# 2022-08-30T17:33:50
# 1661861030
# Quiz Bot
# user983000232
# {'question': '[74/101] Winzip નામના ટૂલની મદદથી_______છે ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'સાઇઝ ઘટાડી શકાય', 'voters': 0, 'chosen': False}, {'text': 'ગુપ્તતા જળવાઈ', 'voters': 1, 'chosen': True}, {'text': 'એક કરતાં વધુ ફાઈલો ભેગી થાય', 'voters': 0, 'chosen': False}, {'text': 'એક પણ નહીં', 'voters': 0, 'chosen': False}]}
#
# 2640
# message
# 2022-08-30T17:33:53
# 1661861033
# Quiz Bot
# user983000232
# {'question': '[75/101] DVD સામાન્ય વધુમાં વધુ એક્સેસ દર _______ધરાવે છે ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': '5.3', 'voters': 0, 'chosen': False}, {'text': '8.3', 'voters': 1, 'chosen': True}, {'text': '6.3', 'voters': 0, 'chosen': False}, {'text': '9.3', 'voters': 0, 'chosen': False}]}
#
# 2641
# message
# 2022-08-30T17:33:56
# 1661861036
# Quiz Bot
# user983000232
# {'question': '[76/101] CNG માં મોટા ભાગે નીચેનામાંથી કયો વાયુ હોય ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'નાઇટ્રોજન', 'voters': 0, 'chosen': False}, {'text': 'ઓક્સિજન', 'voters': 0, 'chosen': False}, {'text': 'મીથેન', 'voters': 1, 'chosen': True}, {'text': 'હિલિયમ', 'voters': 0, 'chosen': False}]}
#
# 2642
# message
# 2022-08-30T17:33:59
# 1661861039
# Quiz Bot
# user983000232
# {'question': '[77/101] When he found the wallet is face glowed but soon it faded us the wallet was________', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'Recovered', 'voters': 0, 'chosen': False}, {'text': 'Empty', 'voters': 1, 'chosen': True}, {'text': 'Expensive', 'voters': 0, 'chosen': False}, {'text': 'Stoien', 'voters': 0, 'chosen': False}]}
#
# 2643
# message
# 2022-08-30T17:34:01
# 1661861041
# Quiz Bot
# user983000232
# {'question': '[78/101] તાજેતરમાં ક્યા દેશમાં થયેલા સરકાર વિરોધી દેખાવોમાં આશરે 30 લોકો ના મોત થયા છે ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'ઈરાક', 'voters': 0, 'chosen': False}, {'text': 'પાકિસ્તાન', 'voters': 1, 'chosen': True}, {'text': 'અફઘનિસ્તાન', 'voters': 0, 'chosen': False}, {'text': 'ઈરાન', 'voters': 0, 'chosen': False}]}
#
# 2644
# message
# 2022-08-30T17:34:07
# 1661861047
# Quiz Bot
# user983000232
# {'question': '[79/101] The police made him_________his crime.', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'Confess', 'voters': 0, 'chosen': False}, {'text': 'Confessed', 'voters': 0, 'chosen': False}, {'text': 'To confess', 'voters': 1, 'chosen': True}, {'text': 'confesses', 'voters': 0, 'chosen': False}]}
#
# 2645
# message
# 2022-08-30T17:34:10
# 1661861050
# Quiz Bot
# user983000232
# {'question': '[80/101] You and I are doing our work, ________ ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'Are we', 'voters': 0, 'chosen': False}, {'text': "Aren't you", 'voters': 1, 'chosen': True}, {'text': "Aren't me", 'voters': 0, 'chosen': False}, {'text': "Aren't i", 'voters': 0, 'chosen': False}]}
#
# 2647
# message
# 2022-08-30T17:34:16
# 1661861056
# Quiz Bot
# user983000232
# {'question': '[81/101] Shraddha_______since afternoon.', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'Has been working', 'voters': 0, 'chosen': False}, {'text': 'Is working', 'voters': 1, 'chosen': True}, {'text': 'Works', 'voters': 0, 'chosen': False}, {'text': 'Was working', 'voters': 0, 'chosen': False}]}
#
# 2648
# message
# 2022-08-30T17:34:27
# 1661861067
# Quiz Bot
# user983000232
# {'question': '[82/101] લગ્ન વખતે કન્યાને પહેરવાનું વસ્ત્ર શબ્દ સમૂહ માટે નો એક શબ્દ કયો ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'પાલવ', 'voters': 0, 'chosen': False}, {'text': 'મીઢણ', 'voters': 1, 'chosen': True}, {'text': 'પાનેતર', 'voters': 0, 'chosen': False}, {'text': 'સાડી', 'voters': 0, 'chosen': False}]}
#
# 2649
# message
# 2022-08-30T17:34:35
# 1661861075
# Quiz Bot
# user983000232
# {'question': '[83/101] મધ્યકાલીન ગુજરાતી સાહિત્યમાં સૌથી વધુ લોક પ્રિય પદ્યવાર્તાકાર તરીકે કોણ પ્રસિદ્ધ છે ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'પ્રેમાનંદ', 'voters': 0, 'chosen': False}, {'text': 'ભોજા ભગત', 'voters': 1, 'chosen': True}, {'text': 'ભાલણ', 'voters': 0, 'chosen': False}, {'text': 'શામળ', 'voters': 0, 'chosen': False}]}
#
# 2650
# message
# 2022-08-30T17:34:42
# 1661861082
# Quiz Bot
# user983000232
# {'question': '[84/101] ઉંબરે ઊભી સાંભળું રે બોલ વાલમના ગીત લખનાર ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'મણિલાલ દેસાઈ', 'voters': 0, 'chosen': False}, {'text': 'મણિલાલ વેગડ', 'voters': 1, 'chosen': True}, {'text': 'મનસુખલાલ', 'voters': 0, 'chosen': False}, {'text': 'મહિપત ભાઈ', 'voters': 0, 'chosen': False}]}
#
# 2651
# message
# 2022-08-30T17:34:46
# 1661861086
# Quiz Bot
# user983000232
# {'question': '[85/101] ભારતની પ્રથમ વોટર ટેપ નો પ્રારંભ ક્યારે થયો ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'મુંબઈ', 'voters': 0, 'chosen': False}, {'text': 'દિલ્હી', 'voters': 1, 'chosen': True}, {'text': 'અમદાવાદ', 'voters': 0, 'chosen': False}, {'text': 'હૈદરાબાદ', 'voters': 0, 'chosen': False}]}
#
# 2652
# message
# 2022-08-30T17:34:48
# 1661861088
# Quiz Bot
# user983000232
# {'question': '[86/101] Ipl પીએમ કોલકાતા નાઇટ રાઇડર્સના કેપ્ટન તરીકે કોની પસંદગી કરવામાં આવી છે ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'યુસુફ પઠાણ', 'voters': 0, 'chosen': False}, {'text': 'ભુનેશ્વર', 'voters': 1, 'chosen': True}, {'text': 'મહેન્દ્રસિંહ ધોની', 'voters': 0, 'chosen': False}, {'text': 'શ્રેયસ ઐયર', 'voters': 0, 'chosen': False}]}
#
# 2653
# message
# 2022-08-30T17:34:52
# 1661861092
# Quiz Bot
# user983000232
# {'question': '[87/101] 16 ફેબ્રુઆરી 2020 ના રોજ ગુરુ રવિદાસ ની કેટલામી જન્મ જયંતી ઉજવાય ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': '653', 'voters': 0, 'chosen': False}, {'text': '650', 'voters': 0, 'chosen': False}, {'text': '645', 'voters': 1, 'chosen': True}, {'text': '655', 'voters': 0, 'chosen': False}]}
#
# 2654
# message
# 2022-08-30T17:34:57
# 1661861097
# Quiz Bot
# user983000232
# {'question': '[88/101] રાષ્ટ્રીય ઉત્પાદકતા દિવસ ક્યારે ઉજવવામાં આવે છે ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': '12 ફેબ્રુઆરી', 'voters': 0, 'chosen': False}, {'text': '8 માર્ચ', 'voters': 1, 'chosen': True}, {'text': '10 ફેબ્રુઆરી', 'voters': 0, 'chosen': False}, {'text': '20 ફેબ્રુઆરી', 'voters': 0, 'chosen': False}]}
#
# 2655
# message
# 2022-08-30T17:35:00
# 1661861100
# Quiz Bot
# user983000232
# {'question': '[89/101] I really enjoy______ the poor.', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'Help', 'voters': 0, 'chosen': False}, {'text': 'Helped', 'voters': 1, 'chosen': True}, {'text': 'Helping', 'voters': 0, 'chosen': False}, {'text': 'Will help', 'voters': 0, 'chosen': False}]}
#
# 2656
# message
# 2022-08-30T17:35:02
# 1661861102
# Quiz Bot
# user983000232
# {'question': "[90/101] Don't _______ your time, otherwise you can't progress in life.", 'closed': True, 'total_voters': 1, 'answers': [{'text': 'Waste', 'voters': 0, 'chosen': False}, {'text': 'Start', 'voters': 1, 'chosen': True}, {'text': 'Lose', 'voters': 0, 'chosen': False}, {'text': 'Spoil', 'voters': 0, 'chosen': False}]}
#
# 2658
# message
# 2022-08-30T17:35:06
# 1661861106
# Quiz Bot
# user983000232
# {'question': '[91/101] સક્રિય રોના પ્રથમ સેલ પર જવા માટે નીચેનામાંથી ____કી વપરાય છે  ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'END', 'voters': 0, 'chosen': False}, {'text': 'HOME', 'voters': 1, 'chosen': True}, {'text': 'TAB', 'voters': 0, 'chosen': False}, {'text': 'ESC', 'voters': 0, 'chosen': False}]}
#
# 2659
# message
# 2022-08-30T17:35:10
# 1661861110
# Quiz Bot
# user983000232
# {'question': '[92/101] To run after someone is________', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'Marathen', 'voters': 0, 'chosen': False}, {'text': 'Race', 'voters': 1, 'chosen': True}, {'text': 'Follo', 'voters': 0, 'chosen': False}, {'text': 'Chase', 'voters': 0, 'chosen': False}]}
#
# 2660
# message
# 2022-08-30T17:35:15
# 1661861115
# Quiz Bot
# user983000232
# {'question': '[93/101] Kusum father was_________ London last month.', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'Had', 'voters': 0, 'chosen': False}, {'text': 'Gone', 'voters': 0, 'chosen': False}, {'text': 'In', 'voters': 1, 'chosen': True}, {'text': 'From', 'voters': 0, 'chosen': False}]}
#
# 2661
# message
# 2022-08-30T17:35:18
# 1661861118
# Quiz Bot
# user983000232
# {'question': '[94/101] Find nearly opposite meaning : monarchy', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'Kingdom', 'voters': 0, 'chosen': False}, {'text': 'Democracy', 'voters': 1, 'chosen': True}, {'text': 'Freedom', 'voters': 0, 'chosen': False}, {'text': 'Strong rule', 'voters': 0, 'chosen': False}]}
#
# 2662
# message
# 2022-08-30T17:35:22
# 1661861122
# Quiz Bot
# user983000232
# {'question': '[95/101] રેફ્રિજરેટરમાં કુલન્ટ રૂપે______ગેસનો ઉપયોગ થાય છે ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'એમોનીયા', 'voters': 0, 'chosen': False}, {'text': 'કાર્બન ડાયોક્સાઇડ', 'voters': 0, 'chosen': False}, {'text': 'હિલિયમ', 'voters': 1, 'chosen': True}, {'text': 'નાઇટ્રોજન', 'voters': 0, 'chosen': False}]}
#
# 2663
# message
# 2022-08-30T17:35:29
# 1661861129
# Quiz Bot
# user983000232
# {'question': '[96/101] પાણીની ઘનતા સૌથી વધુ હોય છે ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': '100સે પર', 'voters': 0, 'chosen': False}, {'text': '0સે પર', 'voters': 0, 'chosen': False}, {'text': '-4સે પર', 'voters': 1, 'chosen': True}, {'text': '4સે પર', 'voters': 0, 'chosen': False}]}
#
# 2664
# message
# 2022-08-30T17:35:32
# 1661861132
# Quiz Bot
# user983000232
# {'question': '[97/101] પસંદ કરેલ 7 આડી રો તથા 9 ઊભી હરોળ ની હદ માટે એડ્રેસ બોક્સમાં _____ લખાશે   ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': '9C7R', 'voters': 0, 'chosen': False}, {'text': '9R × 7C', 'voters': 0, 'chosen': False}, {'text': '79RC', 'voters': 1, 'chosen': True}, {'text': '7R × 9C', 'voters': 0, 'chosen': False}]}
#
# 2665
# message
# 2022-08-30T17:35:35
# 1661861135
# Quiz Bot
# user983000232
# {'question': '[98/101] ભારતમાં ગ્રુહ વપરાશ માટે AC વોલ્ટેજ નું મૂલ્ય અને આવૃત્તિ શું છે ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': '110 v, 60 Hz', 'voters': 0, 'chosen': False}, {'text': '110 v, 50 Hz', 'voters': 0, 'chosen': False}, {'text': '220 v, 50 Hz', 'voters': 1, 'chosen': True}, {'text': '220 v, 60 Hz', 'voters': 0, 'chosen': False}]}
#
# 2666
# message
# 2022-08-30T17:35:38
# 1661861138
# Quiz Bot
# user983000232
# {'question': '[99/101] નીચેના માંથી એરીથમેટિક ઓપરેશન. ક્યાં.?', 'closed': True, 'total_voters': 1, 'answers': [{'text': '+  અને  -', 'voters': 0, 'chosen': False}, {'text': '%  અને  <', 'voters': 0, 'chosen': False}, {'text': '*  અને  ?', 'voters': 1, 'chosen': True}, {'text': 'તમામ', 'voters': 0, 'chosen': False}]}
#
# 2667
# message
# 2022-08-30T17:35:41
# 1661861141
# Quiz Bot
# user983000232
# {'question': '[100/101] સ્વાવલંબી પોષણ પદ્ધત્તિ માં શાની જરૂર હોય છે ?', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'CO² અને પાણી', 'voters': 0, 'chosen': False}, {'text': 'કલોરોફિલ', 'voters': 0, 'chosen': False}, {'text': 'સૂર્ય પ્રકાશ', 'voters': 1, 'chosen': True}, {'text': 'ત્રણેય', 'voters': 0, 'chosen': False}]}

# %%
q=[]
o1=[]
o2=[]
o3=[]
o4=[]
for i in range(0,101):
    print(dict2[i]['poll']["question"][8:])
    q.append(dict2[i]['poll']["question"][8:])
    
    print((dict2[i]['poll']["answers"][0]["text"]))
    
    o1.append(dict2[i]['poll']["answers"][0]["text"])
    
    if (len(dict2[i]['poll']["answers"]))>1:
        o2.append(dict2[i]['poll']["answers"][1]["text"])
    else:
        o2.append("-")
    pdf.cell(200, 10, txt = o1[i]) 
    if len(dict2[i]['poll']["answers"])>2:
        o3.append(dict2[i]['poll']["answers"][2]["text"])
    else:
        o3.append("-")
    pdf.cell(200, 10, txt = o3[i]) 
    if len(dict2[i]['poll']["answers"])>3:   
        o4.append(dict2[i]['poll']["answers"][3]["text"])
    else:
        o4.append("-")
    pdf.cell(200, 10, txt = o4[i]) 
pdf.output("GF1G.pdf")
# Out:
# કવિ રમેશ પારેખનો જન્મ ક્યાં થયો હતો?
# અમરેલી
# અમરતકાકી – કઈ કૃતિનું પાત્ર છે?
# જનમટીપ
# ગોપાળબાપા’ પ્રકરણ કઈ નવલકથામાંથી લેવામાં આવ્યું છે?
# દીપ નિર્વાણ
# નીચેનામાંથી ખોટી સંધિ જણાવો.
# કવીશ્વર = કવિ + ઈશ્વર
# એક સમાંતર શ્રેણીનું પ્રથમ પદ 5 અને છેલ્લું પદ 45 છે અને બધા પદોનો સરવાળો 500 હોય તો પદોની સંખ્યા કેટલી હશે?
# 19
# વેપારી પોતાના માલ પર 20% અને 10% એમ બે ક્રમિક વળતર આપે છે. પરિણામી વળતર કેટલું થાય?
# 30
# રાહીનું સ્થાન વર્ગમાં ઉપરથી 16મું અને નીચેથી 24મું છે, તો વર્ગમાં કુલ કેટલા વિદ્યાર્થીઓ હશે?
# 41
# શ્રેણી -6, ૩, 0નો સામાન્ય તફાવત _____ છે.
# 3
# 14 કારીગરોનો 10 દિવસનો પગાર 22,400 રૂ. છે તો 16 કારીગરોનો 16 દિવસનો પગાર કેટલો થાય?
# 20480
#  નીચેનામાંથી કયો શબ્દ તત્પુરુષ સમાસ નથી?
# દેશપ્રેમ
#  સાંઢ નાથ્યો’ પ્રકરણ કઈ નવલકથામાંથી લેવામાં આવ્યું છે
# ભવસાગર
#  નીચેનામાંથી કયો શબ્દ કર્મધારય સમાસ છે?
# પૃથ્વી
#  ભારતના બંધારણના નીચેના પૈકી ક્યા અનુચ્છેદો સંઘ અને રાજ્યો વચ્ચેના વહીવટી સબંધો બાબતના છે?
# અનુ. 245 – 255
#  ભારતની રાષ્ટ્રપતિની ચૂંટણીમાંદરેક સંસદ સભ્યના મતનું મૂલ્ય કેટલું છે?
# 708
#  16 ડિસેમ્બર, 2017ના રોજ વડાપ્રધાન શ્રી નરેન્દ્રભાઈ મોદીએ ક્યા રાજ્યમાં ગરીબોને મફત વીજળી આપવાની જાહેરાત કરી હતી?
# ઓરિસ્સા
#  ભારતમાં ઉપરાષ્ટ્રપતિ હોદ્દાની રૂએ…
# લોકસભાના અધ્યક્ષ બને છે
#  Change into passive voice : “They asked me my name”
# My name is asked by them
#  Give synonym of ‘poison’
# elixir
#  Choose odd one out :
# Odour
#  ભારતમાં મ્યુનિસિપલ ગવર્નર ક્યા વર્ષથી અસ્તિત્વમાં આવ્યું?
# 1961
#  પંચાયતી રાજ પ્રણાલીનો અમલ પ્રથમ કયા રાજ્યમાં થયો ?
# રાજસ્થાન
#  ભારતમાં 73 મો બંધારણીય સુધારો કયા વર્ષથી અમલમાં મુકવામાં આવ્યો ?
# 1994
#  ક્યા સત્યાગ્રહને ગુજરાતનો પ્રથમ સત્યાગ્રહ માનવામાં આવે છે ?
# બારડોલી
#  ભારતમાં ટેલિકોમ ક્રાંતિ લાવવામાં ક્યા ગુજરાતીઓએ અગ્રણી ભૂમિકા ભજવી છે ?
# જમશેદજી તાતા
#  સાક્ષર નગરી તરીકે કયું શહેર જાણીતું છે ?
# નડિયાદ
#  ચુડા તાલુકો ગુજરાત રાજ્યના કયા જિલ્લામાં આવેલો છે ?
# બોટાદ
#  કેલ્સાઈટ ના ઉત્પાદન માં ગુજરાત સમગ્ર ભારતમાં કેટલામાં ક્રમે છે ?
# પ્રથમ
#  ગુજરાત ના કેટલા જિલ્લાઓ ની સરહદ દરિયા સાથે સંકળાયેલ છે ?
# 14
#  નિમ્નલિખિત પૈકી કઈ અખિલ ભારતીય સેવા નથી ?
# ભારતીય પ્રશાસનિક સેવા
#  જુમો ભિસ્તી વાર્તા માં પાડા નું નામ શું છે ?
# ભૂરો
#  'જેનામાં વૃક્ષ પ્રીતિ નથી તેનામાં જાણે કે જીવન પ્રીતિ જ નથી ' પંક્તિ નો અલંકાર ઓળખાવો ?
# ઉત્પ્રેક્ષા
#  સન્યાસી સંધિનો ક્યો વિગ્રહ સાચો છે ?
# સમ્ + નિ + _આસ્તી
#  વાવ તે લણે માટે સર્વનામ ના પ્રકાર દર્શાવો ?
# દર્શક
#  થીગડું વાર્તા ના લેખક કોણ છે?
# ચંદ્રકાંત બક્ષી
#  નીચેનામાંથી કયો સમાસ એકપદપ્રધાન નથી ?
# દ્વન્દ્વ
#  ભારતનો સંત્રી એટલે શું ?
# હિંદ મહાસાગર
#  બનારસ હિંદુ વિશ્વવિદ્યાલયના સ્થાપક કોણ હતા ?
# મદન મોહન માલવીયા
#  સંયુક્ત રાષ્ટ્ર ઔદ્યોગિક વિકાસ સંગઠનનું મુખ્યાલય કયાં આવેલું છે?
# સ્વિટઝર્લેન્ડ
#  P,Q,R અને S ચાર ક્રમિક મહિના છે જો P અને S 30 દિવસો છે તો  S ક્યો મહિનો છે.?
# સપ્ટેમ્બર
#  Will you mind ____ sitting there?
# My
#  The dinner _____ before I arrived.
# had been served
#  Find the uncountable noun
# Book
#  Usual behaviour of a social group
# fondle
#  My brother lives ____ Jetpur.
# On
#  નીચેનામાંથી કયાં વિધાનો સાચાં છે?
# 1.ગુજરાતમાં પ્રાથમિક શાળામાં ફરજિયાત શિક્ષણ સયાજીરાવ ગાયકવાડ દ્વારા શરૂ કરાયું હતુ.
# 2.સ્વામી દયાનંદ સરસ્વતી એ આર્ય સમાજની સ્થાપના કરી હતી.  3.મોહમ્મદ ગઝનવીએ સોમનાથ પર ચડાઈ કરી તે સમયે ભીમદેવ પ્રથમ ત્યાં રાજ કરતા હતા.
# 1, 2, 3
#  સવારે સૂર્યોદય બાદ રાજીવ એક થાંભલા સામે ઊભો હતો . થાંભલાનો પડછાયો તેની જમણી બાજુએ પડતો હતો તો તે કઈ દિશા માં મો રાખીને ઊભો હશે?
# ઉત્તર
#  એક વેપારી 1 કિલોગ્રામ ને બદલે 1250 ગ્રામ દર્શાવતા વજનકાંટાનો ઉપયોગ કરે છે વધુમાં તે મૂળ કિંમત થી 20% જેટલી વધારે અંકિત રાખે છે તો નફાની ટકાવારી કેટલી થશે ?
# 35%
#  એક સમબાજુ ચતુષ્કોણના વિકર્ણોની લંબાઈ 24 સેમી અને 10 સેમી હોય ,  તો તેના ક્ષેત્રફળ અને પરિમિતિનો ગુણોત્તર કેટલો થશે ?
# 12:5
#  નીચે આપેલ શ્રેણી માં ખૂટતું પદ શોધો.
# 12, 15, ____, 42, 69
# 18
#  એક સાંકેતિક ભાષામાં RED નો સંકેત 2076 હોય તો GREEN નો સંકેત કયો હશે ?
# 9207716
#  મંદકન્તા છંદ નું બંધારણ ઓળખવો ?
# ન ર મ ર સ લ ગા
#  નેશનલ રજીસ્ટર ઓફ સીટીઝન (NRC) ની સ્થાપના કયા રાજય માટે કરવામા આવી છે ?
# અસમ
#  તાજેતરમા ક્યાં દેશમાં થયેલા સરકાર વિરોધી દેખાવોમાં આશરે 30 લોકો ના મોત થયા છે ?
# ઈરાક
#  બિહુ નૃત્ય ક્યા રાજ્યનું છે?
# બંગાળ
#  ભારતે સૌપ્રથમ વખત અણુ ધડાકો ક્યા કર્યો હતો.?
# પોખરણ
#  સ્વતંત્ર ભારતમાં પહેલી વાર  રૂ.5000 ની ચલણી નોટો ક્યારે બહાર પાડવામાં આવી હતી.
# 1950
#  મોઢેરાનું સૂર્યમંદિર ક્યા સોલંકી શાસકના સમયમાં બંધાવ્યું હતું?
# સિદ્ધરાજ જયસિંહ
#  ઉજ્જૈનનું પ્રાચીન નામ શું હતું?
# અવંતિકા
#  દાંડીકૂચની શરૂઆત થઈ ત્યારે પ્રથમ રાત્રિ નો વિરામ ક્યા લીધો હતો?
# લાલટ
#  ભારતમાં ઉંમર આધારિત સ્ત્રી પુરુષ ગુણોત્તર ની  ગણતરી કરવાનું ક્યારથી શરૂ થયું?
# 1951
#  ઇન્ડિકા પુસ્તક ના રચયિતા કોણ છે ?
# મેગેસ્થનીઝ
#  Wtok hard______you should fail.
# So that
#  Give  synonyms of : contemplate
# Meditate
#  લઘુ વાંચવું એ કઈ કેળવણી નથી - કૃંદત નો પ્રકાર જણાવો
# વિધ્યાથૅ કુંદત
#  વાછરડું જોયા વિના દૂધ દેહવા દેતી ગાય ?
# અવલી
#  ગુજરાતી ભાષાને અન્ય ભાષા જેવું ગૌરવ ન મળે ત્યાં સુધી પાઘડી ન પહેરવાની પ્રતિજ્ઞા કોણે લીધી હતી ?
# દલપતરામ
#  કુસ્તીમાં ઓલમ્પિક મેડલ જીતનાર પ્રથમ ભારતિય મહિલા કોણ છે ?
# પી વી સિંધુ
#  અસ્મિતા પર્વત કયા દિવસે ઉજવવામાં આવે છે ?
# જન્માષ્ટમી
#  નીતિ પંચના અધ્યક્ષ કોણ હોય છે ?
# રાષ્ટ્રપતિ
#  ભારત સરકાર રમત-ગમતના કોચિંગ માટે કયા સર્વોચ્ચ એવોર્ડ એનાયત કરે છે ?
# ગુરુ એવોર્ડ
#  બનારસ હિંદુ વિશ્વવિદ્યાલયના સ્થાપક કોણ હતા ?
# બાલ ગંગાધર તિલક
#  ભારતના પ્રથમ ગવર્નર જનરલ કોણ હતા ?
# વિલિયમ બેન્ટિક
#  CD ROM ડ્રાઈવર ની ગતિ____હોય છે?
# 40 ×
#  Winzip નામના ટૂલની મદદથી_______છે ?
# સાઇઝ ઘટાડી શકાય
#  DVD સામાન્ય વધુમાં વધુ એક્સેસ દર _______ધરાવે છે ?
# 5.3
#  CNG માં મોટા ભાગે નીચેનામાંથી કયો વાયુ હોય ?
# નાઇટ્રોજન
#  When he found the wallet is face glowed but soon it faded us the wallet was________
# Recovered
#  તાજેતરમાં ક્યા દેશમાં થયેલા સરકાર વિરોધી દેખાવોમાં આશરે 30 લોકો ના મોત થયા છે ?
# ઈરાક
#  The police made him_________his crime.
# Confess
#  You and I are doing our work, ________ ?
# Are we
#  Shraddha_______since afternoon.
# Has been working
#  લગ્ન વખતે કન્યાને પહેરવાનું વસ્ત્ર શબ્દ સમૂહ માટે નો એક શબ્દ કયો ?
# પાલવ
#  મધ્યકાલીન ગુજરાતી સાહિત્યમાં સૌથી વધુ લોક પ્રિય પદ્યવાર્તાકાર તરીકે કોણ પ્રસિદ્ધ છે ?
# પ્રેમાનંદ
#  ઉંબરે ઊભી સાંભળું રે બોલ વાલમના ગીત લખનાર ?
# મણિલાલ દેસાઈ
#  ભારતની પ્રથમ વોટર ટેપ નો પ્રારંભ ક્યારે થયો ?
# મુંબઈ
#  Ipl પીએમ કોલકાતા નાઇટ રાઇડર્સના કેપ્ટન તરીકે કોની પસંદગી કરવામાં આવી છે ?
# યુસુફ પઠાણ
#  16 ફેબ્રુઆરી 2020 ના રોજ ગુરુ રવિદાસ ની કેટલામી જન્મ જયંતી ઉજવાય ?
# 653
#  રાષ્ટ્રીય ઉત્પાદકતા દિવસ ક્યારે ઉજવવામાં આવે છે ?
# 12 ફેબ્રુઆરી
#  I really enjoy______ the poor.
# Help
#  Don't _______ your time, otherwise you can't progress in life.
# Waste
#  સક્રિય રોના પ્રથમ સેલ પર જવા માટે નીચેનામાંથી ____કી વપરાય છે  ?
# END
#  To run after someone is________
# Marathen
#  Kusum father was_________ London last month.
# Had
#  Find nearly opposite meaning : monarchy
# Kingdom
#  રેફ્રિજરેટરમાં કુલન્ટ રૂપે______ગેસનો ઉપયોગ થાય છે ?
# એમોનીયા
#  પાણીની ઘનતા સૌથી વધુ હોય છે ?
# 100સે પર
#  પસંદ કરેલ 7 આડી રો તથા 9 ઊભી હરોળ ની હદ માટે એડ્રેસ બોક્સમાં _____ લખાશે   ?
# 9C7R
#  ભારતમાં ગ્રુહ વપરાશ માટે AC વોલ્ટેજ નું મૂલ્ય અને આવૃત્તિ શું છે ?
# 110 v, 60 Hz
#  નીચેના માંથી એરીથમેટિક ઓપરેશન. ક્યાં.?
# +  અને  -
# ] સ્વાવલંબી પોષણ પદ્ધત્તિ માં શાની જરૂર હોય છે ?
# CO² અને પાણી
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_40/2251032501.py in <module>
#       5 o4=[]
#       6 for i in range(0,101):
# ----> 7     print(dict2[i]['poll']["question"][8:])
#       8     q.append(dict2[i]['poll']["question"][8:])
#       9
#
# IndexError: list index out of range

# %%
dict2[4]['poll']["answers"][1]["text"]
# Out:
# '22'

# %%
o1
# Out:
# ['અમરેલી',
#  'જનમટીપ',
#  'દીપ નિર્વાણ',
#  'કવીશ્વર = કવિ + ઈશ્વર',
#  '19',
#  '30',
#  '41',
#  '3',
#  '20480',
#  'દેશપ્રેમ',
#  'ભવસાગર',
#  'પૃથ્વી',
#  'અનુ. 245 – 255',
#  '708',
#  'ઓરિસ્સા',
#  'લોકસભાના અધ્યક્ષ બને છે',
#  'My name is asked by them',
#  'elixir',
#  'Odour',
#  '1961',
#  'રાજસ્થાન',
#  '1994',
#  'બારડોલી',
#  'જમશેદજી તાતા',
#  'નડિયાદ',
#  'બોટાદ',
#  'પ્રથમ',
#  '14',
#  'ભારતીય પ્રશાસનિક સેવા',
#  'ભૂરો',
#  'ઉત્પ્રેક્ષા',
#  'સમ્ + નિ + _આસ્તી',
#  'દર્શક',
#  'ચંદ્રકાંત બક્ષી',
#  'દ્વન્દ્વ',
#  'હિંદ મહાસાગર',
#  'મદન મોહન માલવીયા',
#  'સ્વિટઝર્લેન્ડ',
#  'સપ્ટેમ્બર',
#  'My',
#  'had been served',
#  'Book',
#  'fondle',
#  'On',
#  '1, 2, 3',
#  'ઉત્તર',
#  '35%',
#  '12:5',
#  '18',
#  '9207716',
#  'ન ર મ ર સ લ ગા',
#  'અસમ',
#  'ઈરાક',
#  'બંગાળ',
#  'પોખરણ',
#  '1950',
#  'સિદ્ધરાજ જયસિંહ',
#  'અવંતિકા',
#  'લાલટ',
#  '1951',
#  'મેગેસ્થનીઝ',
#  'So that',
#  'Meditate',
#  'વિધ્યાથૅ કુંદત',
#  'અવલી',
#  'દલપતરામ',
#  'પી વી સિંધુ',
#  'જન્માષ્ટમી',
#  'રાષ્ટ્રપતિ',
#  'ગુરુ એવોર્ડ',
#  'બાલ ગંગાધર તિલક',
#  'વિલિયમ બેન્ટિક',
#  '40 ×',
#  'સાઇઝ ઘટાડી શકાય',
#  '5.3',
#  'નાઇટ્રોજન',
#  'Recovered',
#  'ઈરાક',
#  'Confess',
#  'Are we',
#  'Has been working',
#  'પાલવ',
#  'પ્રેમાનંદ',
#  'મણિલાલ દેસાઈ',
#  'મુંબઈ',
#  'યુસુફ પઠાણ',
#  '653',
#  '12 ફેબ્રુઆરી',
#  'Help',
#  'Waste',
#  'END',
#  'Marathen',
#  'Had',
#  'Kingdom',
#  'એમોનીયા',
#  '100સે પર',
#  '9C7R',
#  '110 v, 60 Hz',
#  '+  અને  -',
#  'CO² અને પાણી']

# %%
import pandas as pd

# %%
from fpdf import FPDF
pdf = FPDF()
 
# Add a page
pdf.add_page()
pdf.set_font("Arial", size = 15)

pdf.cell(200, 10, txt = "GeeksforGeeks")
pdf.output("GFG.pdf")
# Out:
# ''

# %%
# dictionary of lists 
dict8 = {'Question': q, 'option1': o1,'option2': o2,'option3': o3,'option4': o4 } 
    
df = pd.DataFrame(dict8)
    
df
# Out:
#                                              Question                option1  \
# 0                કવિ રમેશ પારેખનો જન્મ ક્યાં થયો હતો?                 અમરેલી
# 1                     અમરતકાકી – કઈ કૃતિનું પાત્ર છે?                 જનમટીપ
# 2   ગોપાળબાપા’ પ્રકરણ કઈ નવલકથામાંથી લેવામાં આવ્યુ...            દીપ નિર્વાણ
# 3                        નીચેનામાંથી ખોટી સંધિ જણાવો.  કવીશ્વર = કવિ + ઈશ્વર
# 4   એક સમાંતર શ્રેણીનું પ્રથમ પદ 5 અને છેલ્લું પદ ...                     19
# ..                                                ...                    ...
# 95                      પાણીની ઘનતા સૌથી વધુ હોય છે ?               100સે પર
# 96   પસંદ કરેલ 7 આડી રો તથા 9 ઊભી હરોળ ની હદ માટે ...                   9C7R
# 97   ભારતમાં ગ્રુહ વપરાશ માટે AC વોલ્ટેજ નું મૂલ્ય...           110 v, 60 Hz
# 98             નીચેના માંથી એરીથમેટિક ઓપરેશન. ક્યાં.?              +  અને  -
# 99   ] સ્વાવલંબી પોષણ પદ્ધત્તિ માં શાની જરૂર હોય છે ?           CO² અને પાણી
#
#                      option2                   option3  \
# 0                      બોટાદ                    ભાવનગર
# 1                લોહીની સગાઈ               શરણાઈના સૂર
# 2                  સોક્રેટીસ  ઝેર તો પીધા છે જાણી જાણી
# 3   પૂર્વોક્ત = પૂર્વ + ઊક્ત    ઉપેન્દ્ર = ઉપ + ઈન્દ્ર
# 4                         22                        21
# ..                       ...                       ...
# 95                    0સે પર                   -4સે પર
# 96                   9R × 7C                      79RC
# 97              110 v, 50 Hz              220 v, 50 Hz
# 98                 %  અને  <                 *  અને  ?
# 99                  કલોરોફિલ              સૂર્ય પ્રકાશ
#
#                     option4
# 0                      સુરત
# 1               જુમો ભિસ્તી
# 2               કુરુક્ષેત્ર
# 3   રવીન્દ્ર = રવિ + ઈન્દ્ર
# 4                        20
# ..                      ...
# 95                   4સે પર
# 96                  7R × 9C
# 97             220 v, 60 Hz
# 98                     તમામ
# 99                   ત્રણેય
#
# [100 rows x 5 columns]

# %%
df.to_csv('તલાટી અને જુનિયર કલાર્ક મોડેલ પેપર -6.tsv', sep="\t")

# %%
for i in range(100):
    print("",(i+1),") " , q[i])
    print("(A) ",o1[i])
    print("(B) " ,o2[i])
    print("(C) ",o3[i])
    print("(D) ",o4[i])
    print("\n")
# Out:
# ( 1 )  કવિ રમેશ પારેખનો જન્મ ક્યાં થયો હતો?
# (A)  અમરેલી
# (B)  બોટાદ
# (C)  ભાવનગર
# (D)  સુરત
#
#
# ( 2 )  અમરતકાકી – કઈ કૃતિનું પાત્ર છે?
# (A)  જનમટીપ
# (B)  લોહીની સગાઈ
# (C)  શરણાઈના સૂર
# (D)  જુમો ભિસ્તી
#
#
# ( 3 )  ગોપાળબાપા’ પ્રકરણ કઈ નવલકથામાંથી લેવામાં આવ્યું છે?
# (A)  દીપ નિર્વાણ
# (B)  સોક્રેટીસ
# (C)  ઝેર તો પીધા છે જાણી જાણી
# (D)  કુરુક્ષેત્ર
#
#
# ( 4 )  નીચેનામાંથી ખોટી સંધિ જણાવો.
# (A)  કવીશ્વર = કવિ + ઈશ્વર
# (B)  પૂર્વોક્ત = પૂર્વ + ઊક્ત
# (C)  ઉપેન્દ્ર = ઉપ + ઈન્દ્ર
# (D)  રવીન્દ્ર = રવિ + ઈન્દ્ર
#
#
# ( 5 )  એક સમાંતર શ્રેણીનું પ્રથમ પદ 5 અને છેલ્લું પદ 45 છે અને બધા પદોનો સરવાળો 500 હોય તો પદોની સંખ્યા કેટલી હશે?
# (A)  19
# (B)  22
# (C)  21
# (D)  20
#
#
# ( 6 )  વેપારી પોતાના માલ પર 20% અને 10% એમ બે ક્રમિક વળતર આપે છે. પરિણામી વળતર કેટલું થાય?
# (A)  30
# (B)  22
# (C)  28
# (D)  20
#
#
# ( 7 )  રાહીનું સ્થાન વર્ગમાં ઉપરથી 16મું અને નીચેથી 24મું છે, તો વર્ગમાં કુલ કેટલા વિદ્યાર્થીઓ હશે?
# (A)  41
# (B)  39
# (C)  40
# (D)  38
#
#
# ( 8 )  શ્રેણી -6, ૩, 0નો સામાન્ય તફાવત _____ છે.
# (A)  3
# (B)  -3
# (C)  -9
# (D)  9
#
#
# ( 9 )  14 કારીગરોનો 10 દિવસનો પગાર 22,400 રૂ. છે તો 16 કારીગરોનો 16 દિવસનો પગાર કેટલો થાય?
# (A)  20480
# (B)  4096
# (C)  25600
# (D)  40960
#
#
# ( 10 )   નીચેનામાંથી કયો શબ્દ તત્પુરુષ સમાસ નથી?
# (A)  દેશપ્રેમ
# (B)  વનવાસ
# (C)  પાપપુણ્ય
# (D)  સ્નેહાધિન
#
#
# ( 11 )   સાંઢ નાથ્યો’ પ્રકરણ કઈ નવલકથામાંથી લેવામાં આવ્યું છે
# (A)  ભવસાગર
# (B)  જનમટીપ
# (C)  મારી હૈયા સગડી
# (D)  દીપ નિર્માણ
#
#
# ( 12 )   નીચેનામાંથી કયો શબ્દ કર્મધારય સમાસ છે?
# (A)  પૃથ્વી
# (B)  મનહર
# (C)  પિતાંબર
# (D)  ખાધું-પીધું
#
#
# ( 13 )   ભારતના બંધારણના નીચેના પૈકી ક્યા અનુચ્છેદો સંઘ અને રાજ્યો વચ્ચેના વહીવટી સબંધો બાબતના છે?
# (A)  અનુ. 245 – 255
# (B)  અનુ. 233 – 245
# (C)  અનુ. 256 – 263
# (D)  અનુ. 269 – 279
#
#
# ( 14 )   ભારતની રાષ્ટ્રપતિની ચૂંટણીમાંદરેક સંસદ સભ્યના મતનું મૂલ્ય કેટલું છે?
# (A)  708
# (B)  504
# (C)  706
# (D)  302
#
#
# ( 15 )   16 ડિસેમ્બર, 2017ના રોજ વડાપ્રધાન શ્રી નરેન્દ્રભાઈ મોદીએ ક્યા રાજ્યમાં ગરીબોને મફત વીજળી આપવાની જાહેરાત કરી હતી?
# (A)  ઓરિસ્સા
# (B)  ઉત્તરપ્રદેશ
# (C)  મિઝોરમ
# (D)  બિહાર
#
#
# ( 16 )   ભારતમાં ઉપરાષ્ટ્રપતિ હોદ્દાની રૂએ…
# (A)  લોકસભાના અધ્યક્ષ બને છે
# (B)  રાજ્યસભાના અધ્યક્ષ બને છે
# (C)  બંનેના અધ્યક્ષ બની શકે છે
# (D)  ત્રણેયમાંથી એક પણ નહિ
#
#
# ( 17 )   Change into passive voice : “They asked me my name”
# (A)  My name is asked by them
# (B)  I was asked my name by them
# (C)  I asked my name by them
# (D)  I am asked my name by them
#
#
# ( 18 )   Give synonym of ‘poison’
# (A)  elixir
# (B)  fatal
# (C)  bitter
# (D)  venom
#
#
# ( 19 )   Choose odd one out :
# (A)  Odour
# (B)  Fragrance
# (C)  Foul
# (D)  Incense
#
#
# ( 20 )   ભારતમાં મ્યુનિસિપલ ગવર્નર ક્યા વર્ષથી અસ્તિત્વમાં આવ્યું?
# (A)  1961
# (B)  1752
# (C)  1681
# (D)  1687
#
#
# ( 21 )   પંચાયતી રાજ પ્રણાલીનો અમલ પ્રથમ કયા રાજ્યમાં થયો ?
# (A)  રાજસ્થાન
# (B)  હરિયાણા
# (C)  પંજાબ
# (D)  ગુજરાત
#
#
# ( 22 )   ભારતમાં 73 મો બંધારણીય સુધારો કયા વર્ષથી અમલમાં મુકવામાં આવ્યો ?
# (A)  1994
# (B)  1989
# (C)  1998
# (D)  1992
#
#
# ( 23 )   ક્યા સત્યાગ્રહને ગુજરાતનો પ્રથમ સત્યાગ્રહ માનવામાં આવે છે ?
# (A)  બારડોલી
# (B)  બોરસદ
# (C)  ખેડા
# (D)  અમદાવાદ
#
#
# ( 24 )   ભારતમાં ટેલિકોમ ક્રાંતિ લાવવામાં ક્યા ગુજરાતીઓએ અગ્રણી ભૂમિકા ભજવી છે ?
# (A)  જમશેદજી તાતા
# (B)  સામ પિત્રોડા
# (C)  મુકેશભાઈ અંબાણી
# (D)  ધીરુભાઈ અંબાણી
#
#
# ( 25 )   સાક્ષર નગરી તરીકે કયું શહેર જાણીતું છે ?
# (A)  નડિયાદ
# (B)  બોટાદ
# (C)  આણંદ
# (D)  ભાવનગર
#
#
# ( 26 )   ચુડા તાલુકો ગુજરાત રાજ્યના કયા જિલ્લામાં આવેલો છે ?
# (A)  બોટાદ
# (B)  રાજકોટ
# (C)  સુરેન્દ્રનગર
# (D)  ભાવનગર
#
#
# ( 27 )   કેલ્સાઈટ ના ઉત્પાદન માં ગુજરાત સમગ્ર ભારતમાં કેટલામાં ક્રમે છે ?
# (A)  પ્રથમ
# (B)  ત્રીજા
# (C)  બીજા
# (D)  ચોથા
#
#
# ( 28 )   ગુજરાત ના કેટલા જિલ્લાઓ ની સરહદ દરિયા સાથે સંકળાયેલ છે ?
# (A)  14
# (B)  16
# (C)  13
# (D)  15
#
#
# ( 29 )   નિમ્નલિખિત પૈકી કઈ અખિલ ભારતીય સેવા નથી ?
# (A)  ભારતીય પ્રશાસનિક સેવા
# (B)  ભારતીય પોલીસ સેવા
# (C)  ભારતીય વન  સેવા
# (D)  ભારતીય વિદેશ સેવા
#
#
# ( 30 )   જુમો ભિસ્તી વાર્તા માં પાડા નું નામ શું છે ?
# (A)  ભૂરો
# (B)  જુમો
# (C)  વેણુ
# (D)  રેણુ
#
#
# ( 31 )   'જેનામાં વૃક્ષ પ્રીતિ નથી તેનામાં જાણે કે જીવન પ્રીતિ જ નથી ' પંક્તિ નો અલંકાર ઓળખાવો ?
# (A)  ઉત્પ્રેક્ષા
# (B)  વનવાસ
# (C)  ઉપમા
# (D)  સ્નેહાધીન
#
#
# ( 32 )   સન્યાસી સંધિનો ક્યો વિગ્રહ સાચો છે ?
# (A)  સમ્ + નિ + _આસ્તી
# (B)  સન + ન્યાસી
# (C)  સ + નિ +‌ યાસી
# (D)  સન્ની + યાસી
#
#
# ( 33 )   વાવ તે લણે માટે સર્વનામ ના પ્રકાર દર્શાવો ?
# (A)  દર્શક
# (B)  અન્યન્યવાચક
# (C)  સાપેક્ષ
# (D)  ત્રીજા પુરુષ
#
#
# ( 34 )   થીગડું વાર્તા ના લેખક કોણ છે?
# (A)  ચંદ્રકાંત બક્ષી
# (B)  મધુરાય
# (C)  સુરેશ જોશી
# (D)  રઘુવીર ચૌધરી
#
#
# ( 35 )   નીચેનામાંથી કયો સમાસ એકપદપ્રધાન નથી ?
# (A)  દ્વન્દ્વ
# (B)  મધ્યમપદલોપી
# (C)  કર્મધારય
# (D)  ઉપપદ
#
#
# ( 36 )   ભારતનો સંત્રી એટલે શું ?
# (A)  હિંદ મહાસાગર
# (B)  હિમાલય પર્વત
# (C)  અરવલ્લી પર્વત
# (D)  કચ્છનો અખાત
#
#
# ( 37 )   બનારસ હિંદુ વિશ્વવિદ્યાલયના સ્થાપક કોણ હતા ?
# (A)  મદન મોહન માલવીયા
# (B)  બાળ ગંગાધર તિલક
# (C)  એની બેસન્ટ
# (D)  સરદાર પટેલ
#
#
# ( 38 )   સંયુક્ત રાષ્ટ્ર ઔદ્યોગિક વિકાસ સંગઠનનું મુખ્યાલય કયાં આવેલું છે?
# (A)  સ્વિટઝર્લેન્ડ
# (B)  ન્યૂયોર્ક
# (C)  વિયેના
# (D)  વોશિગ્ટન ડી.સી.
#
#
# ( 39 )   P,Q,R અને S ચાર ક્રમિક મહિના છે જો P અને S 30 દિવસો છે તો  S ક્યો મહિનો છે.?
# (A)  સપ્ટેમ્બર
# (B)  જૂન
# (C)  એપ્રિલ
# (D)  નવેમ્બર
#
#
# ( 40 )   Will you mind ____ sitting there?
# (A)  My
# (B)  Me
# (C)  I
# (D)  Mine
#
#
# ( 41 )   The dinner _____ before I arrived.
# (A)  had been served
# (B)  had been served
# (C)  will be served
# (D)  has been served
#
#
# ( 42 )   Find the uncountable noun
# (A)  Book
# (B)  a swarm
# (C)  orange
# (D)  water
#
#
# ( 43 )   Usual behaviour of a social group
# (A)  fondle
# (B)  benevolence
# (C)  custom
# (D)  custems
#
#
# ( 44 )   My brother lives ____ Jetpur.
# (A)  On
# (B)  Into
# (C)  In
# (D)  At
#
#
# ( 45 )   નીચેનામાંથી કયાં વિધાનો સાચાં છે?
# 1.ગુજરાતમાં પ્રાથમિક શાળામાં ફરજિયાત શિક્ષણ સયાજીરાવ ગાયકવાડ દ્વારા શરૂ કરાયું હતુ.
# 2.સ્વામી દયાનંદ સરસ્વતી એ આર્ય સમાજની સ્થાપના કરી હતી.  3.મોહમ્મદ ગઝનવીએ સોમનાથ પર ચડાઈ કરી તે સમયે ભીમદેવ પ્રથમ ત્યાં રાજ કરતા હતા.
# (A)  1, 2, 3
# (B)  1 અને 2
# (C)  2 અને 3
# (D)  1 અને 3
#
#
# ( 46 )   સવારે સૂર્યોદય બાદ રાજીવ એક થાંભલા સામે ઊભો હતો . થાંભલાનો પડછાયો તેની જમણી બાજુએ પડતો હતો તો તે કઈ દિશા માં મો રાખીને ઊભો હશે?
# (A)  ઉત્તર
# (B)  દક્ષિણ
# (C)  પૂર્વ
# (D)  પશ્ચિમ
#
#
# ( 47 )   એક વેપારી 1 કિલોગ્રામ ને બદલે 1250 ગ્રામ દર્શાવતા વજનકાંટાનો ઉપયોગ કરે છે વધુમાં તે મૂળ કિંમત થી 20% જેટલી વધારે અંકિત રાખે છે તો નફાની ટકાવારી કેટલી થશે ?
# (A)  35%
# (B)  45%
# (C)  50%
# (D)  None
#
#
# ( 48 )   એક સમબાજુ ચતુષ્કોણના વિકર્ણોની લંબાઈ 24 સેમી અને 10 સેમી હોય ,  તો તેના ક્ષેત્રફળ અને પરિમિતિનો ગુણોત્તર કેટલો થશે ?
# (A)  12:5
# (B)  12:7
# (C)  13:5
# (D)  None
#
#
# ( 49 )   નીચે આપેલ શ્રેણી માં ખૂટતું પદ શોધો.
# 12, 15, ____, 42, 69
# (A)  18
# (B)  26
# (C)  28
# (D)  27
#
#
# ( 50 )   એક સાંકેતિક ભાષામાં RED નો સંકેત 2076 હોય તો GREEN નો સંકેત કયો હશે ?
# (A)  9207716
# (B)  9197717
# (C)  1677209
# (D)  9207616
#
#
# ( 51 )   મંદકન્તા છંદ નું બંધારણ ઓળખવો ?
# (A)  ન ર મ ર સ લ ગા
# (B)  મ ભ ન ત ત ગા ગા
# (C)  મ ભ ન ત લ ગા ગા
# (D)  જ સ જ સ ય લ ગા
#
#
# ( 52 )   નેશનલ રજીસ્ટર ઓફ સીટીઝન (NRC) ની સ્થાપના કયા રાજય માટે કરવામા આવી છે ?
# (A)  અસમ
# (B)  બિહાર
# (C)  ગુજરાત
# (D)  રાજસ્થાન
#
#
# ( 53 )   તાજેતરમા ક્યાં દેશમાં થયેલા સરકાર વિરોધી દેખાવોમાં આશરે 30 લોકો ના મોત થયા છે ?
# (A)  ઈરાક
# (B)  પાકિસ્તાન
# (C)  અફઘાનિસ્તાન
# (D)  ઈરાન
#
#
# ( 54 )   બિહુ નૃત્ય ક્યા રાજ્યનું છે?
# (A)  બંગાળ
# (B)  આસામ
# (C)  બિહાર
# (D)  ઓરિસ્સા
#
#
# ( 55 )   ભારતે સૌપ્રથમ વખત અણુ ધડાકો ક્યા કર્યો હતો.?
# (A)  પોખરણ
# (B)  ચાંદીપુર
# (C)  શ્રી હરિકોટા
# (D)  થુંબા
#
#
# ( 56 )   સ્વતંત્ર ભારતમાં પહેલી વાર  રૂ.5000 ની ચલણી નોટો ક્યારે બહાર પાડવામાં આવી હતી.
# (A)  1950
# (B)  1966
# (C)  1960
# (D)  1954
#
#
# ( 57 )   મોઢેરાનું સૂર્યમંદિર ક્યા સોલંકી શાસકના સમયમાં બંધાવ્યું હતું?
# (A)  સિદ્ધરાજ જયસિંહ
# (B)  ભીમદેવ.1
# (C)  કુમારપાળ
# (D)  કર્ણદેવ
#
#
# ( 58 )   ઉજ્જૈનનું પ્રાચીન નામ શું હતું?
# (A)  અવંતિકા
# (B)  ઈન્દ્રપ્રસ્થ
# (C)  નાલંદા
# (D)  તક્ષશિલા
#
#
# ( 59 )   દાંડીકૂચની શરૂઆત થઈ ત્યારે પ્રથમ રાત્રિ નો વિરામ ક્યા લીધો હતો?
# (A)  લાલટ
# (B)  આલસી
# (C)  અલટ
# (D)  અસ્લાલી
#
#
# ( 60 )   ભારતમાં ઉંમર આધારિત સ્ત્રી પુરુષ ગુણોત્તર ની  ગણતરી કરવાનું ક્યારથી શરૂ થયું?
# (A)  1951
# (B)  1961
# (C)  1941
# (D)  1971
#
#
# ( 61 )   ઇન્ડિકા પુસ્તક ના રચયિતા કોણ છે ?
# (A)  મેગેસ્થનીઝ
# (B)  કૌટિલ્ય
# (C)  ફફાન
# (D)  હુએન ત્યાંગ
#
#
# ( 62 )   Wtok hard______you should fail.
# (A)  So that
# (B)  And
# (C)  But
# (D)  Lest
#
#
# ( 63 )   Give  synonyms of : contemplate
# (A)  Meditate
# (B)  Condemn
# (C)  Menuplate
# (D)  None
#
#
# ( 64 )   લઘુ વાંચવું એ કઈ કેળવણી નથી - કૃંદત નો પ્રકાર જણાવો
# (A)  વિધ્યાથૅ કુંદત
# (B)  સબંધક કૃંદત
# (C)  ભવિષ્ય કૃંદત
# (D)  વર્તમાન કૃંદત
#
#
# ( 65 )   વાછરડું જોયા વિના દૂધ દેહવા દેતી ગાય ?
# (A)  અવલી
# (B)  ઝવલી
# (C)  રવલી
# (D)  કવલી
#
#
# ( 66 )   ગુજરાતી ભાષાને અન્ય ભાષા જેવું ગૌરવ ન મળે ત્યાં સુધી પાઘડી ન પહેરવાની પ્રતિજ્ઞા કોણે લીધી હતી ?
# (A)  દલપતરામ
# (B)  નર્મદ
# (C)  પ્રેમાનંદ
# (D)  શામળ
#
#
# ( 67 )   કુસ્તીમાં ઓલમ્પિક મેડલ જીતનાર પ્રથમ ભારતિય મહિલા કોણ છે ?
# (A)  પી વી સિંધુ
# (B)  સાક્ષી મલિક
# (C)  ગીતા ફોગટ
# (D)  દીપિકા કુમારી
#
#
# ( 68 )   અસ્મિતા પર્વત કયા દિવસે ઉજવવામાં આવે છે ?
# (A)  જન્માષ્ટમી
# (B)  મહાશિવરાત્રી
# (C)  હનુમાન જયંતી
# (D)  રામનોમવી
#
#
# ( 69 )   નીતિ પંચના અધ્યક્ષ કોણ હોય છે ?
# (A)  રાષ્ટ્રપતિ
# (B)  નાણામંત્રી
# (C)  વડાપ્રધાન
# (D)  ઉપરાષ્ટ્રપતિ
#
#
# ( 70 )   ભારત સરકાર રમત-ગમતના કોચિંગ માટે કયા સર્વોચ્ચ એવોર્ડ એનાયત કરે છે ?
# (A)  ગુરુ એવોર્ડ
# (B)  ખેલરત્ન એવોર્ડ
# (C)  અર્જુન એવોર્ડ
# (D)  દ્રોણાચાર્ય એવોર્ડ
#
#
# ( 71 )   બનારસ હિંદુ વિશ્વવિદ્યાલયના સ્થાપક કોણ હતા ?
# (A)  બાલ ગંગાધર તિલક
# (B)  મદન મોહન માલવીયા
# (C)  એની બેસન્ટ
# (D)  સરદાર પટેલ
#
#
# ( 72 )   ભારતના પ્રથમ ગવર્નર જનરલ કોણ હતા ?
# (A)  વિલિયમ બેન્ટિક
# (B)  લૉર્ડ વિલીઝન
# (C)  લૉર્ડ મૈકલ
# (D)  લૉર્ડ હેસ્ટિગ્જ
#
#
# ( 73 )   CD ROM ડ્રાઈવર ની ગતિ____હોય છે?
# (A)  40 ×
# (B)  48 ×
# (C)  52 ×
# (D)  બધા જ
#
#
# ( 74 )   Winzip નામના ટૂલની મદદથી_______છે ?
# (A)  સાઇઝ ઘટાડી શકાય
# (B)  ગુપ્તતા જળવાઈ
# (C)  એક કરતાં વધુ ફાઈલો ભેગી થાય
# (D)  એક પણ નહીં
#
#
# ( 75 )   DVD સામાન્ય વધુમાં વધુ એક્સેસ દર _______ધરાવે છે ?
# (A)  5.3
# (B)  8.3
# (C)  6.3
# (D)  9.3
#
#
# ( 76 )   CNG માં મોટા ભાગે નીચેનામાંથી કયો વાયુ હોય ?
# (A)  નાઇટ્રોજન
# (B)  ઓક્સિજન
# (C)  મીથેન
# (D)  હિલિયમ
#
#
# ( 77 )   When he found the wallet is face glowed but soon it faded us the wallet was________
# (A)  Recovered
# (B)  Empty
# (C)  Expensive
# (D)  Stoien
#
#
# ( 78 )   તાજેતરમાં ક્યા દેશમાં થયેલા સરકાર વિરોધી દેખાવોમાં આશરે 30 લોકો ના મોત થયા છે ?
# (A)  ઈરાક
# (B)  પાકિસ્તાન
# (C)  અફઘનિસ્તાન
# (D)  ઈરાન
#
#
# ( 79 )   The police made him_________his crime.
# (A)  Confess
# (B)  Confessed
# (C)  To confess
# (D)  confesses
#
#
# ( 80 )   You and I are doing our work, ________ ?
# (A)  Are we
# (B)  Aren't you
# (C)  Aren't me
# (D)  Aren't i
#
#
# ( 81 )   Shraddha_______since afternoon.
# (A)  Has been working
# (B)  Is working
# (C)  Works
# (D)  Was working
#
#
# ( 82 )   લગ્ન વખતે કન્યાને પહેરવાનું વસ્ત્ર શબ્દ સમૂહ માટે નો એક શબ્દ કયો ?
# (A)  પાલવ
# (B)  મીઢણ
# (C)  પાનેતર
# (D)  સાડી
#
#
# ( 83 )   મધ્યકાલીન ગુજરાતી સાહિત્યમાં સૌથી વધુ લોક પ્રિય પદ્યવાર્તાકાર તરીકે કોણ પ્રસિદ્ધ છે ?
# (A)  પ્રેમાનંદ
# (B)  ભોજા ભગત
# (C)  ભાલણ
# (D)  શામળ
#
#
# ( 84 )   ઉંબરે ઊભી સાંભળું રે બોલ વાલમના ગીત લખનાર ?
# (A)  મણિલાલ દેસાઈ
# (B)  મણિલાલ વેગડ
# (C)  મનસુખલાલ
# (D)  મહિપત ભાઈ
#
#
# ( 85 )   ભારતની પ્રથમ વોટર ટેપ નો પ્રારંભ ક્યારે થયો ?
# (A)  મુંબઈ
# (B)  દિલ્હી
# (C)  અમદાવાદ
# (D)  હૈદરાબાદ
#
#
# ( 86 )   Ipl પીએમ કોલકાતા નાઇટ રાઇડર્સના કેપ્ટન તરીકે કોની પસંદગી કરવામાં આવી છે ?
# (A)  યુસુફ પઠાણ
# (B)  ભુનેશ્વર
# (C)  મહેન્દ્રસિંહ ધોની
# (D)  શ્રેયસ ઐયર
#
#
# ( 87 )   16 ફેબ્રુઆરી 2020 ના રોજ ગુરુ રવિદાસ ની કેટલામી જન્મ જયંતી ઉજવાય ?
# (A)  653
# (B)  650
# (C)  645
# (D)  655
#
#
# ( 88 )   રાષ્ટ્રીય ઉત્પાદકતા દિવસ ક્યારે ઉજવવામાં આવે છે ?
# (A)  12 ફેબ્રુઆરી
# (B)  8 માર્ચ
# (C)  10 ફેબ્રુઆરી
# (D)  20 ફેબ્રુઆરી
#
#
# ( 89 )   I really enjoy______ the poor.
# (A)  Help
# (B)  Helped
# (C)  Helping
# (D)  Will help
#
#
# ( 90 )   Don't _______ your time, otherwise you can't progress in life.
# (A)  Waste
# (B)  Start
# (C)  Lose
# (D)  Spoil
#
#
# ( 91 )   સક્રિય રોના પ્રથમ સેલ પર જવા માટે નીચેનામાંથી ____કી વપરાય છે  ?
# (A)  END
# (B)  HOME
# (C)  TAB
# (D)  ESC
#
#
# ( 92 )   To run after someone is________
# (A)  Marathen
# (B)  Race
# (C)  Follo
# (D)  Chase
#
#
# ( 93 )   Kusum father was_________ London last month.
# (A)  Had
# (B)  Gone
# (C)  In
# (D)  From
#
#
# ( 94 )   Find nearly opposite meaning : monarchy
# (A)  Kingdom
# (B)  Democracy
# (C)  Freedom
# (D)  Strong rule
#
#
# ( 95 )   રેફ્રિજરેટરમાં કુલન્ટ રૂપે______ગેસનો ઉપયોગ થાય છે ?
# (A)  એમોનીયા
# (B)  કાર્બન ડાયોક્સાઇડ
# (C)  હિલિયમ
# (D)  નાઇટ્રોજન
#
#
# ( 96 )   પાણીની ઘનતા સૌથી વધુ હોય છે ?
# (A)  100સે પર
# (B)  0સે પર
# (C)  -4સે પર
# (D)  4સે પર
#
#
# ( 97 )   પસંદ કરેલ 7 આડી રો તથા 9 ઊભી હરોળ ની હદ માટે એડ્રેસ બોક્સમાં _____ લખાશે   ?
# (A)  9C7R
# (B)  9R × 7C
# (C)  79RC
# (D)  7R × 9C
#
#
# ( 98 )   ભારતમાં ગ્રુહ વપરાશ માટે AC વોલ્ટેજ નું મૂલ્ય અને આવૃત્તિ શું છે ?
# (A)  110 v, 60 Hz
# (B)  110 v, 50 Hz
# (C)  220 v, 50 Hz
# (D)  220 v, 60 Hz
#
#
# ( 99 )   નીચેના માંથી એરીથમેટિક ઓપરેશન. ક્યાં.?
# (A)  +  અને  -
# (B)  %  અને  <
# (C)  *  અને  ?
# (D)  તમામ
#
#
# ( 100 )  ] સ્વાવલંબી પોષણ પદ્ધત્તિ માં શાની જરૂર હોય છે ?
# (A)  CO² અને પાણી
# (B)  કલોરોફિલ
# (C)  સૂર્ય પ્રકાશ
# (D)  ત્રણેય

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.
