# %% [markdown]
# # clustering-tds
#
# Use the "Run" button to execute the code.

# %%
# !pip install jovian --upgrade --quiet

# %%
import jovian

# %%
# Execute this to save new versions of the notebook
jovian.commit(project="clustering-tds")

# %% [markdown]
# **Demo on k-Means clustering and cluster analysis**

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import KMeans

# %%
stockData = pd.read_csv('TDS_Week_5_Dataset_2 - Sheet1.csv')

# %%
# All % columns were on a scale where 1 meant 100%, except for Stock Return %. We multiply all % columns (except Returns) by 100
stockData['Free Float Market Cap %'] = stockData['Free Float Market Cap %']*100
stockData['RoE %'] = stockData['RoE %']*100
stockData['RoCE %'] = stockData['RoCE %']*100
stockData['EBIT Margin %'] = stockData['EBIT Margin %']*100
stockData['PAT %'] = stockData['PAT %']*100
stockData.describe()
# Out:
#        record number        Price   Market Cap  Free Float Market Cap %  \
# count    1225.000000  1225.000000  1225.000000              1225.000000
# mean      612.000000     0.010163     0.015214                38.659175
# std       353.771348     0.038309     0.060153                16.673399
# min         0.000000     0.000000     0.000000                 0.000000
# 25%       306.000000     0.001167     0.000601                24.450608
# 50%       612.000000     0.003291     0.001707                36.398549
# 75%       918.000000     0.008680     0.006294                47.973117
# max      1224.000000     1.000000     1.000000               100.000000
#
#             6m ADV        RoE %       RoCE %  EBIT Margin %          EPS  \
# count  1225.000000  1225.000000  1225.000000    1225.000000  1225.000000
# mean      0.027942    52.906076    56.741580      53.847632     0.022321
# std       0.090669    12.632005     7.923857       8.536269     0.051913
# min       0.000000     0.000000     0.000000       0.000000     0.000000
# 25%       0.000550    50.696507    52.707946      51.687277     0.003966
# 50%       0.002338    54.490617    55.832344      53.847632     0.009215
# 75%       0.010388    58.547111    59.838861      56.672358     0.020459
# max       1.000000   100.000000   100.000000     100.000000     1.000000
#
#              PAT %  Stock Return %
# count  1225.000000     1225.000000
# mean     51.524376        0.145038
# std       8.710919        0.075296
# min       0.000000        0.000000
# 25%      50.327121        0.102570
# 50%      51.967712        0.132243
# 75%      54.324236        0.171613
# max     100.000000        1.000000

# %%
features = stockData.columns[2:]
features
# Out:
# Index(['Market Cap', 'Free Float Market Cap %', '6m ADV', 'RoE %', 'RoCE %',
#        'EBIT Margin %', 'EPS', 'PAT %', 'Stock Return %'],
#       dtype='object')

# %%
# Good idea to normalize the features before k-Means
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
stockDataFeatures_scaled = scaler.fit_transform(stockData[features])
stockDataFeatures_scaled = pd.DataFrame(stockDataFeatures_scaled, columns=features)
stockDataFeatures_scaled.describe()
# Out:
#         Market Cap  Free Float Market Cap %       6m ADV        RoE %  \
# count  1225.000000              1225.000000  1225.000000  1225.000000
# mean      0.015214                 0.386592     0.027942     0.529061
# std       0.060153                 0.166734     0.090669     0.126320
# min       0.000000                 0.000000     0.000000     0.000000
# 25%       0.000601                 0.244506     0.000550     0.506965
# 50%       0.001707                 0.363985     0.002338     0.544906
# 75%       0.006294                 0.479731     0.010388     0.585471
# max       1.000000                 1.000000     1.000000     1.000000
#
#             RoCE %  EBIT Margin %          EPS        PAT %  Stock Return %
# count  1225.000000    1225.000000  1225.000000  1225.000000     1225.000000
# mean      0.567416       0.538476     0.022321     0.515244        0.145038
# std       0.079239       0.085363     0.051913     0.087109        0.075296
# min       0.000000       0.000000     0.000000     0.000000        0.000000
# 25%       0.527079       0.516873     0.003966     0.503271        0.102570
# 50%       0.558323       0.538476     0.009215     0.519677        0.132243
# 75%       0.598389       0.566724     0.020459     0.543242        0.171613
# max       1.000000       1.000000     1.000000     1.000000        1.000000

# %%
kmeans = KMeans(7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_38/4277937899.py in <module>
# ----> 1 kmeans = KMeans(7,seed=1729)
#
# TypeError: __init__() got an unexpected keyword argument 'seed'

# %%
clus = kmeans.fit_predict(stockDataFeatures_scaled)

# %%
stockData['cluster'] = clus
stockData['cluster'].value_counts()
# Out:
# 5    389
# 2    360
# 4    212
# 1    155
# 3     62
# 0     28
# 6     19
# Name: cluster, dtype: int64

# %%
clusterDesc = pd.DataFrame(stockData.iloc[:,2:].groupby('cluster').mean().round(3))
clusterDesc.insert(0,'size',stockData['cluster'].value_counts())

# %%
clusterDesc
# Out:
#          size  Market Cap  Free Float Market Cap %  6m ADV   RoE %  RoCE %  \
# cluster
# 0          28       0.303                   48.722   0.503  60.882  63.020
# 1         155       0.008                   67.009   0.026  53.874  56.317
# 2         360       0.006                   24.000   0.008  52.679  54.865
# 3          62       0.003                   40.550   0.012  13.253  46.030
# 4         212       0.019                   29.475   0.023  63.223  65.256
# 5         389       0.006                   44.397   0.019  54.100  56.077
# 6          19       0.001                   49.133   0.003  27.401  40.063
#
#          EBIT Margin %    EPS   PAT %  Stock Return %
# cluster
# 0               57.662  0.011  55.212           0.166
# 1               54.539  0.036  52.429           0.129
# 2               53.035  0.020  51.288           0.149
# 3               45.871  0.050  38.270           0.121
# 4               60.229  0.006  57.685           0.142
# 5               53.804  0.025  51.951           0.153
# 6               13.712  0.015   8.962           0.115
