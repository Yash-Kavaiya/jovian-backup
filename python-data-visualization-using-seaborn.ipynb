# %% [markdown]
# # python-data-visualization-using-seaborn
#
# Use the "Run" button to execute the code.

# %%
# !pip install jovian --upgrade --quiet

# %%
import jovian

# %%
# Execute this to save new versions of the notebook
jovian.commit(project="python-data-visualization-using-seaborn")
# Out:
# [jovian] Updating notebook "yash-kavaiya/python-data-visualization-using-seaborn" on https://jovian.ai
# [jovian] Committed successfully! https://jovian.ai/yash-kavaiya/python-data-visualization-using-seaborn
# 'https://jovian.ai/yash-kavaiya/python-data-visualization-using-seaborn'

# %% [markdown]
# # Introductory Level
# - Scatter Plot
# - Line Plot
# - Count Plot
# - PointPlot
# - BoxenPlot
# - Violenpot
# - Barplot
# - Swarmplot
# - Stripplot
# - Catplot

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="darkgrid")

# %%
tips=sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # Relplot https://seaborn.pydata.org/generated/seaborn.relplot.html#seaborn.relplot

# %%
sns.relplot(x='total_bill',y='tip',data=tips);

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker');

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker',style="time");

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='size',palette='ch:r=-5,l=.75 ');

# %%
sns.relplot(x='total_bill',y='tip',data=tips,size='size');

# %%
sns.relplot(x='total_bill',y='tip',data=tips,size='size',sizes=(15,200));

# %%
ax=sns.scatterplot(x='total_bill',y='tip',data=tips)

# %%
ax1=sns.scatterplot(x='total_bill',y='tip',data=tips,hue='time')

# %%
ax2=sns.scatterplot(x='total_bill',y='tip',data=tips,style='time')

# %%
ax2=sns.scatterplot(x='total_bill',y='tip',data=tips,style='time',hue='time')

# %%
ax3=sns.scatterplot(x='total_bill',y='tip',data=tips,hue='day',style='time')

# %%
ax4=sns.scatterplot(x='total_bill',y='tip',data=tips,size='size')

# %%
ax5=sns.scatterplot(x='total_bill',y='tip',data=tips,size='size',hue='size');

# %%
cmap=sns.cubehelix_palette(dark=0.1,light=0.5,as_cmap=True)
ax6=sns.scatterplot(x='total_bill',y='tip',hue="size",size='size',palette=cmap,data=tips)

# %%
cmap=sns.cubehelix_palette(dark=0.1,light=0.8,as_cmap=True)
ax8=sns.scatterplot(x='total_bill',y='tip',hue="size",size='size',palette=cmap,data=tips,sizes=(20,200),legend="full")

# %%
cmap=sns.cubehelix_palette(dark=0.1,light=0.8,as_cmap=True)
ax8=sns.scatterplot(x='total_bill',y='tip',hue="day",size='smoker',palette="Set2",data=tips,legend="full")

# %%
ax9=sns.scatterplot(x='total_bill',y='tip',s=100,color="0.2",marker="+",data=tips)

# %%
iris=sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
ax10=sns.scatterplot(x="sepal_length",y="sepal_width",hue="species",data=iris,style="species")

# %%
ax11=sns.scatterplot(x=iris.sepal_length,y=iris.sepal_width,hue=iris.species,style=iris.species)

# %%
index=pd.date_range("1 1 2000",periods=100,freq="m",name="date")
index
# Out:
# DatetimeIndex(['2000-01-31', '2000-02-29', '2000-03-31', '2000-04-30',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-30', '2000-10-31', '2000-11-30', '2000-12-31',
#                '2001-01-31', '2001-02-28', '2001-03-31', '2001-04-30',
#                '2001-05-31', '2001-06-30', '2001-07-31', '2001-08-31',
#                '2001-09-30', '2001-10-31', '2001-11-30', '2001-12-31',
#                '2002-01-31', '2002-02-28', '2002-03-31', '2002-04-30',
#                '2002-05-31', '2002-06-30', '2002-07-31', '2002-08-31',
#                '2002-09-30', '2002-10-31', '2002-11-30', '2002-12-31',
#                '2003-01-31', '2003-02-28', '2003-03-31', '2003-04-30',
#                '2003-05-31', '2003-06-30', '2003-07-31', '2003-08-31',
#                '2003-09-30', '2003-10-31', '2003-11-30', '2003-12-31',
#                '2004-01-31', '2004-02-29', '2004-03-31', '2004-04-30',
# ...

# %%
data=np.random.randn(100,4).cumsum(axis=0)
data
# Out:
# array([[ 1.17746732e-02,  1.61017899e-02,  3.12503530e-01,
#         -6.25323455e-01],
#        [ 1.49454986e+00, -1.01274296e+00,  2.79577226e-01,
#         -1.70872548e+00],
#        [ 2.22954267e+00, -1.08860141e+00,  1.12396393e+00,
#         -1.21514345e+00],
#        [ 1.57986903e+00, -2.07473512e+00,  3.14936506e-01,
#         -2.66818227e+00],
#        [ 1.97201338e+00, -2.07234449e+00,  1.49629824e+00,
#         -2.16884461e+00],
#        [ 1.85887019e+00, -4.32731730e+00,  1.98157928e+00,
#         -3.19603724e+00],
#        [ 2.52055627e+00, -6.26900419e+00,  1.34893148e+00,
#         -3.77522713e+00],
#        [ 2.96003942e+00, -8.06896949e+00,  2.33942466e+00,
#         -2.29249531e+00],
#        [ 4.14381375e+00, -9.48093525e+00,  2.13734363e+00,
#         -4.68481911e+00],
#        [ 4.13008742e+00, -8.39185967e+00,  1.54784310e+00,
#         -3.07672788e+00],
#        [ 2.72166942e+00, -8.58253498e+00, -1.09619401e+00,
#         -3.88380127e+00],
# ...

# %%
wide_df=pd.DataFrame(data,index,["a","b","c","d"])
wide_df
# Out:
#                     a         b         c          d
# date
# 2000-01-31   0.011775  0.016102  0.312504  -0.625323
# 2000-02-29   1.494550 -1.012743  0.279577  -1.708725
# 2000-03-31   2.229543 -1.088601  1.123964  -1.215143
# 2000-04-30   1.579869 -2.074735  0.314937  -2.668182
# 2000-05-31   1.972013 -2.072344  1.496298  -2.168845
# ...               ...       ...       ...        ...
# 2007-12-31 -23.270322 -1.538940  6.032018 -14.727180
# 2008-01-31 -24.626977 -0.179074  4.100592 -14.487313
# 2008-02-29 -22.594003 -1.115759  5.425924 -15.023564
# 2008-03-31 -24.553129 -1.592427  6.027721 -14.002129
# 2008-04-30 -22.858709 -0.058749  3.730385 -14.170864
#
# [100 rows x 4 columns]

# %%
ax11=sns.scatterplot(data=wide_df)
